# %% [markdown]
# # Functional Encryption - Classification and information leakage
#
# Our start point is the work on encrypted classification using Function Encryption of the paper [Reading in the Dark: Classifying Encrypted Digits with Functional Encryption](https://eprint.iacr.org/2018/206), and the associated [GitHub repository](https://github.com/edufoursans/reading-in-the-dark).
#
# More specifically, the paper provides a new Functional Encryption scheme for quadratic multi-variate polynomials, which can under some hypothesis be seen as a single hidden layer neural network with a quadratic activation.
# In the paper, the output corresponds to element per class, and it is made in clear. We analyse how this output can disclose information about the initial input or about charasteristics of this input.
#
# To this aim, we have just built a dataset which is very similar to MNIST, used in the original paper but which is composed of 26 letter characters of 5 differents fonts. Our goal is two-fold:
#  - Evaluate how the output in clear can be leverage with a public NN to make better prediction than a simple `argmax` function in the character recognition task.
#  - Analyse to what extent the output in clear of the model trained for character recognition can reveal information about the font used, using an "adversarial" network.
#
# ### Purpose
#
# We keep the same structure as before of the network but now try to do a single optimisation step by improving a single loss which contains both objectives and tries to reduce the collateral objective.
#
# More formally, what we want to do is to optimize the following problem:
# $ \min_Q [ \min_C l_C(Q, C) - \alpha \min_F l_F(Q, F) ] $
#
#
# The game is in 3 epoch time:
#  - The normal phase where both tasks learn and strenghten before the joint optimisation:
#   - `Optimize: Q + C`
#   - `Optimize: Freezed(Q) + F`
#  - The phase with the joint optimisation, where C and F are updated depending on the Q variations and Q is optimised to reduce the loss `C - alpha * F`:
#   - `Optimize: Freezed(Q) + C`
#   - `Optimize: Freezed(Q) + F`
#   - `Optimize : Q + [Freezed(C) - alpha * Freezed(F)]`
#  - The recovery part, where both tasks recover from the perturbation, `Q` won't change now:
#   - `Optimize: Freezed(Q) + C`
#   - `Optimize: Freezed(Q) + F`
#
# Contrary to Part 9, we use the same optimiser for all optimisation task. Note that our objective on Q imposes that we take `alpha < loss(F) / loss(C)` so in practice we keep $\alpha \leq 2$.

# %% [markdown]
# # 1. Joint optimisation

# %% [markdown]
# We will use the code directly from the repo, to make the notebook more readable. Functions are similar to those presented earlier.

# %%
# Allow to load packages from parent
import sys, os
sys.path.insert(1, os.path.realpath(os.path.pardir))

# %%
import random

import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as utils

import learn
from learn import load_data, show_results

# %%
class Parser:
    """Parameters for the training"""
    def __init__(self):
        self.epochs = 10
        self.sabotage_epochs = 10
        self.recovering_epochs = 10
        self.lr = 0.002
        self.momentum = 0.5
        self.test_batch_size = 1000
        self.batch_size = 64
        self.log_interval = 100

# %% [markdown]
# Let's define the model with the describes architecture. Basically you have 3 blocs: 1 quadratic and 2 CNN.

# %%
N_CHARS = 26
N_FONTS = 5
class QuadConvNet(nn.Module):
    def __init__(self):
        super(QuadConvNet, self).__init__()
        self.proj1 = nn.Linear(784, 50)
        self.diag1 = nn.Linear(50, 8)
        
        # --- FFN for characters
        self.lin1 = nn.Linear(8, 16)
        self.lin2 = nn.Linear(16, N_CHARS)
        
        # --- FFN for font families
        self.lin3 = nn.Linear(8, 16)
        self.lin4 = nn.Linear(16, N_FONTS)
        
    def quad(self, x):
        """Same as forward up to the junction part
        Used for the collateral training"""
        # --- Quadratic 
        x = x.view(-1, 784)
        x = self.proj1(x)
        x = x * x
        x = self.diag1(x)
        return x
    
    def conv_char(self, x):
        # --- FFN
        x = F.relu(self.lin1(x))
        x = self.lin2(x)
        return x
        
    def conv_font(self, x):
        # --- FFN
        x = F.relu(self.lin3(x))
        x = self.lin4(x)
        return x

    def forward_char(self, x):
        x = self.quad(x)
        x = self.conv_char(x)
        return F.log_softmax(x, dim=1)
    
    def forward_font(self, x):
        x = self.quad(x)
        x = self.conv_font(x)
        return F.log_softmax(x, dim=1)
    
    def get_params(self, net):
        """Select the params for a given part of the net"""
        if net == 'quad':
            layers = [self.proj1, self.diag1]
        elif net == 'char':
            layers = [self.lin1, self.lin2]
        elif net == 'font':
            layers = [self.lin3, self.lin4]
        else:
            raise AttributeError(f'{net} type not recognized')
        params = [p for layer in layers for p in layer.parameters()]
        return params
    
    def freeze(self, net):
        """Freeze a part of the net"""
        net_params = self.get_params(net)
        for param in net_params:
            param.requires_grad = False
            
    def unfreeze(self):
        """Unfreeze the net"""
        for param in self.parameters():
            param.requires_grad = True

# %% [markdown]
# Next, we define the train and test functions. They assume the train_load return two labels: the char and the font of some input.
#
# In the training phase we execute the 3 steps as described aboved.
#
# In the test function, we just test the performance for the main and collateral tasks.

# %%
def train(args, model, train_loader, optimizer, epoch, alpha, initial_phase, perturbate):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # Split the two targets
        target_char = target[:, 0]
        target_font = target[:, 1]
        
        
        # Optimize C and F parts of the model with 2 strategies
        if initial_phase:  # Normal optimisation of C
            # Phase 1: Optimise Q + C
            optimizer.zero_grad()
            output = model.forward_char(data)
            loss_char = F.nll_loss(output, target_char)
            loss_char.backward()
            optimizer.step()
        else: # Freezed(Q) optimisation
            # Phase 1: Optimise Freezed(Q) + F
            model.freeze('quad')
            optimizer.zero_grad()
            output_char = model.forward_char(data)
            loss_char = F.nll_loss(output_char, target_char)
            loss_char.backward()
            optimizer.step()
            model.unfreeze()
        # Phase 2: Optimise Freezed(Q) + F
        model.freeze('quad')
        output_font = model.forward_font(data)
        loss_font = F.nll_loss(output_font, target_font)
        loss_font.backward()
        optimizer.step()
        model.unfreeze()
        
        if perturbate:
            # Optimize Q
            model.freeze('font')
            model.freeze('char')
            optimizer.zero_grad()
            output_char = model.forward_char(data)
            loss_char = F.nll_loss(output_char, target_char)

            output_font = model.forward_font(data)
            loss_font = F.nll_loss(output_font, target_font)

            loss = loss_char - alpha * loss_font
            loss.backward()
            optimizer.step()
            model.unfreeze()
        
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss Char: {:.6f} Loss Font: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss_char.item(), loss_font.item()))

# %%
def test(args, model, test_loader):
    model.eval()
    correct_char = 0
    correct_font = 0
    with torch.no_grad():
        for data, target in test_loader:
            # Split the two targets
            target_char = target[:, 0]
            target_font = target[:, 1]

            # Char evaluation
            output = model.forward_char(data)
            pred = output.argmax(1, keepdim=True)
            correct_char += pred.eq(target_char.view_as(pred)).sum().item()
            
            # Font evaluation
            output = model.forward_font(data)
            pred = output.argmax(1, keepdim=True)
            correct_font += pred.eq(target_font.view_as(pred)).sum().item()

    acc_char = 100. * correct_char / len(test_loader.dataset)
    acc_font = 100. * correct_font / len(test_loader.dataset)
    print('\nTest set: Accuracy Char : {}/{} ({:.2f}%)\n          Accuracy Font : {}/{} ({:.2f}%)'.format(
        correct_char, len(test_loader.dataset), acc_char, correct_font, len(test_loader.dataset), acc_font))

    return acc_char, acc_font

# %% [markdown]
# Now we can handle the main function. The only thing that really changes is that we now want to have both labels associated to a input item.

# %%
def build_tensor_dataset(data, target):
    """Utility function to cast our data into a normalized torch TensorDataset"""
    normed_data = [(d - d.mean()) / d.std() for d in data]
    normed_data = torch.stack([torch.Tensor(d).reshape(1, 28, 28) for d in normed_data])
    target = torch.LongTensor([[i[0][0], i[1][0]] for i in target])
    tensor_dataset = utils.TensorDataset(normed_data, target)
    return tensor_dataset

# %% [markdown]
# Last the main function !

# %%
def main(alpha=0):
    """
    Perform a learning phase
    """
    torch.manual_seed(1)
    args = Parser()

    data = load_data()
    train_data, train_target_char, train_target_family, test_data, test_target_char, test_target_family = data
    # Merge the target datasets
    train_target = list(zip(train_target_char, train_target_family))
    test_target = list(zip(test_target_char, test_target_family))

    # We use here the slightly modified version of this function
    train_dataset = build_tensor_dataset(train_data, train_target)
    test_dataset = build_tensor_dataset(test_data, test_target)

    train_loader = utils.DataLoader(
        train_dataset,
        batch_size=args.batch_size, shuffle=True
    )

    test_loader = utils.DataLoader(
        test_dataset,
        batch_size=args.test_batch_size, shuffle=True
    )
   
    model = QuadConvNet()

    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)
    
    test_perfs_char = []
    test_perfs_font = []
    
    for epoch in range(1, args.epochs + args.sabotage_epochs + args.recovering_epochs + 1):
        initial_phase = epoch <= args.epochs
        if initial_phase:
            print("(initial phase)")
        perturbate = epoch > args.epochs and epoch <= args.epochs + args.sabotage_epochs
        if perturbate:
            print("(perturbate)")
        train(args, model, train_loader, optimizer, epoch, alpha, initial_phase, perturbate)
        test_perf_char, test_perf_font = test(args, model, test_loader)
        test_perfs_char.append(test_perf_char)
        test_perfs_font.append(test_perf_font)

    return test_perfs_char, test_perfs_font, model

# %%
results = {}
test_perfs_char_clean, test_perfs_font_clean, model_clean = main(alpha=0)
results["Main task in the normal setting"] = test_perfs_char_clean
results["Collateral task in the normal setting"] = test_perfs_font_clean
# Out:
# Training set 60000 items
# Testing set  10000 items
# (initial phase)
# Train Epoch: 1 [0/60000 (0%)]	Loss Char: 3.241490 Loss Font: 1.619655
# Train Epoch: 1 [6400/60000 (11%)]	Loss Char: 3.243401 Loss Font: 1.634818
# Train Epoch: 1 [12800/60000 (21%)]	Loss Char: 3.125095 Loss Font: 1.670732
# Train Epoch: 1 [19200/60000 (32%)]	Loss Char: 2.984154 Loss Font: 1.708088
# Train Epoch: 1 [25600/60000 (43%)]	Loss Char: 2.888399 Loss Font: 1.640867
# Train Epoch: 1 [32000/60000 (53%)]	Loss Char: 2.595878 Loss Font: 1.645604
# Train Epoch: 1 [38400/60000 (64%)]	Loss Char: 2.191660 Loss Font: 1.634457
# Train Epoch: 1 [44800/60000 (75%)]	Loss Char: 1.920311 Loss Font: 1.644273
# Train Epoch: 1 [51200/60000 (85%)]	Loss Char: 1.738962 Loss Font: 1.688137
# Train Epoch: 1 [57600/60000 (96%)]	Loss Char: 1.865170 Loss Font: 1.599646
#
# Test set: Accuracy Char : 4957/10000 (49.57%)
#           Accuracy Font : 2659/10000 (26.59%)
# (initial phase)
# Train Epoch: 2 [0/60000 (0%)]	Loss Char: 1.318387 Loss Font: 1.608933
# Train Epoch: 2 [6400/60000 (11%)]	Loss Char: 1.550118 Loss Font: 1.520178
# Train Epoch: 2 [12800/60000 (21%)]	Loss Char: 1.160004 Loss Font: 1.508529
# Train Epoch: 2 [19200/60000 (32%)]	Loss Char: 1.097548 Loss Font: 1.513336
# Train Epoch: 2 [25600/60000 (43%)]	Loss Char: 1.117916 Loss Font: 1.522316
# Train Epoch: 2 [32000/60000 (53%)]	Loss Char: 0.818825 Loss Font: 1.561099
# Train Epoch: 2 [38400/60000 (64%)]	Loss Char: 0.771766 Loss Font: 1.542226
# Train Epoch: 2 [44800/60000 (75%)]	Loss Char: 1.050970 Loss Font: 1.455329
# Train Epoch: 2 [51200/60000 (85%)]	Loss Char: 0.822885 Loss Font: 1.556443
# Train Epoch: 2 [57600/60000 (96%)]	Loss Char: 1.063315 Loss Font: 1.586820
#
# Test set: Accuracy Char : 7465/10000 (74.65%)
#           Accuracy Font : 3104/10000 (31.04%)
# (initial phase)
# Train Epoch: 3 [0/60000 (0%)]	Loss Char: 0.846573 Loss Font: 1.514468
# Train Epoch: 3 [6400/60000 (11%)]	Loss Char: 0.830905 Loss Font: 1.440030
# Train Epoch: 3 [12800/60000 (21%)]	Loss Char: 0.838321 Loss Font: 1.605255
# Train Epoch: 3 [19200/60000 (32%)]	Loss Char: 0.746728 Loss Font: 1.463067
# Train Epoch: 3 [25600/60000 (43%)]	Loss Char: 0.769849 Loss Font: 1.550862
# Train Epoch: 3 [32000/60000 (53%)]	Loss Char: 0.517730 Loss Font: 1.450067
# Train Epoch: 3 [38400/60000 (64%)]	Loss Char: 0.601043 Loss Font: 1.477565
# Train Epoch: 3 [44800/60000 (75%)]	Loss Char: 0.542821 Loss Font: 1.628974
# Train Epoch: 3 [51200/60000 (85%)]	Loss Char: 0.596551 Loss Font: 1.468087
# Train Epoch: 3 [57600/60000 (96%)]	Loss Char: 0.743588 Loss Font: 1.523732
#
# Test set: Accuracy Char : 8261/10000 (82.61%)
#           Accuracy Font : 3257/10000 (32.57%)
# (initial phase)
# Train Epoch: 4 [0/60000 (0%)]	Loss Char: 0.549530 Loss Font: 1.450864
# Train Epoch: 4 [6400/60000 (11%)]	Loss Char: 0.383065 Loss Font: 1.469275
# Train Epoch: 4 [12800/60000 (21%)]	Loss Char: 0.436886 Loss Font: 1.455344
# Train Epoch: 4 [19200/60000 (32%)]	Loss Char: 0.598079 Loss Font: 1.564009
# Train Epoch: 4 [25600/60000 (43%)]	Loss Char: 0.318404 Loss Font: 1.417232
# Train Epoch: 4 [32000/60000 (53%)]	Loss Char: 0.465218 Loss Font: 1.481279
# Train Epoch: 4 [38400/60000 (64%)]	Loss Char: 0.416448 Loss Font: 1.493089
# Train Epoch: 4 [44800/60000 (75%)]	Loss Char: 0.476082 Loss Font: 1.460058
# Train Epoch: 4 [51200/60000 (85%)]	Loss Char: 0.561793 Loss Font: 1.416564
# Train Epoch: 4 [57600/60000 (96%)]	Loss Char: 0.383984 Loss Font: 1.525175
#
# Test set: Accuracy Char : 8492/10000 (84.92%)
#           Accuracy Font : 3349/10000 (33.49%)
# (initial phase)
# Train Epoch: 5 [0/60000 (0%)]	Loss Char: 0.465208 Loss Font: 1.441594
# Train Epoch: 5 [6400/60000 (11%)]	Loss Char: 0.482403 Loss Font: 1.375755
# Train Epoch: 5 [12800/60000 (21%)]	Loss Char: 0.405939 Loss Font: 1.326863
# Train Epoch: 5 [19200/60000 (32%)]	Loss Char: 0.362571 Loss Font: 1.499023
# Train Epoch: 5 [25600/60000 (43%)]	Loss Char: 0.332217 Loss Font: 1.405209
# Train Epoch: 5 [32000/60000 (53%)]	Loss Char: 0.303684 Loss Font: 1.413099
# Train Epoch: 5 [38400/60000 (64%)]	Loss Char: 0.489397 Loss Font: 1.481379
# Train Epoch: 5 [44800/60000 (75%)]	Loss Char: 0.263597 Loss Font: 1.312635
# Train Epoch: 5 [51200/60000 (85%)]	Loss Char: 0.546229 Loss Font: 1.443149
# Train Epoch: 5 [57600/60000 (96%)]	Loss Char: 0.264077 Loss Font: 1.464120
#
# Test set: Accuracy Char : 8951/10000 (89.51%)
#           Accuracy Font : 3599/10000 (35.99%)
# (initial phase)
# Train Epoch: 6 [0/60000 (0%)]	Loss Char: 0.235854 Loss Font: 1.509135
# Train Epoch: 6 [6400/60000 (11%)]	Loss Char: 0.449579 Loss Font: 1.517862
# Train Epoch: 6 [12800/60000 (21%)]	Loss Char: 0.241981 Loss Font: 1.432219
# Train Epoch: 6 [19200/60000 (32%)]	Loss Char: 0.586458 Loss Font: 1.423619
# Train Epoch: 6 [25600/60000 (43%)]	Loss Char: 0.439160 Loss Font: 1.557969
# Train Epoch: 6 [32000/60000 (53%)]	Loss Char: 0.378124 Loss Font: 1.526518
# Train Epoch: 6 [38400/60000 (64%)]	Loss Char: 0.249369 Loss Font: 1.578080
# Train Epoch: 6 [44800/60000 (75%)]	Loss Char: 0.254407 Loss Font: 1.413932
# Train Epoch: 6 [51200/60000 (85%)]	Loss Char: 0.202057 Loss Font: 1.415316
# Train Epoch: 6 [57600/60000 (96%)]	Loss Char: 0.332146 Loss Font: 1.304578
#
# Test set: Accuracy Char : 9034/10000 (90.34%)
#           Accuracy Font : 3692/10000 (36.92%)
# (initial phase)
# Train Epoch: 7 [0/60000 (0%)]	Loss Char: 0.211176 Loss Font: 1.406888
# Train Epoch: 7 [6400/60000 (11%)]	Loss Char: 0.303036 Loss Font: 1.432919
# Train Epoch: 7 [12800/60000 (21%)]	Loss Char: 0.273678 Loss Font: 1.490821
# Train Epoch: 7 [19200/60000 (32%)]	Loss Char: 0.378296 Loss Font: 1.296944
# Train Epoch: 7 [25600/60000 (43%)]	Loss Char: 0.434525 Loss Font: 1.333350
# Train Epoch: 7 [32000/60000 (53%)]	Loss Char: 0.345688 Loss Font: 1.412492
# Train Epoch: 7 [38400/60000 (64%)]	Loss Char: 0.466365 Loss Font: 1.438078
# Train Epoch: 7 [44800/60000 (75%)]	Loss Char: 0.234117 Loss Font: 1.409068
# Train Epoch: 7 [51200/60000 (85%)]	Loss Char: 0.335284 Loss Font: 1.357813
# Train Epoch: 7 [57600/60000 (96%)]	Loss Char: 0.144080 Loss Font: 1.301559
#
# Test set: Accuracy Char : 9054/10000 (90.54%)
#           Accuracy Font : 3788/10000 (37.88%)
# (initial phase)
# Train Epoch: 8 [0/60000 (0%)]	Loss Char: 0.266888 Loss Font: 1.267742
# Train Epoch: 8 [6400/60000 (11%)]	Loss Char: 0.266663 Loss Font: 1.279194
# Train Epoch: 8 [12800/60000 (21%)]	Loss Char: 0.107764 Loss Font: 1.410281
# Train Epoch: 8 [19200/60000 (32%)]	Loss Char: 0.062947 Loss Font: 1.410076
# Train Epoch: 8 [25600/60000 (43%)]	Loss Char: 0.184841 Loss Font: 1.401432
# Train Epoch: 8 [32000/60000 (53%)]	Loss Char: 0.248879 Loss Font: 1.418651
# Train Epoch: 8 [38400/60000 (64%)]	Loss Char: 0.263521 Loss Font: 1.395258
# Train Epoch: 8 [44800/60000 (75%)]	Loss Char: 0.331028 Loss Font: 1.372722
# Train Epoch: 8 [51200/60000 (85%)]	Loss Char: 0.193999 Loss Font: 1.316621
# Train Epoch: 8 [57600/60000 (96%)]	Loss Char: 0.347703 Loss Font: 1.397890
#
# Test set: Accuracy Char : 9125/10000 (91.25%)
#           Accuracy Font : 3844/10000 (38.44%)
# (initial phase)
# Train Epoch: 9 [0/60000 (0%)]	Loss Char: 0.233935 Loss Font: 1.323599
# Train Epoch: 9 [6400/60000 (11%)]	Loss Char: 0.094830 Loss Font: 1.305113
# Train Epoch: 9 [12800/60000 (21%)]	Loss Char: 0.131809 Loss Font: 1.285592
# Train Epoch: 9 [19200/60000 (32%)]	Loss Char: 0.299382 Loss Font: 1.376420
# Train Epoch: 9 [25600/60000 (43%)]	Loss Char: 0.218124 Loss Font: 1.407190
# Train Epoch: 9 [32000/60000 (53%)]	Loss Char: 0.508665 Loss Font: 1.498717
# Train Epoch: 9 [38400/60000 (64%)]	Loss Char: 0.184355 Loss Font: 1.423950
# Train Epoch: 9 [44800/60000 (75%)]	Loss Char: 0.159247 Loss Font: 1.381975
# Train Epoch: 9 [51200/60000 (85%)]	Loss Char: 0.310555 Loss Font: 1.352751
# Train Epoch: 9 [57600/60000 (96%)]	Loss Char: 0.112406 Loss Font: 1.227715
#
# Test set: Accuracy Char : 9284/10000 (92.84%)
#           Accuracy Font : 3906/10000 (39.06%)
# (initial phase)
# Train Epoch: 10 [0/60000 (0%)]	Loss Char: 0.166191 Loss Font: 1.441306
# Train Epoch: 10 [6400/60000 (11%)]	Loss Char: 0.356349 Loss Font: 1.350080
# Train Epoch: 10 [12800/60000 (21%)]	Loss Char: 0.178570 Loss Font: 1.328286
# Train Epoch: 10 [19200/60000 (32%)]	Loss Char: 0.186070 Loss Font: 1.484167
# Train Epoch: 10 [25600/60000 (43%)]	Loss Char: 0.195577 Loss Font: 1.469617
# Train Epoch: 10 [32000/60000 (53%)]	Loss Char: 0.145385 Loss Font: 1.345128
# Train Epoch: 10 [38400/60000 (64%)]	Loss Char: 0.117435 Loss Font: 1.306534
# Train Epoch: 10 [44800/60000 (75%)]	Loss Char: 0.142440 Loss Font: 1.466446
# Train Epoch: 10 [51200/60000 (85%)]	Loss Char: 0.235981 Loss Font: 1.445580
# Train Epoch: 10 [57600/60000 (96%)]	Loss Char: 0.174490 Loss Font: 1.521461
#
# Test set: Accuracy Char : 9294/10000 (92.94%)
#           Accuracy Font : 3947/10000 (39.47%)
# (perturbate)
# Train Epoch: 11 [0/60000 (0%)]	Loss Char: 0.186847 Loss Font: 1.429575
# Train Epoch: 11 [6400/60000 (11%)]	Loss Char: 0.096837 Loss Font: 1.364297
# Train Epoch: 11 [12800/60000 (21%)]	Loss Char: 0.088227 Loss Font: 1.481300
# Train Epoch: 11 [19200/60000 (32%)]	Loss Char: 0.195887 Loss Font: 1.197696
# Train Epoch: 11 [25600/60000 (43%)]	Loss Char: 0.176588 Loss Font: 1.434108
# Train Epoch: 11 [32000/60000 (53%)]	Loss Char: 0.204951 Loss Font: 1.335171
# Train Epoch: 11 [38400/60000 (64%)]	Loss Char: 0.099443 Loss Font: 1.244669
# Train Epoch: 11 [44800/60000 (75%)]	Loss Char: 0.071223 Loss Font: 1.333809
# Train Epoch: 11 [51200/60000 (85%)]	Loss Char: 0.111809 Loss Font: 1.348273
# Train Epoch: 11 [57600/60000 (96%)]	Loss Char: 0.093707 Loss Font: 1.276393
#
# Test set: Accuracy Char : 9394/10000 (93.94%)
#           Accuracy Font : 3999/10000 (39.99%)
# (perturbate)
# Train Epoch: 12 [0/60000 (0%)]	Loss Char: 0.184348 Loss Font: 1.424974
# Train Epoch: 12 [6400/60000 (11%)]	Loss Char: 0.040987 Loss Font: 1.416219
# Train Epoch: 12 [12800/60000 (21%)]	Loss Char: 0.100257 Loss Font: 1.305169
# Train Epoch: 12 [19200/60000 (32%)]	Loss Char: 0.277983 Loss Font: 1.463555
# Train Epoch: 12 [25600/60000 (43%)]	Loss Char: 0.130743 Loss Font: 1.360704
# Train Epoch: 12 [32000/60000 (53%)]	Loss Char: 0.091565 Loss Font: 1.307480
# Train Epoch: 12 [38400/60000 (64%)]	Loss Char: 0.079838 Loss Font: 1.328341
# Train Epoch: 12 [44800/60000 (75%)]	Loss Char: 0.210824 Loss Font: 1.277629
# Train Epoch: 12 [51200/60000 (85%)]	Loss Char: 0.074347 Loss Font: 1.258268
# Train Epoch: 12 [57600/60000 (96%)]	Loss Char: 0.223195 Loss Font: 1.343244
#
# Test set: Accuracy Char : 9387/10000 (93.87%)
#           Accuracy Font : 3959/10000 (39.59%)
# (perturbate)
# Train Epoch: 13 [0/60000 (0%)]	Loss Char: 0.265273 Loss Font: 1.362892
# Train Epoch: 13 [6400/60000 (11%)]	Loss Char: 0.131870 Loss Font: 1.297955
# Train Epoch: 13 [12800/60000 (21%)]	Loss Char: 0.112925 Loss Font: 1.319891
# Train Epoch: 13 [19200/60000 (32%)]	Loss Char: 0.119058 Loss Font: 1.261672
# Train Epoch: 13 [25600/60000 (43%)]	Loss Char: 0.101271 Loss Font: 1.270611
# Train Epoch: 13 [32000/60000 (53%)]	Loss Char: 0.117050 Loss Font: 1.338935
# Train Epoch: 13 [38400/60000 (64%)]	Loss Char: 0.154978 Loss Font: 1.279290
# Train Epoch: 13 [44800/60000 (75%)]	Loss Char: 0.043803 Loss Font: 1.345440
# Train Epoch: 13 [51200/60000 (85%)]	Loss Char: 0.083608 Loss Font: 1.249005
# Train Epoch: 13 [57600/60000 (96%)]	Loss Char: 0.165491 Loss Font: 1.339643
#
# Test set: Accuracy Char : 9374/10000 (93.74%)
#           Accuracy Font : 4052/10000 (40.52%)
# (perturbate)
# Train Epoch: 14 [0/60000 (0%)]	Loss Char: 0.203570 Loss Font: 1.147611
# Train Epoch: 14 [6400/60000 (11%)]	Loss Char: 0.071579 Loss Font: 1.297546
# Train Epoch: 14 [12800/60000 (21%)]	Loss Char: 0.093320 Loss Font: 1.262919
# Train Epoch: 14 [19200/60000 (32%)]	Loss Char: 0.169741 Loss Font: 1.254969
# Train Epoch: 14 [25600/60000 (43%)]	Loss Char: 0.095032 Loss Font: 1.152583
# Train Epoch: 14 [32000/60000 (53%)]	Loss Char: 0.071462 Loss Font: 1.383709
# Train Epoch: 14 [38400/60000 (64%)]	Loss Char: 0.061954 Loss Font: 1.359987
# Train Epoch: 14 [44800/60000 (75%)]	Loss Char: 0.115983 Loss Font: 1.405904
# Train Epoch: 14 [51200/60000 (85%)]	Loss Char: 0.077607 Loss Font: 1.307689
# Train Epoch: 14 [57600/60000 (96%)]	Loss Char: 0.057830 Loss Font: 1.350356
#
# Test set: Accuracy Char : 9442/10000 (94.42%)
#           Accuracy Font : 4318/10000 (43.18%)
# (perturbate)
# Train Epoch: 15 [0/60000 (0%)]	Loss Char: 0.112366 Loss Font: 1.308219
# Train Epoch: 15 [6400/60000 (11%)]	Loss Char: 0.082148 Loss Font: 1.391894
# Train Epoch: 15 [12800/60000 (21%)]	Loss Char: 0.052789 Loss Font: 1.377117
# Train Epoch: 15 [19200/60000 (32%)]	Loss Char: 0.050751 Loss Font: 1.335704
# Train Epoch: 15 [25600/60000 (43%)]	Loss Char: 0.117943 Loss Font: 1.356040
# Train Epoch: 15 [32000/60000 (53%)]	Loss Char: 0.150826 Loss Font: 1.232334
# Train Epoch: 15 [38400/60000 (64%)]	Loss Char: 0.088582 Loss Font: 1.323829
# Train Epoch: 15 [44800/60000 (75%)]	Loss Char: 0.121134 Loss Font: 1.181959
# Train Epoch: 15 [51200/60000 (85%)]	Loss Char: 0.124326 Loss Font: 1.220922
# Train Epoch: 15 [57600/60000 (96%)]	Loss Char: 0.049541 Loss Font: 1.324879
#
# Test set: Accuracy Char : 9348/10000 (93.48%)
#           Accuracy Font : 4282/10000 (42.82%)
# (perturbate)
# Train Epoch: 16 [0/60000 (0%)]	Loss Char: 0.080198 Loss Font: 1.345965
# Train Epoch: 16 [6400/60000 (11%)]	Loss Char: 0.251241 Loss Font: 1.377197
# Train Epoch: 16 [12800/60000 (21%)]	Loss Char: 0.060116 Loss Font: 1.298360
# Train Epoch: 16 [19200/60000 (32%)]	Loss Char: 0.085119 Loss Font: 1.217313
# Train Epoch: 16 [25600/60000 (43%)]	Loss Char: 0.113696 Loss Font: 1.434972
# Train Epoch: 16 [32000/60000 (53%)]	Loss Char: 0.060365 Loss Font: 1.360799
# Train Epoch: 16 [38400/60000 (64%)]	Loss Char: 0.079498 Loss Font: 1.348348
# Train Epoch: 16 [44800/60000 (75%)]	Loss Char: 0.047512 Loss Font: 1.271554
# Train Epoch: 16 [51200/60000 (85%)]	Loss Char: 0.139543 Loss Font: 1.297491
# Train Epoch: 16 [57600/60000 (96%)]	Loss Char: 0.118753 Loss Font: 1.529499
#
# Test set: Accuracy Char : 9451/10000 (94.51%)
#           Accuracy Font : 4448/10000 (44.48%)
# (perturbate)
# Train Epoch: 17 [0/60000 (0%)]	Loss Char: 0.036992 Loss Font: 1.139412
# Train Epoch: 17 [6400/60000 (11%)]	Loss Char: 0.019112 Loss Font: 1.194142
# Train Epoch: 17 [12800/60000 (21%)]	Loss Char: 0.127660 Loss Font: 1.232727
# Train Epoch: 17 [19200/60000 (32%)]	Loss Char: 0.087775 Loss Font: 1.251731
# Train Epoch: 17 [25600/60000 (43%)]	Loss Char: 0.104160 Loss Font: 1.216497
# Train Epoch: 17 [32000/60000 (53%)]	Loss Char: 0.057590 Loss Font: 1.277063
# Train Epoch: 17 [38400/60000 (64%)]	Loss Char: 0.241435 Loss Font: 1.324522
# Train Epoch: 17 [44800/60000 (75%)]	Loss Char: 0.035169 Loss Font: 1.244483
# Train Epoch: 17 [51200/60000 (85%)]	Loss Char: 0.111692 Loss Font: 1.231672
# Train Epoch: 17 [57600/60000 (96%)]	Loss Char: 0.119012 Loss Font: 1.254806
#
# Test set: Accuracy Char : 9385/10000 (93.85%)
#           Accuracy Font : 4200/10000 (42.00%)
# (perturbate)
# Train Epoch: 18 [0/60000 (0%)]	Loss Char: 0.091152 Loss Font: 1.368362
# Train Epoch: 18 [6400/60000 (11%)]	Loss Char: 0.142742 Loss Font: 1.268412
# Train Epoch: 18 [12800/60000 (21%)]	Loss Char: 0.060712 Loss Font: 1.204738
# Train Epoch: 18 [19200/60000 (32%)]	Loss Char: 0.111908 Loss Font: 1.308515
# Train Epoch: 18 [25600/60000 (43%)]	Loss Char: 0.068838 Loss Font: 1.163497
# Train Epoch: 18 [32000/60000 (53%)]	Loss Char: 0.109789 Loss Font: 1.160635
# Train Epoch: 18 [38400/60000 (64%)]	Loss Char: 0.051919 Loss Font: 1.179732
# Train Epoch: 18 [44800/60000 (75%)]	Loss Char: 0.050999 Loss Font: 1.194684
# Train Epoch: 18 [51200/60000 (85%)]	Loss Char: 0.045960 Loss Font: 1.290882
# Train Epoch: 18 [57600/60000 (96%)]	Loss Char: 0.200560 Loss Font: 1.241708
#
# Test set: Accuracy Char : 9474/10000 (94.74%)
#           Accuracy Font : 4349/10000 (43.49%)
# (perturbate)
# Train Epoch: 19 [0/60000 (0%)]	Loss Char: 0.032644 Loss Font: 1.384432
# Train Epoch: 19 [6400/60000 (11%)]	Loss Char: 0.182373 Loss Font: 1.174980
# Train Epoch: 19 [12800/60000 (21%)]	Loss Char: 0.140265 Loss Font: 1.196274
# Train Epoch: 19 [19200/60000 (32%)]	Loss Char: 0.108164 Loss Font: 1.307403
# Train Epoch: 19 [25600/60000 (43%)]	Loss Char: 0.059562 Loss Font: 1.165263
# Train Epoch: 19 [32000/60000 (53%)]	Loss Char: 0.139047 Loss Font: 1.363173
# Train Epoch: 19 [38400/60000 (64%)]	Loss Char: 0.277763 Loss Font: 1.199728
# Train Epoch: 19 [44800/60000 (75%)]	Loss Char: 0.047848 Loss Font: 1.320596
# Train Epoch: 19 [51200/60000 (85%)]	Loss Char: 0.075893 Loss Font: 1.370599
# Train Epoch: 19 [57600/60000 (96%)]	Loss Char: 0.056994 Loss Font: 1.204677
#
# Test set: Accuracy Char : 9441/10000 (94.41%)
#           Accuracy Font : 4322/10000 (43.22%)
# (perturbate)
# Train Epoch: 20 [0/60000 (0%)]	Loss Char: 0.033627 Loss Font: 1.210887
# Train Epoch: 20 [6400/60000 (11%)]	Loss Char: 0.059127 Loss Font: 1.344574
# Train Epoch: 20 [12800/60000 (21%)]	Loss Char: 0.096955 Loss Font: 1.362745
# Train Epoch: 20 [19200/60000 (32%)]	Loss Char: 0.038264 Loss Font: 1.163785
# Train Epoch: 20 [25600/60000 (43%)]	Loss Char: 0.074458 Loss Font: 1.254259
# Train Epoch: 20 [32000/60000 (53%)]	Loss Char: 0.057496 Loss Font: 1.258646
# Train Epoch: 20 [38400/60000 (64%)]	Loss Char: 0.024605 Loss Font: 1.305933
# Train Epoch: 20 [44800/60000 (75%)]	Loss Char: 0.045617 Loss Font: 1.332320
# Train Epoch: 20 [51200/60000 (85%)]	Loss Char: 0.142277 Loss Font: 1.252406
# Train Epoch: 20 [57600/60000 (96%)]	Loss Char: 0.019476 Loss Font: 1.101295
#
# Test set: Accuracy Char : 9473/10000 (94.73%)
#           Accuracy Font : 4333/10000 (43.33%)
# Train Epoch: 21 [0/60000 (0%)]	Loss Char: 0.032359 Loss Font: 1.437826
# Train Epoch: 21 [6400/60000 (11%)]	Loss Char: 0.028821 Loss Font: 1.243466
# Train Epoch: 21 [12800/60000 (21%)]	Loss Char: 0.172874 Loss Font: 1.336825
# Train Epoch: 21 [19200/60000 (32%)]	Loss Char: 0.101949 Loss Font: 1.270777
# Train Epoch: 21 [25600/60000 (43%)]	Loss Char: 0.218505 Loss Font: 1.243243
# Train Epoch: 21 [32000/60000 (53%)]	Loss Char: 0.120109 Loss Font: 1.136882
# Train Epoch: 21 [38400/60000 (64%)]	Loss Char: 0.115469 Loss Font: 1.320721
# Train Epoch: 21 [44800/60000 (75%)]	Loss Char: 0.075811 Loss Font: 1.182901
# Train Epoch: 21 [51200/60000 (85%)]	Loss Char: 0.047384 Loss Font: 1.363292
# Train Epoch: 21 [57600/60000 (96%)]	Loss Char: 0.097387 Loss Font: 1.377520
#
# Test set: Accuracy Char : 9498/10000 (94.98%)
#           Accuracy Font : 4483/10000 (44.83%)
# Train Epoch: 22 [0/60000 (0%)]	Loss Char: 0.095015 Loss Font: 1.218071
# Train Epoch: 22 [6400/60000 (11%)]	Loss Char: 0.185130 Loss Font: 1.586932
# Train Epoch: 22 [12800/60000 (21%)]	Loss Char: 0.069230 Loss Font: 1.248641
# Train Epoch: 22 [19200/60000 (32%)]	Loss Char: 0.057923 Loss Font: 1.409234
# Train Epoch: 22 [25600/60000 (43%)]	Loss Char: 0.032391 Loss Font: 1.337302
# Train Epoch: 22 [32000/60000 (53%)]	Loss Char: 0.024228 Loss Font: 1.240304
# Train Epoch: 22 [38400/60000 (64%)]	Loss Char: 0.065553 Loss Font: 1.287797
# Train Epoch: 22 [44800/60000 (75%)]	Loss Char: 0.018068 Loss Font: 1.432199
# Train Epoch: 22 [51200/60000 (85%)]	Loss Char: 0.049672 Loss Font: 1.344606
# Train Epoch: 22 [57600/60000 (96%)]	Loss Char: 0.159946 Loss Font: 1.322706
#
# Test set: Accuracy Char : 9494/10000 (94.94%)
#           Accuracy Font : 4243/10000 (42.43%)
# Train Epoch: 23 [0/60000 (0%)]	Loss Char: 0.081551 Loss Font: 1.498835
# Train Epoch: 23 [6400/60000 (11%)]	Loss Char: 0.016167 Loss Font: 1.191409
# Train Epoch: 23 [12800/60000 (21%)]	Loss Char: 0.043950 Loss Font: 1.264972
# Train Epoch: 23 [19200/60000 (32%)]	Loss Char: 0.091140 Loss Font: 1.181207
# Train Epoch: 23 [25600/60000 (43%)]	Loss Char: 0.117472 Loss Font: 1.363857
# Train Epoch: 23 [32000/60000 (53%)]	Loss Char: 0.024588 Loss Font: 1.269749
# Train Epoch: 23 [38400/60000 (64%)]	Loss Char: 0.052946 Loss Font: 1.463278
# Train Epoch: 23 [44800/60000 (75%)]	Loss Char: 0.096870 Loss Font: 1.249594
# Train Epoch: 23 [51200/60000 (85%)]	Loss Char: 0.061922 Loss Font: 1.267807
# Train Epoch: 23 [57600/60000 (96%)]	Loss Char: 0.243907 Loss Font: 1.262238
#
# Test set: Accuracy Char : 9495/10000 (94.95%)
#           Accuracy Font : 4418/10000 (44.18%)
# Train Epoch: 24 [0/60000 (0%)]	Loss Char: 0.121155 Loss Font: 1.291298
# Train Epoch: 24 [6400/60000 (11%)]	Loss Char: 0.120630 Loss Font: 1.338860
# Train Epoch: 24 [12800/60000 (21%)]	Loss Char: 0.089553 Loss Font: 1.300246
# Train Epoch: 24 [19200/60000 (32%)]	Loss Char: 0.112145 Loss Font: 1.434678
# Train Epoch: 24 [25600/60000 (43%)]	Loss Char: 0.079940 Loss Font: 1.175697
# Train Epoch: 24 [32000/60000 (53%)]	Loss Char: 0.053714 Loss Font: 1.389877
# Train Epoch: 24 [38400/60000 (64%)]	Loss Char: 0.207894 Loss Font: 1.320690
# Train Epoch: 24 [44800/60000 (75%)]	Loss Char: 0.082914 Loss Font: 1.234240
# Train Epoch: 24 [51200/60000 (85%)]	Loss Char: 0.256195 Loss Font: 1.226047
# Train Epoch: 24 [57600/60000 (96%)]	Loss Char: 0.224170 Loss Font: 1.258280
#
# Test set: Accuracy Char : 9499/10000 (94.99%)
#           Accuracy Font : 4503/10000 (45.03%)
# Train Epoch: 25 [0/60000 (0%)]	Loss Char: 0.133548 Loss Font: 1.276015
# Train Epoch: 25 [6400/60000 (11%)]	Loss Char: 0.140867 Loss Font: 1.238078
# Train Epoch: 25 [12800/60000 (21%)]	Loss Char: 0.107416 Loss Font: 1.424540
# Train Epoch: 25 [19200/60000 (32%)]	Loss Char: 0.193408 Loss Font: 1.145646
# Train Epoch: 25 [25600/60000 (43%)]	Loss Char: 0.131188 Loss Font: 1.154651
# Train Epoch: 25 [32000/60000 (53%)]	Loss Char: 0.118119 Loss Font: 1.221822
# Train Epoch: 25 [38400/60000 (64%)]	Loss Char: 0.165340 Loss Font: 1.387555
# Train Epoch: 25 [44800/60000 (75%)]	Loss Char: 0.086297 Loss Font: 1.176707
# Train Epoch: 25 [51200/60000 (85%)]	Loss Char: 0.043982 Loss Font: 1.187334
# Train Epoch: 25 [57600/60000 (96%)]	Loss Char: 0.128550 Loss Font: 1.135053
#
# Test set: Accuracy Char : 9502/10000 (95.02%)
#           Accuracy Font : 4402/10000 (44.02%)
# Train Epoch: 26 [0/60000 (0%)]	Loss Char: 0.081723 Loss Font: 1.267168
# Train Epoch: 26 [6400/60000 (11%)]	Loss Char: 0.015183 Loss Font: 1.107166
# Train Epoch: 26 [12800/60000 (21%)]	Loss Char: 0.026739 Loss Font: 1.177269
# Train Epoch: 26 [19200/60000 (32%)]	Loss Char: 0.028864 Loss Font: 1.323778
# Train Epoch: 26 [25600/60000 (43%)]	Loss Char: 0.049483 Loss Font: 1.358365
# Train Epoch: 26 [32000/60000 (53%)]	Loss Char: 0.151425 Loss Font: 1.243167
# Train Epoch: 26 [38400/60000 (64%)]	Loss Char: 0.023184 Loss Font: 1.427849
# Train Epoch: 26 [44800/60000 (75%)]	Loss Char: 0.069176 Loss Font: 1.287842
# Train Epoch: 26 [51200/60000 (85%)]	Loss Char: 0.130274 Loss Font: 1.232163
# Train Epoch: 26 [57600/60000 (96%)]	Loss Char: 0.062575 Loss Font: 1.217157
#
# Test set: Accuracy Char : 9503/10000 (95.03%)
#           Accuracy Font : 4465/10000 (44.65%)
# Train Epoch: 27 [0/60000 (0%)]	Loss Char: 0.063005 Loss Font: 1.426573
# Train Epoch: 27 [6400/60000 (11%)]	Loss Char: 0.092969 Loss Font: 1.176563
# Train Epoch: 27 [12800/60000 (21%)]	Loss Char: 0.027636 Loss Font: 1.227878
# Train Epoch: 27 [19200/60000 (32%)]	Loss Char: 0.031250 Loss Font: 1.186672
# Train Epoch: 27 [25600/60000 (43%)]	Loss Char: 0.067420 Loss Font: 1.361025
# Train Epoch: 27 [32000/60000 (53%)]	Loss Char: 0.028374 Loss Font: 1.197609
# Train Epoch: 27 [38400/60000 (64%)]	Loss Char: 0.118026 Loss Font: 1.204769
# Train Epoch: 27 [44800/60000 (75%)]	Loss Char: 0.088300 Loss Font: 1.236017
# Train Epoch: 27 [51200/60000 (85%)]	Loss Char: 0.075588 Loss Font: 1.514887
# Train Epoch: 27 [57600/60000 (96%)]	Loss Char: 0.097662 Loss Font: 1.403536
#
# Test set: Accuracy Char : 9511/10000 (95.11%)
#           Accuracy Font : 4476/10000 (44.76%)
# Train Epoch: 28 [0/60000 (0%)]	Loss Char: 0.111278 Loss Font: 1.228401
# Train Epoch: 28 [6400/60000 (11%)]	Loss Char: 0.131770 Loss Font: 1.409438
# Train Epoch: 28 [12800/60000 (21%)]	Loss Char: 0.265930 Loss Font: 1.281253
# Train Epoch: 28 [19200/60000 (32%)]	Loss Char: 0.123879 Loss Font: 1.237533
# Train Epoch: 28 [25600/60000 (43%)]	Loss Char: 0.037570 Loss Font: 1.335649
# Train Epoch: 28 [32000/60000 (53%)]	Loss Char: 0.080825 Loss Font: 1.247285
# Train Epoch: 28 [38400/60000 (64%)]	Loss Char: 0.016104 Loss Font: 1.316478
# Train Epoch: 28 [44800/60000 (75%)]	Loss Char: 0.084198 Loss Font: 1.230349
# Train Epoch: 28 [51200/60000 (85%)]	Loss Char: 0.155262 Loss Font: 1.420359
# Train Epoch: 28 [57600/60000 (96%)]	Loss Char: 0.076804 Loss Font: 1.190529
#
# Test set: Accuracy Char : 9489/10000 (94.89%)
#           Accuracy Font : 4399/10000 (43.99%)
# Train Epoch: 29 [0/60000 (0%)]	Loss Char: 0.077620 Loss Font: 1.225158
# Train Epoch: 29 [6400/60000 (11%)]	Loss Char: 0.060216 Loss Font: 1.243866
# Train Epoch: 29 [12800/60000 (21%)]	Loss Char: 0.033099 Loss Font: 1.425451
# Train Epoch: 29 [19200/60000 (32%)]	Loss Char: 0.158422 Loss Font: 1.452407
# Train Epoch: 29 [25600/60000 (43%)]	Loss Char: 0.085295 Loss Font: 1.191388
# Train Epoch: 29 [32000/60000 (53%)]	Loss Char: 0.060958 Loss Font: 1.384165
# Train Epoch: 29 [38400/60000 (64%)]	Loss Char: 0.113467 Loss Font: 1.262483
# Train Epoch: 29 [44800/60000 (75%)]	Loss Char: 0.067703 Loss Font: 1.270942
# Train Epoch: 29 [51200/60000 (85%)]	Loss Char: 0.098648 Loss Font: 1.322237
# Train Epoch: 29 [57600/60000 (96%)]	Loss Char: 0.129067 Loss Font: 1.480115
#
# Test set: Accuracy Char : 9493/10000 (94.93%)
#           Accuracy Font : 4472/10000 (44.72%)
# Train Epoch: 30 [0/60000 (0%)]	Loss Char: 0.117864 Loss Font: 1.300349
# Train Epoch: 30 [6400/60000 (11%)]	Loss Char: 0.062966 Loss Font: 1.292098
# Train Epoch: 30 [12800/60000 (21%)]	Loss Char: 0.184147 Loss Font: 1.157818
# Train Epoch: 30 [19200/60000 (32%)]	Loss Char: 0.085521 Loss Font: 1.283452
# Train Epoch: 30 [25600/60000 (43%)]	Loss Char: 0.034567 Loss Font: 1.163255
# Train Epoch: 30 [32000/60000 (53%)]	Loss Char: 0.038528 Loss Font: 1.311681
# Train Epoch: 30 [38400/60000 (64%)]	Loss Char: 0.055842 Loss Font: 1.383152
# Train Epoch: 30 [44800/60000 (75%)]	Loss Char: 0.088089 Loss Font: 1.277948
# Train Epoch: 30 [51200/60000 (85%)]	Loss Char: 0.120493 Loss Font: 1.209706
# Train Epoch: 30 [57600/60000 (96%)]	Loss Char: 0.302401 Loss Font: 1.498148
#
# Test set: Accuracy Char : 9508/10000 (95.08%)
#           Accuracy Font : 4333/10000 (43.33%)

# %%
alphas = [0.05, 0.1, 0.2, 0.5, 1, 1.5, 2]
for alpha in alphas:
    test_perfs_char_perturbate, test_perfs_font_perturbate, model_perturbate = main(alpha=alpha)
    results[f"Main task with perturbation alpha={alpha}"] = test_perfs_char_perturbate
    results[f"Collateral task with perturbation alpha={alpha}"] = test_perfs_font_perturbate
# Out:
# Training set 60000 items
# Testing set  10000 items
# (initial phase)
# Train Epoch: 1 [0/60000 (0%)]	Loss Char: 3.241490 Loss Font: 1.619655
# Train Epoch: 1 [6400/60000 (11%)]	Loss Char: 3.243401 Loss Font: 1.634818
# Train Epoch: 1 [12800/60000 (21%)]	Loss Char: 3.125095 Loss Font: 1.670732
# Train Epoch: 1 [19200/60000 (32%)]	Loss Char: 2.984154 Loss Font: 1.708088
# Train Epoch: 1 [25600/60000 (43%)]	Loss Char: 2.888399 Loss Font: 1.640867
# Train Epoch: 1 [32000/60000 (53%)]	Loss Char: 2.595878 Loss Font: 1.645604
# Train Epoch: 1 [38400/60000 (64%)]	Loss Char: 2.191660 Loss Font: 1.634457
# Train Epoch: 1 [44800/60000 (75%)]	Loss Char: 1.920311 Loss Font: 1.644273
# Train Epoch: 1 [51200/60000 (85%)]	Loss Char: 1.738962 Loss Font: 1.688137
# Train Epoch: 1 [57600/60000 (96%)]	Loss Char: 1.865170 Loss Font: 1.599646
#
# Test set: Accuracy Char : 4957/10000 (49.57%)
#           Accuracy Font : 2659/10000 (26.59%)
# (initial phase)
# Train Epoch: 2 [0/60000 (0%)]	Loss Char: 1.318387 Loss Font: 1.608933
# Train Epoch: 2 [6400/60000 (11%)]	Loss Char: 1.550118 Loss Font: 1.520178
# Train Epoch: 2 [12800/60000 (21%)]	Loss Char: 1.160004 Loss Font: 1.508529
# Train Epoch: 2 [19200/60000 (32%)]	Loss Char: 1.097548 Loss Font: 1.513336
# Train Epoch: 2 [25600/60000 (43%)]	Loss Char: 1.117916 Loss Font: 1.522316
# Train Epoch: 2 [32000/60000 (53%)]	Loss Char: 0.818825 Loss Font: 1.561099
# Train Epoch: 2 [38400/60000 (64%)]	Loss Char: 0.771766 Loss Font: 1.542226
# Train Epoch: 2 [44800/60000 (75%)]	Loss Char: 1.050970 Loss Font: 1.455329
# Train Epoch: 2 [51200/60000 (85%)]	Loss Char: 0.822885 Loss Font: 1.556443
# Train Epoch: 2 [57600/60000 (96%)]	Loss Char: 1.063315 Loss Font: 1.586820
#
# Test set: Accuracy Char : 7465/10000 (74.65%)
#           Accuracy Font : 3104/10000 (31.04%)
# (initial phase)
# Train Epoch: 3 [0/60000 (0%)]	Loss Char: 0.846573 Loss Font: 1.514468
# Train Epoch: 3 [6400/60000 (11%)]	Loss Char: 0.830905 Loss Font: 1.440030
# Train Epoch: 3 [12800/60000 (21%)]	Loss Char: 0.838321 Loss Font: 1.605255
# Train Epoch: 3 [19200/60000 (32%)]	Loss Char: 0.746728 Loss Font: 1.463067
# Train Epoch: 3 [25600/60000 (43%)]	Loss Char: 0.769849 Loss Font: 1.550862
# Train Epoch: 3 [32000/60000 (53%)]	Loss Char: 0.517730 Loss Font: 1.450067
# Train Epoch: 3 [38400/60000 (64%)]	Loss Char: 0.601043 Loss Font: 1.477565
# Train Epoch: 3 [44800/60000 (75%)]	Loss Char: 0.542821 Loss Font: 1.628974
# Train Epoch: 3 [51200/60000 (85%)]	Loss Char: 0.596551 Loss Font: 1.468087
# Train Epoch: 3 [57600/60000 (96%)]	Loss Char: 0.743588 Loss Font: 1.523732
#
# Test set: Accuracy Char : 8261/10000 (82.61%)
#           Accuracy Font : 3257/10000 (32.57%)
# (initial phase)
# Train Epoch: 4 [0/60000 (0%)]	Loss Char: 0.549530 Loss Font: 1.450864
# Train Epoch: 4 [6400/60000 (11%)]	Loss Char: 0.383065 Loss Font: 1.469275
# Train Epoch: 4 [12800/60000 (21%)]	Loss Char: 0.436886 Loss Font: 1.455344
# Train Epoch: 4 [19200/60000 (32%)]	Loss Char: 0.598079 Loss Font: 1.564009
# Train Epoch: 4 [25600/60000 (43%)]	Loss Char: 0.318404 Loss Font: 1.417232
# Train Epoch: 4 [32000/60000 (53%)]	Loss Char: 0.465218 Loss Font: 1.481279
# Train Epoch: 4 [38400/60000 (64%)]	Loss Char: 0.416448 Loss Font: 1.493089
# Train Epoch: 4 [44800/60000 (75%)]	Loss Char: 0.476082 Loss Font: 1.460058
# Train Epoch: 4 [51200/60000 (85%)]	Loss Char: 0.561793 Loss Font: 1.416564
# Train Epoch: 4 [57600/60000 (96%)]	Loss Char: 0.383984 Loss Font: 1.525175
#
# Test set: Accuracy Char : 8492/10000 (84.92%)
#           Accuracy Font : 3349/10000 (33.49%)
# (initial phase)
# Train Epoch: 5 [0/60000 (0%)]	Loss Char: 0.465208 Loss Font: 1.441594
# Train Epoch: 5 [6400/60000 (11%)]	Loss Char: 0.482403 Loss Font: 1.375755
# Train Epoch: 5 [12800/60000 (21%)]	Loss Char: 0.405939 Loss Font: 1.326863
# Train Epoch: 5 [19200/60000 (32%)]	Loss Char: 0.362571 Loss Font: 1.499023
# Train Epoch: 5 [25600/60000 (43%)]	Loss Char: 0.332217 Loss Font: 1.405209
# Train Epoch: 5 [32000/60000 (53%)]	Loss Char: 0.303684 Loss Font: 1.413099
# Train Epoch: 5 [38400/60000 (64%)]	Loss Char: 0.489397 Loss Font: 1.481379
# Train Epoch: 5 [44800/60000 (75%)]	Loss Char: 0.263597 Loss Font: 1.312635
# Train Epoch: 5 [51200/60000 (85%)]	Loss Char: 0.546229 Loss Font: 1.443149
# Train Epoch: 5 [57600/60000 (96%)]	Loss Char: 0.264077 Loss Font: 1.464120
#
# Test set: Accuracy Char : 8951/10000 (89.51%)
#           Accuracy Font : 3599/10000 (35.99%)
# (initial phase)
# Train Epoch: 6 [0/60000 (0%)]	Loss Char: 0.235854 Loss Font: 1.509135
# Train Epoch: 6 [6400/60000 (11%)]	Loss Char: 0.449579 Loss Font: 1.517862
# Train Epoch: 6 [12800/60000 (21%)]	Loss Char: 0.241981 Loss Font: 1.432219
# Train Epoch: 6 [19200/60000 (32%)]	Loss Char: 0.586458 Loss Font: 1.423619
# Train Epoch: 6 [25600/60000 (43%)]	Loss Char: 0.439160 Loss Font: 1.557969
# Train Epoch: 6 [32000/60000 (53%)]	Loss Char: 0.378124 Loss Font: 1.526518
# Train Epoch: 6 [38400/60000 (64%)]	Loss Char: 0.249369 Loss Font: 1.578080
# Train Epoch: 6 [44800/60000 (75%)]	Loss Char: 0.254407 Loss Font: 1.413932
# Train Epoch: 6 [51200/60000 (85%)]	Loss Char: 0.202057 Loss Font: 1.415316
# Train Epoch: 6 [57600/60000 (96%)]	Loss Char: 0.332146 Loss Font: 1.304578
#
# Test set: Accuracy Char : 9034/10000 (90.34%)
#           Accuracy Font : 3692/10000 (36.92%)
# (initial phase)
# Train Epoch: 7 [0/60000 (0%)]	Loss Char: 0.211176 Loss Font: 1.406888
# Train Epoch: 7 [6400/60000 (11%)]	Loss Char: 0.303036 Loss Font: 1.432919
# Train Epoch: 7 [12800/60000 (21%)]	Loss Char: 0.273678 Loss Font: 1.490821
# Train Epoch: 7 [19200/60000 (32%)]	Loss Char: 0.378296 Loss Font: 1.296944
# Train Epoch: 7 [25600/60000 (43%)]	Loss Char: 0.434525 Loss Font: 1.333350
# Train Epoch: 7 [32000/60000 (53%)]	Loss Char: 0.345688 Loss Font: 1.412492
# Train Epoch: 7 [38400/60000 (64%)]	Loss Char: 0.466365 Loss Font: 1.438078
# Train Epoch: 7 [44800/60000 (75%)]	Loss Char: 0.234117 Loss Font: 1.409068
# Train Epoch: 7 [51200/60000 (85%)]	Loss Char: 0.335284 Loss Font: 1.357813
# Train Epoch: 7 [57600/60000 (96%)]	Loss Char: 0.144080 Loss Font: 1.301559
#
# Test set: Accuracy Char : 9054/10000 (90.54%)
#           Accuracy Font : 3788/10000 (37.88%)
# (initial phase)
# Train Epoch: 8 [0/60000 (0%)]	Loss Char: 0.266888 Loss Font: 1.267742
# Train Epoch: 8 [6400/60000 (11%)]	Loss Char: 0.266663 Loss Font: 1.279194
# Train Epoch: 8 [12800/60000 (21%)]	Loss Char: 0.107764 Loss Font: 1.410281
# Train Epoch: 8 [19200/60000 (32%)]	Loss Char: 0.062947 Loss Font: 1.410076
# Train Epoch: 8 [25600/60000 (43%)]	Loss Char: 0.184841 Loss Font: 1.401432
# Train Epoch: 8 [32000/60000 (53%)]	Loss Char: 0.248879 Loss Font: 1.418651
# Train Epoch: 8 [38400/60000 (64%)]	Loss Char: 0.263521 Loss Font: 1.395258
# Train Epoch: 8 [44800/60000 (75%)]	Loss Char: 0.331028 Loss Font: 1.372722
# Train Epoch: 8 [51200/60000 (85%)]	Loss Char: 0.193999 Loss Font: 1.316621
# Train Epoch: 8 [57600/60000 (96%)]	Loss Char: 0.347703 Loss Font: 1.397890
#
# Test set: Accuracy Char : 9125/10000 (91.25%)
#           Accuracy Font : 3844/10000 (38.44%)
# (initial phase)
# Train Epoch: 9 [0/60000 (0%)]	Loss Char: 0.233935 Loss Font: 1.323599
# Train Epoch: 9 [6400/60000 (11%)]	Loss Char: 0.094830 Loss Font: 1.305113
# Train Epoch: 9 [12800/60000 (21%)]	Loss Char: 0.131809 Loss Font: 1.285592
# Train Epoch: 9 [19200/60000 (32%)]	Loss Char: 0.299382 Loss Font: 1.376420
# Train Epoch: 9 [25600/60000 (43%)]	Loss Char: 0.218124 Loss Font: 1.407190
# Train Epoch: 9 [32000/60000 (53%)]	Loss Char: 0.508665 Loss Font: 1.498717
# Train Epoch: 9 [38400/60000 (64%)]	Loss Char: 0.184355 Loss Font: 1.423950
# Train Epoch: 9 [44800/60000 (75%)]	Loss Char: 0.159247 Loss Font: 1.381975
# Train Epoch: 9 [51200/60000 (85%)]	Loss Char: 0.310555 Loss Font: 1.352751
# Train Epoch: 9 [57600/60000 (96%)]	Loss Char: 0.112406 Loss Font: 1.227715
#
# Test set: Accuracy Char : 9284/10000 (92.84%)
#           Accuracy Font : 3906/10000 (39.06%)
# (initial phase)
# Train Epoch: 10 [0/60000 (0%)]	Loss Char: 0.166191 Loss Font: 1.441306
# Train Epoch: 10 [6400/60000 (11%)]	Loss Char: 0.356349 Loss Font: 1.350080
# Train Epoch: 10 [12800/60000 (21%)]	Loss Char: 0.178570 Loss Font: 1.328286
# Train Epoch: 10 [19200/60000 (32%)]	Loss Char: 0.186070 Loss Font: 1.484167
# Train Epoch: 10 [25600/60000 (43%)]	Loss Char: 0.195577 Loss Font: 1.469617
# Train Epoch: 10 [32000/60000 (53%)]	Loss Char: 0.145385 Loss Font: 1.345128
# Train Epoch: 10 [38400/60000 (64%)]	Loss Char: 0.117435 Loss Font: 1.306534
# Train Epoch: 10 [44800/60000 (75%)]	Loss Char: 0.142440 Loss Font: 1.466446
# Train Epoch: 10 [51200/60000 (85%)]	Loss Char: 0.235981 Loss Font: 1.445580
# Train Epoch: 10 [57600/60000 (96%)]	Loss Char: 0.174490 Loss Font: 1.521461
#
# Test set: Accuracy Char : 9294/10000 (92.94%)
#           Accuracy Font : 3947/10000 (39.47%)
# (perturbate)
# Train Epoch: 11 [0/60000 (0%)]	Loss Char: 0.186847 Loss Font: 1.429575
# Train Epoch: 11 [6400/60000 (11%)]	Loss Char: 0.096967 Loss Font: 1.366989
# Train Epoch: 11 [12800/60000 (21%)]	Loss Char: 0.088430 Loss Font: 1.485423
# Train Epoch: 11 [19200/60000 (32%)]	Loss Char: 0.195931 Loss Font: 1.203422
# Train Epoch: 11 [25600/60000 (43%)]	Loss Char: 0.175513 Loss Font: 1.440112
# Train Epoch: 11 [32000/60000 (53%)]	Loss Char: 0.204216 Loss Font: 1.339566
# Train Epoch: 11 [38400/60000 (64%)]	Loss Char: 0.101733 Loss Font: 1.252529
# Train Epoch: 11 [44800/60000 (75%)]	Loss Char: 0.073976 Loss Font: 1.344758
# Train Epoch: 11 [51200/60000 (85%)]	Loss Char: 0.112567 Loss Font: 1.359632
# Train Epoch: 11 [57600/60000 (96%)]	Loss Char: 0.091900 Loss Font: 1.287913
#
# Test set: Accuracy Char : 9401/10000 (94.01%)
#           Accuracy Font : 3945/10000 (39.45%)
# (perturbate)
# Train Epoch: 12 [0/60000 (0%)]	Loss Char: 0.187645 Loss Font: 1.438849
# Train Epoch: 12 [6400/60000 (11%)]	Loss Char: 0.042137 Loss Font: 1.427433
# Train Epoch: 12 [12800/60000 (21%)]	Loss Char: 0.100665 Loss Font: 1.316992
# Train Epoch: 12 [19200/60000 (32%)]	Loss Char: 0.275485 Loss Font: 1.485109
# Train Epoch: 12 [25600/60000 (43%)]	Loss Char: 0.130443 Loss Font: 1.382770
# Train Epoch: 12 [32000/60000 (53%)]	Loss Char: 0.095640 Loss Font: 1.327620
# Train Epoch: 12 [38400/60000 (64%)]	Loss Char: 0.078333 Loss Font: 1.343120
# Train Epoch: 12 [44800/60000 (75%)]	Loss Char: 0.215817 Loss Font: 1.301590
# Train Epoch: 12 [51200/60000 (85%)]	Loss Char: 0.077893 Loss Font: 1.280136
# Train Epoch: 12 [57600/60000 (96%)]	Loss Char: 0.222225 Loss Font: 1.362492
#
# Test set: Accuracy Char : 9387/10000 (93.87%)
#           Accuracy Font : 3842/10000 (38.42%)
# (perturbate)
# Train Epoch: 13 [0/60000 (0%)]	Loss Char: 0.270595 Loss Font: 1.382643
# Train Epoch: 13 [6400/60000 (11%)]	Loss Char: 0.138935 Loss Font: 1.319422
# Train Epoch: 13 [12800/60000 (21%)]	Loss Char: 0.114456 Loss Font: 1.331102
# Train Epoch: 13 [19200/60000 (32%)]	Loss Char: 0.123963 Loss Font: 1.284976
# Train Epoch: 13 [25600/60000 (43%)]	Loss Char: 0.103981 Loss Font: 1.292269
# Train Epoch: 13 [32000/60000 (53%)]	Loss Char: 0.118689 Loss Font: 1.354575
# Train Epoch: 13 [38400/60000 (64%)]	Loss Char: 0.146962 Loss Font: 1.297004
# Train Epoch: 13 [44800/60000 (75%)]	Loss Char: 0.043399 Loss Font: 1.364086
# Train Epoch: 13 [51200/60000 (85%)]	Loss Char: 0.083685 Loss Font: 1.272049
# Train Epoch: 13 [57600/60000 (96%)]	Loss Char: 0.175893 Loss Font: 1.355562
#
# Test set: Accuracy Char : 9370/10000 (93.70%)
#           Accuracy Font : 3968/10000 (39.68%)
# (perturbate)
# Train Epoch: 14 [0/60000 (0%)]	Loss Char: 0.202189 Loss Font: 1.177510
# Train Epoch: 14 [6400/60000 (11%)]	Loss Char: 0.076353 Loss Font: 1.330282
# Train Epoch: 14 [12800/60000 (21%)]	Loss Char: 0.099868 Loss Font: 1.299095
# Train Epoch: 14 [19200/60000 (32%)]	Loss Char: 0.170239 Loss Font: 1.265444
# Train Epoch: 14 [25600/60000 (43%)]	Loss Char: 0.092969 Loss Font: 1.179388
# Train Epoch: 14 [32000/60000 (53%)]	Loss Char: 0.075083 Loss Font: 1.406966
# Train Epoch: 14 [38400/60000 (64%)]	Loss Char: 0.066619 Loss Font: 1.382384
# Train Epoch: 14 [44800/60000 (75%)]	Loss Char: 0.113768 Loss Font: 1.429685
# Train Epoch: 14 [51200/60000 (85%)]	Loss Char: 0.078733 Loss Font: 1.334529
# Train Epoch: 14 [57600/60000 (96%)]	Loss Char: 0.062880 Loss Font: 1.379116
#
# Test set: Accuracy Char : 9443/10000 (94.43%)
#           Accuracy Font : 4217/10000 (42.17%)
# (perturbate)
# Train Epoch: 15 [0/60000 (0%)]	Loss Char: 0.109868 Loss Font: 1.330516
# Train Epoch: 15 [6400/60000 (11%)]	Loss Char: 0.086874 Loss Font: 1.417595
# Train Epoch: 15 [12800/60000 (21%)]	Loss Char: 0.056186 Loss Font: 1.403638
# Train Epoch: 15 [19200/60000 (32%)]	Loss Char: 0.050298 Loss Font: 1.353587
# Train Epoch: 15 [25600/60000 (43%)]	Loss Char: 0.110674 Loss Font: 1.399377
# Train Epoch: 15 [32000/60000 (53%)]	Loss Char: 0.165705 Loss Font: 1.267943
# Train Epoch: 15 [38400/60000 (64%)]	Loss Char: 0.086560 Loss Font: 1.364478
# Train Epoch: 15 [44800/60000 (75%)]	Loss Char: 0.117184 Loss Font: 1.217139
# Train Epoch: 15 [51200/60000 (85%)]	Loss Char: 0.125261 Loss Font: 1.250612
# Train Epoch: 15 [57600/60000 (96%)]	Loss Char: 0.051065 Loss Font: 1.368250
#
# Test set: Accuracy Char : 9334/10000 (93.34%)
#           Accuracy Font : 4129/10000 (41.29%)
# (perturbate)
# Train Epoch: 16 [0/60000 (0%)]	Loss Char: 0.082018 Loss Font: 1.391763
# Train Epoch: 16 [6400/60000 (11%)]	Loss Char: 0.239628 Loss Font: 1.430826
# Train Epoch: 16 [12800/60000 (21%)]	Loss Char: 0.060129 Loss Font: 1.343805
# Train Epoch: 16 [19200/60000 (32%)]	Loss Char: 0.087476 Loss Font: 1.242896
# Train Epoch: 16 [25600/60000 (43%)]	Loss Char: 0.118476 Loss Font: 1.451642
# Train Epoch: 16 [32000/60000 (53%)]	Loss Char: 0.066497 Loss Font: 1.372142
# Train Epoch: 16 [38400/60000 (64%)]	Loss Char: 0.089741 Loss Font: 1.365445
# Train Epoch: 16 [44800/60000 (75%)]	Loss Char: 0.045684 Loss Font: 1.304384
# Train Epoch: 16 [51200/60000 (85%)]	Loss Char: 0.140155 Loss Font: 1.322534
# Train Epoch: 16 [57600/60000 (96%)]	Loss Char: 0.123016 Loss Font: 1.528411
#
# Test set: Accuracy Char : 9461/10000 (94.61%)
#           Accuracy Font : 4205/10000 (42.05%)
# (perturbate)
# Train Epoch: 17 [0/60000 (0%)]	Loss Char: 0.035738 Loss Font: 1.168451
# Train Epoch: 17 [6400/60000 (11%)]	Loss Char: 0.020788 Loss Font: 1.250776
# Train Epoch: 17 [12800/60000 (21%)]	Loss Char: 0.130619 Loss Font: 1.270474
# Train Epoch: 17 [19200/60000 (32%)]	Loss Char: 0.085896 Loss Font: 1.316474
# Train Epoch: 17 [25600/60000 (43%)]	Loss Char: 0.104991 Loss Font: 1.265726
# Train Epoch: 17 [32000/60000 (53%)]	Loss Char: 0.055669 Loss Font: 1.334593
# Train Epoch: 17 [38400/60000 (64%)]	Loss Char: 0.238190 Loss Font: 1.374314
# Train Epoch: 17 [44800/60000 (75%)]	Loss Char: 0.038909 Loss Font: 1.299724
# Train Epoch: 17 [51200/60000 (85%)]	Loss Char: 0.099367 Loss Font: 1.270782
# Train Epoch: 17 [57600/60000 (96%)]	Loss Char: 0.123688 Loss Font: 1.292539
#
# Test set: Accuracy Char : 9392/10000 (93.92%)
#           Accuracy Font : 3946/10000 (39.46%)
# (perturbate)
# Train Epoch: 18 [0/60000 (0%)]	Loss Char: 0.087452 Loss Font: 1.402948
# Train Epoch: 18 [6400/60000 (11%)]	Loss Char: 0.147393 Loss Font: 1.305648
# Train Epoch: 18 [12800/60000 (21%)]	Loss Char: 0.058159 Loss Font: 1.263598
# Train Epoch: 18 [19200/60000 (32%)]	Loss Char: 0.114770 Loss Font: 1.341196
# Train Epoch: 18 [25600/60000 (43%)]	Loss Char: 0.076584 Loss Font: 1.151511
# Train Epoch: 18 [32000/60000 (53%)]	Loss Char: 0.108676 Loss Font: 1.218207
# Train Epoch: 18 [38400/60000 (64%)]	Loss Char: 0.049588 Loss Font: 1.226928
# Train Epoch: 18 [44800/60000 (75%)]	Loss Char: 0.052759 Loss Font: 1.250232
# Train Epoch: 18 [51200/60000 (85%)]	Loss Char: 0.047406 Loss Font: 1.326695
# Train Epoch: 18 [57600/60000 (96%)]	Loss Char: 0.186478 Loss Font: 1.262208
#
# Test set: Accuracy Char : 9473/10000 (94.73%)
#           Accuracy Font : 4160/10000 (41.60%)
# (perturbate)
# Train Epoch: 19 [0/60000 (0%)]	Loss Char: 0.036435 Loss Font: 1.413609
# Train Epoch: 19 [6400/60000 (11%)]	Loss Char: 0.178455 Loss Font: 1.230455
# Train Epoch: 19 [12800/60000 (21%)]	Loss Char: 0.143438 Loss Font: 1.231859
# Train Epoch: 19 [19200/60000 (32%)]	Loss Char: 0.113607 Loss Font: 1.364999
# Train Epoch: 19 [25600/60000 (43%)]	Loss Char: 0.064326 Loss Font: 1.222662
# Train Epoch: 19 [32000/60000 (53%)]	Loss Char: 0.145915 Loss Font: 1.376737
# Train Epoch: 19 [38400/60000 (64%)]	Loss Char: 0.278487 Loss Font: 1.227089
# Train Epoch: 19 [44800/60000 (75%)]	Loss Char: 0.043676 Loss Font: 1.342168
# Train Epoch: 19 [51200/60000 (85%)]	Loss Char: 0.072409 Loss Font: 1.375690
# Train Epoch: 19 [57600/60000 (96%)]	Loss Char: 0.061216 Loss Font: 1.250629
#
# Test set: Accuracy Char : 9430/10000 (94.30%)
#           Accuracy Font : 4150/10000 (41.50%)
# (perturbate)
# Train Epoch: 20 [0/60000 (0%)]	Loss Char: 0.035685 Loss Font: 1.245172
# Train Epoch: 20 [6400/60000 (11%)]	Loss Char: 0.062392 Loss Font: 1.423428
# Train Epoch: 20 [12800/60000 (21%)]	Loss Char: 0.114703 Loss Font: 1.392602
# Train Epoch: 20 [19200/60000 (32%)]	Loss Char: 0.038629 Loss Font: 1.197431
# Train Epoch: 20 [25600/60000 (43%)]	Loss Char: 0.071004 Loss Font: 1.294890
# Train Epoch: 20 [32000/60000 (53%)]	Loss Char: 0.065427 Loss Font: 1.297503
# Train Epoch: 20 [38400/60000 (64%)]	Loss Char: 0.023674 Loss Font: 1.357684
# Train Epoch: 20 [44800/60000 (75%)]	Loss Char: 0.043856 Loss Font: 1.405920
# Train Epoch: 20 [51200/60000 (85%)]	Loss Char: 0.141701 Loss Font: 1.301629
# Train Epoch: 20 [57600/60000 (96%)]	Loss Char: 0.019507 Loss Font: 1.161795
#
# Test set: Accuracy Char : 9451/10000 (94.51%)
#           Accuracy Font : 4173/10000 (41.73%)
# Train Epoch: 21 [0/60000 (0%)]	Loss Char: 0.028824 Loss Font: 1.437330
# Train Epoch: 21 [6400/60000 (11%)]	Loss Char: 0.025973 Loss Font: 1.306141
# Train Epoch: 21 [12800/60000 (21%)]	Loss Char: 0.176931 Loss Font: 1.388538
# Train Epoch: 21 [19200/60000 (32%)]	Loss Char: 0.105930 Loss Font: 1.340602
# Train Epoch: 21 [25600/60000 (43%)]	Loss Char: 0.192530 Loss Font: 1.317662
# Train Epoch: 21 [32000/60000 (53%)]	Loss Char: 0.104843 Loss Font: 1.212637
# Train Epoch: 21 [38400/60000 (64%)]	Loss Char: 0.126580 Loss Font: 1.349205
# Train Epoch: 21 [44800/60000 (75%)]	Loss Char: 0.079750 Loss Font: 1.200155
# Train Epoch: 21 [51200/60000 (85%)]	Loss Char: 0.053835 Loss Font: 1.374362
# Train Epoch: 21 [57600/60000 (96%)]	Loss Char: 0.107349 Loss Font: 1.371534
#
# Test set: Accuracy Char : 9498/10000 (94.98%)
#           Accuracy Font : 4263/10000 (42.63%)
# Train Epoch: 22 [0/60000 (0%)]	Loss Char: 0.101097 Loss Font: 1.272937
# Train Epoch: 22 [6400/60000 (11%)]	Loss Char: 0.194529 Loss Font: 1.608658
# Train Epoch: 22 [12800/60000 (21%)]	Loss Char: 0.077734 Loss Font: 1.297937
# Train Epoch: 22 [19200/60000 (32%)]	Loss Char: 0.057230 Loss Font: 1.462926
# Train Epoch: 22 [25600/60000 (43%)]	Loss Char: 0.031767 Loss Font: 1.366887
# Train Epoch: 22 [32000/60000 (53%)]	Loss Char: 0.027021 Loss Font: 1.342172
# Train Epoch: 22 [38400/60000 (64%)]	Loss Char: 0.069263 Loss Font: 1.316005
# Train Epoch: 22 [44800/60000 (75%)]	Loss Char: 0.020217 Loss Font: 1.444961
# Train Epoch: 22 [51200/60000 (85%)]	Loss Char: 0.046861 Loss Font: 1.373693
# Train Epoch: 22 [57600/60000 (96%)]	Loss Char: 0.155309 Loss Font: 1.402072
#
# Test set: Accuracy Char : 9492/10000 (94.92%)
#           Accuracy Font : 4028/10000 (40.28%)
# Train Epoch: 23 [0/60000 (0%)]	Loss Char: 0.086761 Loss Font: 1.539058
# Train Epoch: 23 [6400/60000 (11%)]	Loss Char: 0.018288 Loss Font: 1.232743
# Train Epoch: 23 [12800/60000 (21%)]	Loss Char: 0.039433 Loss Font: 1.330407
# Train Epoch: 23 [19200/60000 (32%)]	Loss Char: 0.105255 Loss Font: 1.241355
# Train Epoch: 23 [25600/60000 (43%)]	Loss Char: 0.127304 Loss Font: 1.354854
# Train Epoch: 23 [32000/60000 (53%)]	Loss Char: 0.023513 Loss Font: 1.288748
# Train Epoch: 23 [38400/60000 (64%)]	Loss Char: 0.056770 Loss Font: 1.507349
# Train Epoch: 23 [44800/60000 (75%)]	Loss Char: 0.087149 Loss Font: 1.302550
# Train Epoch: 23 [51200/60000 (85%)]	Loss Char: 0.058021 Loss Font: 1.417173
# Train Epoch: 23 [57600/60000 (96%)]	Loss Char: 0.242512 Loss Font: 1.342987
#
# Test set: Accuracy Char : 9487/10000 (94.87%)
#           Accuracy Font : 4236/10000 (42.36%)
# Train Epoch: 24 [0/60000 (0%)]	Loss Char: 0.120220 Loss Font: 1.312269
# Train Epoch: 24 [6400/60000 (11%)]	Loss Char: 0.121329 Loss Font: 1.435944
# Train Epoch: 24 [12800/60000 (21%)]	Loss Char: 0.093799 Loss Font: 1.349776
# Train Epoch: 24 [19200/60000 (32%)]	Loss Char: 0.111097 Loss Font: 1.526584
# Train Epoch: 24 [25600/60000 (43%)]	Loss Char: 0.085163 Loss Font: 1.223277
# Train Epoch: 24 [32000/60000 (53%)]	Loss Char: 0.062077 Loss Font: 1.444236
# Train Epoch: 24 [38400/60000 (64%)]	Loss Char: 0.213279 Loss Font: 1.322727
# Train Epoch: 24 [44800/60000 (75%)]	Loss Char: 0.082174 Loss Font: 1.319751
# Train Epoch: 24 [51200/60000 (85%)]	Loss Char: 0.235711 Loss Font: 1.242331
# Train Epoch: 24 [57600/60000 (96%)]	Loss Char: 0.235000 Loss Font: 1.302616
#
# Test set: Accuracy Char : 9480/10000 (94.80%)
#           Accuracy Font : 4356/10000 (43.56%)
# Train Epoch: 25 [0/60000 (0%)]	Loss Char: 0.140108 Loss Font: 1.256279
# Train Epoch: 25 [6400/60000 (11%)]	Loss Char: 0.160672 Loss Font: 1.261608
# Train Epoch: 25 [12800/60000 (21%)]	Loss Char: 0.104594 Loss Font: 1.533341
# Train Epoch: 25 [19200/60000 (32%)]	Loss Char: 0.202416 Loss Font: 1.193467
# Train Epoch: 25 [25600/60000 (43%)]	Loss Char: 0.122640 Loss Font: 1.264063
# Train Epoch: 25 [32000/60000 (53%)]	Loss Char: 0.108028 Loss Font: 1.302302
# Train Epoch: 25 [38400/60000 (64%)]	Loss Char: 0.173097 Loss Font: 1.401146
# Train Epoch: 25 [44800/60000 (75%)]	Loss Char: 0.088800 Loss Font: 1.197262
# Train Epoch: 25 [51200/60000 (85%)]	Loss Char: 0.043901 Loss Font: 1.196036
# Train Epoch: 25 [57600/60000 (96%)]	Loss Char: 0.119197 Loss Font: 1.206540
#
# Test set: Accuracy Char : 9492/10000 (94.92%)
#           Accuracy Font : 4302/10000 (43.02%)
# Train Epoch: 26 [0/60000 (0%)]	Loss Char: 0.070061 Loss Font: 1.297476
# Train Epoch: 26 [6400/60000 (11%)]	Loss Char: 0.014290 Loss Font: 1.155195
# Train Epoch: 26 [12800/60000 (21%)]	Loss Char: 0.029278 Loss Font: 1.220150
# Train Epoch: 26 [19200/60000 (32%)]	Loss Char: 0.031380 Loss Font: 1.341981
# Train Epoch: 26 [25600/60000 (43%)]	Loss Char: 0.041215 Loss Font: 1.440142
# Train Epoch: 26 [32000/60000 (53%)]	Loss Char: 0.156981 Loss Font: 1.350095
# Train Epoch: 26 [38400/60000 (64%)]	Loss Char: 0.028043 Loss Font: 1.462852
# Train Epoch: 26 [44800/60000 (75%)]	Loss Char: 0.063810 Loss Font: 1.306794
# Train Epoch: 26 [51200/60000 (85%)]	Loss Char: 0.133915 Loss Font: 1.235193
# Train Epoch: 26 [57600/60000 (96%)]	Loss Char: 0.054685 Loss Font: 1.298527
#
# Test set: Accuracy Char : 9500/10000 (95.00%)
#           Accuracy Font : 4308/10000 (43.08%)
# Train Epoch: 27 [0/60000 (0%)]	Loss Char: 0.066522 Loss Font: 1.392605
# Train Epoch: 27 [6400/60000 (11%)]	Loss Char: 0.097425 Loss Font: 1.193538
# Train Epoch: 27 [12800/60000 (21%)]	Loss Char: 0.029262 Loss Font: 1.269270
# Train Epoch: 27 [19200/60000 (32%)]	Loss Char: 0.031039 Loss Font: 1.213078
# Train Epoch: 27 [25600/60000 (43%)]	Loss Char: 0.073283 Loss Font: 1.343056
# Train Epoch: 27 [32000/60000 (53%)]	Loss Char: 0.028768 Loss Font: 1.219242
# Train Epoch: 27 [38400/60000 (64%)]	Loss Char: 0.117310 Loss Font: 1.224439
# Train Epoch: 27 [44800/60000 (75%)]	Loss Char: 0.096029 Loss Font: 1.306685
# Train Epoch: 27 [51200/60000 (85%)]	Loss Char: 0.069904 Loss Font: 1.578822
# Train Epoch: 27 [57600/60000 (96%)]	Loss Char: 0.102699 Loss Font: 1.417531
#
# Test set: Accuracy Char : 9489/10000 (94.89%)
#           Accuracy Font : 4343/10000 (43.43%)
# Train Epoch: 28 [0/60000 (0%)]	Loss Char: 0.116511 Loss Font: 1.208553
# Train Epoch: 28 [6400/60000 (11%)]	Loss Char: 0.131974 Loss Font: 1.414895
# Train Epoch: 28 [12800/60000 (21%)]	Loss Char: 0.265804 Loss Font: 1.343402
# Train Epoch: 28 [19200/60000 (32%)]	Loss Char: 0.111455 Loss Font: 1.284949
# Train Epoch: 28 [25600/60000 (43%)]	Loss Char: 0.037962 Loss Font: 1.380977
# Train Epoch: 28 [32000/60000 (53%)]	Loss Char: 0.083903 Loss Font: 1.290369
# Train Epoch: 28 [38400/60000 (64%)]	Loss Char: 0.014830 Loss Font: 1.369476
# Train Epoch: 28 [44800/60000 (75%)]	Loss Char: 0.078854 Loss Font: 1.331319
# Train Epoch: 28 [51200/60000 (85%)]	Loss Char: 0.140777 Loss Font: 1.492226
# Train Epoch: 28 [57600/60000 (96%)]	Loss Char: 0.083805 Loss Font: 1.197883
#
# Test set: Accuracy Char : 9497/10000 (94.97%)
#           Accuracy Font : 4246/10000 (42.46%)
# Train Epoch: 29 [0/60000 (0%)]	Loss Char: 0.068166 Loss Font: 1.284224
# Train Epoch: 29 [6400/60000 (11%)]	Loss Char: 0.063101 Loss Font: 1.298895
# Train Epoch: 29 [12800/60000 (21%)]	Loss Char: 0.036395 Loss Font: 1.471507
# Train Epoch: 29 [19200/60000 (32%)]	Loss Char: 0.143741 Loss Font: 1.389351
# Train Epoch: 29 [25600/60000 (43%)]	Loss Char: 0.080864 Loss Font: 1.258685
# Train Epoch: 29 [32000/60000 (53%)]	Loss Char: 0.055334 Loss Font: 1.402299
# Train Epoch: 29 [38400/60000 (64%)]	Loss Char: 0.117154 Loss Font: 1.220672
# Train Epoch: 29 [44800/60000 (75%)]	Loss Char: 0.058480 Loss Font: 1.352616
# Train Epoch: 29 [51200/60000 (85%)]	Loss Char: 0.094117 Loss Font: 1.330082
# Train Epoch: 29 [57600/60000 (96%)]	Loss Char: 0.125760 Loss Font: 1.451554
#
# Test set: Accuracy Char : 9494/10000 (94.94%)
#           Accuracy Font : 4344/10000 (43.44%)
# Train Epoch: 30 [0/60000 (0%)]	Loss Char: 0.115213 Loss Font: 1.365921
# Train Epoch: 30 [6400/60000 (11%)]	Loss Char: 0.062873 Loss Font: 1.298841
# Train Epoch: 30 [12800/60000 (21%)]	Loss Char: 0.165351 Loss Font: 1.227225
# Train Epoch: 30 [19200/60000 (32%)]	Loss Char: 0.090093 Loss Font: 1.295395
# Train Epoch: 30 [25600/60000 (43%)]	Loss Char: 0.032386 Loss Font: 1.192832
# Train Epoch: 30 [32000/60000 (53%)]	Loss Char: 0.045646 Loss Font: 1.383828
# Train Epoch: 30 [38400/60000 (64%)]	Loss Char: 0.059404 Loss Font: 1.401089
# Train Epoch: 30 [44800/60000 (75%)]	Loss Char: 0.087704 Loss Font: 1.278694
# Train Epoch: 30 [51200/60000 (85%)]	Loss Char: 0.136807 Loss Font: 1.192238
# Train Epoch: 30 [57600/60000 (96%)]	Loss Char: 0.302572 Loss Font: 1.574809
#
# Test set: Accuracy Char : 9494/10000 (94.94%)
#           Accuracy Font : 4289/10000 (42.89%)
# Training set 60000 items
# Testing set  10000 items
# (initial phase)
# Train Epoch: 1 [0/60000 (0%)]	Loss Char: 3.241490 Loss Font: 1.619655
# Train Epoch: 1 [6400/60000 (11%)]	Loss Char: 3.243401 Loss Font: 1.634818
# Train Epoch: 1 [12800/60000 (21%)]	Loss Char: 3.125095 Loss Font: 1.670732
# Train Epoch: 1 [19200/60000 (32%)]	Loss Char: 2.984154 Loss Font: 1.708088
# Train Epoch: 1 [25600/60000 (43%)]	Loss Char: 2.888399 Loss Font: 1.640867
# Train Epoch: 1 [32000/60000 (53%)]	Loss Char: 2.595878 Loss Font: 1.645604
# Train Epoch: 1 [38400/60000 (64%)]	Loss Char: 2.191660 Loss Font: 1.634457
# Train Epoch: 1 [44800/60000 (75%)]	Loss Char: 1.920311 Loss Font: 1.644273
# Train Epoch: 1 [51200/60000 (85%)]	Loss Char: 1.738962 Loss Font: 1.688137
# Train Epoch: 1 [57600/60000 (96%)]	Loss Char: 1.865170 Loss Font: 1.599646
#
# Test set: Accuracy Char : 4957/10000 (49.57%)
#           Accuracy Font : 2659/10000 (26.59%)
# (initial phase)
# Train Epoch: 2 [0/60000 (0%)]	Loss Char: 1.318387 Loss Font: 1.608933
# Train Epoch: 2 [6400/60000 (11%)]	Loss Char: 1.550118 Loss Font: 1.520178
# Train Epoch: 2 [12800/60000 (21%)]	Loss Char: 1.160004 Loss Font: 1.508529
# Train Epoch: 2 [19200/60000 (32%)]	Loss Char: 1.097548 Loss Font: 1.513336
# Train Epoch: 2 [25600/60000 (43%)]	Loss Char: 1.117916 Loss Font: 1.522316
# Train Epoch: 2 [32000/60000 (53%)]	Loss Char: 0.818825 Loss Font: 1.561099
# Train Epoch: 2 [38400/60000 (64%)]	Loss Char: 0.771766 Loss Font: 1.542226
# Train Epoch: 2 [44800/60000 (75%)]	Loss Char: 1.050970 Loss Font: 1.455329
# Train Epoch: 2 [51200/60000 (85%)]	Loss Char: 0.822885 Loss Font: 1.556443
# Train Epoch: 2 [57600/60000 (96%)]	Loss Char: 1.063315 Loss Font: 1.586820
#
# Test set: Accuracy Char : 7465/10000 (74.65%)
#           Accuracy Font : 3104/10000 (31.04%)
# (initial phase)
# Train Epoch: 3 [0/60000 (0%)]	Loss Char: 0.846573 Loss Font: 1.514468
# Train Epoch: 3 [6400/60000 (11%)]	Loss Char: 0.830905 Loss Font: 1.440030
# Train Epoch: 3 [12800/60000 (21%)]	Loss Char: 0.838321 Loss Font: 1.605255
# Train Epoch: 3 [19200/60000 (32%)]	Loss Char: 0.746728 Loss Font: 1.463067
# Train Epoch: 3 [25600/60000 (43%)]	Loss Char: 0.769849 Loss Font: 1.550862
# Train Epoch: 3 [32000/60000 (53%)]	Loss Char: 0.517730 Loss Font: 1.450067
# Train Epoch: 3 [38400/60000 (64%)]	Loss Char: 0.601043 Loss Font: 1.477565
# Train Epoch: 3 [44800/60000 (75%)]	Loss Char: 0.542821 Loss Font: 1.628974
# Train Epoch: 3 [51200/60000 (85%)]	Loss Char: 0.596551 Loss Font: 1.468087
# Train Epoch: 3 [57600/60000 (96%)]	Loss Char: 0.743588 Loss Font: 1.523732
#
# Test set: Accuracy Char : 8261/10000 (82.61%)
#           Accuracy Font : 3257/10000 (32.57%)
# (initial phase)
# Train Epoch: 4 [0/60000 (0%)]	Loss Char: 0.549530 Loss Font: 1.450864
# Train Epoch: 4 [6400/60000 (11%)]	Loss Char: 0.383065 Loss Font: 1.469275
# Train Epoch: 4 [12800/60000 (21%)]	Loss Char: 0.436886 Loss Font: 1.455344
# Train Epoch: 4 [19200/60000 (32%)]	Loss Char: 0.598079 Loss Font: 1.564009
# Train Epoch: 4 [25600/60000 (43%)]	Loss Char: 0.318404 Loss Font: 1.417232
# Train Epoch: 4 [32000/60000 (53%)]	Loss Char: 0.465218 Loss Font: 1.481279
# Train Epoch: 4 [38400/60000 (64%)]	Loss Char: 0.416448 Loss Font: 1.493089
# Train Epoch: 4 [44800/60000 (75%)]	Loss Char: 0.476082 Loss Font: 1.460058
# Train Epoch: 4 [51200/60000 (85%)]	Loss Char: 0.561793 Loss Font: 1.416564
# Train Epoch: 4 [57600/60000 (96%)]	Loss Char: 0.383984 Loss Font: 1.525175
#
# Test set: Accuracy Char : 8492/10000 (84.92%)
#           Accuracy Font : 3349/10000 (33.49%)
# (initial phase)
# Train Epoch: 5 [0/60000 (0%)]	Loss Char: 0.465208 Loss Font: 1.441594
# Train Epoch: 5 [6400/60000 (11%)]	Loss Char: 0.482403 Loss Font: 1.375755
# Train Epoch: 5 [12800/60000 (21%)]	Loss Char: 0.405939 Loss Font: 1.326863
# Train Epoch: 5 [19200/60000 (32%)]	Loss Char: 0.362571 Loss Font: 1.499023
# Train Epoch: 5 [25600/60000 (43%)]	Loss Char: 0.332217 Loss Font: 1.405209
# Train Epoch: 5 [32000/60000 (53%)]	Loss Char: 0.303684 Loss Font: 1.413099
# Train Epoch: 5 [38400/60000 (64%)]	Loss Char: 0.489397 Loss Font: 1.481379
# Train Epoch: 5 [44800/60000 (75%)]	Loss Char: 0.263597 Loss Font: 1.312635
# Train Epoch: 5 [51200/60000 (85%)]	Loss Char: 0.546229 Loss Font: 1.443149
# Train Epoch: 5 [57600/60000 (96%)]	Loss Char: 0.264077 Loss Font: 1.464120
#
# Test set: Accuracy Char : 8951/10000 (89.51%)
#           Accuracy Font : 3599/10000 (35.99%)
# (initial phase)
# Train Epoch: 6 [0/60000 (0%)]	Loss Char: 0.235854 Loss Font: 1.509135
# Train Epoch: 6 [6400/60000 (11%)]	Loss Char: 0.449579 Loss Font: 1.517862
# Train Epoch: 6 [12800/60000 (21%)]	Loss Char: 0.241981 Loss Font: 1.432219
# Train Epoch: 6 [19200/60000 (32%)]	Loss Char: 0.586458 Loss Font: 1.423619
# Train Epoch: 6 [25600/60000 (43%)]	Loss Char: 0.439160 Loss Font: 1.557969
# Train Epoch: 6 [32000/60000 (53%)]	Loss Char: 0.378124 Loss Font: 1.526518
# Train Epoch: 6 [38400/60000 (64%)]	Loss Char: 0.249369 Loss Font: 1.578080
# Train Epoch: 6 [44800/60000 (75%)]	Loss Char: 0.254407 Loss Font: 1.413932
# Train Epoch: 6 [51200/60000 (85%)]	Loss Char: 0.202057 Loss Font: 1.415316
# Train Epoch: 6 [57600/60000 (96%)]	Loss Char: 0.332146 Loss Font: 1.304578
#
# Test set: Accuracy Char : 9034/10000 (90.34%)
#           Accuracy Font : 3692/10000 (36.92%)
# (initial phase)
# Train Epoch: 7 [0/60000 (0%)]	Loss Char: 0.211176 Loss Font: 1.406888
# Train Epoch: 7 [6400/60000 (11%)]	Loss Char: 0.303036 Loss Font: 1.432919
# Train Epoch: 7 [12800/60000 (21%)]	Loss Char: 0.273678 Loss Font: 1.490821
# Train Epoch: 7 [19200/60000 (32%)]	Loss Char: 0.378296 Loss Font: 1.296944
# Train Epoch: 7 [25600/60000 (43%)]	Loss Char: 0.434525 Loss Font: 1.333350
# Train Epoch: 7 [32000/60000 (53%)]	Loss Char: 0.345688 Loss Font: 1.412492
# Train Epoch: 7 [38400/60000 (64%)]	Loss Char: 0.466365 Loss Font: 1.438078
# Train Epoch: 7 [44800/60000 (75%)]	Loss Char: 0.234117 Loss Font: 1.409068
# Train Epoch: 7 [51200/60000 (85%)]	Loss Char: 0.335284 Loss Font: 1.357813
# Train Epoch: 7 [57600/60000 (96%)]	Loss Char: 0.144080 Loss Font: 1.301559
#
# Test set: Accuracy Char : 9054/10000 (90.54%)
#           Accuracy Font : 3788/10000 (37.88%)
# (initial phase)
# Train Epoch: 8 [0/60000 (0%)]	Loss Char: 0.266888 Loss Font: 1.267742
# Train Epoch: 8 [6400/60000 (11%)]	Loss Char: 0.266663 Loss Font: 1.279194
# Train Epoch: 8 [12800/60000 (21%)]	Loss Char: 0.107764 Loss Font: 1.410281
# Train Epoch: 8 [19200/60000 (32%)]	Loss Char: 0.062947 Loss Font: 1.410076
# Train Epoch: 8 [25600/60000 (43%)]	Loss Char: 0.184841 Loss Font: 1.401432
# Train Epoch: 8 [32000/60000 (53%)]	Loss Char: 0.248879 Loss Font: 1.418651
# Train Epoch: 8 [38400/60000 (64%)]	Loss Char: 0.263521 Loss Font: 1.395258
# Train Epoch: 8 [44800/60000 (75%)]	Loss Char: 0.331028 Loss Font: 1.372722
# Train Epoch: 8 [51200/60000 (85%)]	Loss Char: 0.193999 Loss Font: 1.316621
# Train Epoch: 8 [57600/60000 (96%)]	Loss Char: 0.347703 Loss Font: 1.397890
#
# Test set: Accuracy Char : 9125/10000 (91.25%)
#           Accuracy Font : 3844/10000 (38.44%)
# (initial phase)
# Train Epoch: 9 [0/60000 (0%)]	Loss Char: 0.233935 Loss Font: 1.323599
# Train Epoch: 9 [6400/60000 (11%)]	Loss Char: 0.094830 Loss Font: 1.305113
# Train Epoch: 9 [12800/60000 (21%)]	Loss Char: 0.131809 Loss Font: 1.285592
# Train Epoch: 9 [19200/60000 (32%)]	Loss Char: 0.299382 Loss Font: 1.376420
# Train Epoch: 9 [25600/60000 (43%)]	Loss Char: 0.218124 Loss Font: 1.407190
# Train Epoch: 9 [32000/60000 (53%)]	Loss Char: 0.508665 Loss Font: 1.498717
# Train Epoch: 9 [38400/60000 (64%)]	Loss Char: 0.184355 Loss Font: 1.423950
# Train Epoch: 9 [44800/60000 (75%)]	Loss Char: 0.159247 Loss Font: 1.381975
# Train Epoch: 9 [51200/60000 (85%)]	Loss Char: 0.310555 Loss Font: 1.352751
# Train Epoch: 9 [57600/60000 (96%)]	Loss Char: 0.112406 Loss Font: 1.227715
#
# Test set: Accuracy Char : 9284/10000 (92.84%)
#           Accuracy Font : 3906/10000 (39.06%)
# (initial phase)
# Train Epoch: 10 [0/60000 (0%)]	Loss Char: 0.166191 Loss Font: 1.441306
# Train Epoch: 10 [6400/60000 (11%)]	Loss Char: 0.356349 Loss Font: 1.350080
# Train Epoch: 10 [12800/60000 (21%)]	Loss Char: 0.178570 Loss Font: 1.328286
# Train Epoch: 10 [19200/60000 (32%)]	Loss Char: 0.186070 Loss Font: 1.484167
# Train Epoch: 10 [25600/60000 (43%)]	Loss Char: 0.195577 Loss Font: 1.469617
# Train Epoch: 10 [32000/60000 (53%)]	Loss Char: 0.145385 Loss Font: 1.345128
# Train Epoch: 10 [38400/60000 (64%)]	Loss Char: 0.117435 Loss Font: 1.306534
# Train Epoch: 10 [44800/60000 (75%)]	Loss Char: 0.142440 Loss Font: 1.466446
# Train Epoch: 10 [51200/60000 (85%)]	Loss Char: 0.235981 Loss Font: 1.445580
# Train Epoch: 10 [57600/60000 (96%)]	Loss Char: 0.174490 Loss Font: 1.521461
#
# Test set: Accuracy Char : 9294/10000 (92.94%)
#           Accuracy Font : 3947/10000 (39.47%)
# (perturbate)
# Train Epoch: 11 [0/60000 (0%)]	Loss Char: 0.186847 Loss Font: 1.429575
# Train Epoch: 11 [6400/60000 (11%)]	Loss Char: 0.097303 Loss Font: 1.370102
# Train Epoch: 11 [12800/60000 (21%)]	Loss Char: 0.088315 Loss Font: 1.490234
# Train Epoch: 11 [19200/60000 (32%)]	Loss Char: 0.195330 Loss Font: 1.209098
# Train Epoch: 11 [25600/60000 (43%)]	Loss Char: 0.174711 Loss Font: 1.446724
# Train Epoch: 11 [32000/60000 (53%)]	Loss Char: 0.207124 Loss Font: 1.344861
# Train Epoch: 11 [38400/60000 (64%)]	Loss Char: 0.106316 Loss Font: 1.261082
# Train Epoch: 11 [44800/60000 (75%)]	Loss Char: 0.072710 Loss Font: 1.356241
# Train Epoch: 11 [51200/60000 (85%)]	Loss Char: 0.116298 Loss Font: 1.367918
# Train Epoch: 11 [57600/60000 (96%)]	Loss Char: 0.092352 Loss Font: 1.294365
#
# Test set: Accuracy Char : 9391/10000 (93.91%)
#           Accuracy Font : 3884/10000 (38.84%)
# (perturbate)
# Train Epoch: 12 [0/60000 (0%)]	Loss Char: 0.191894 Loss Font: 1.449735
# Train Epoch: 12 [6400/60000 (11%)]	Loss Char: 0.042358 Loss Font: 1.435235
# Train Epoch: 12 [12800/60000 (21%)]	Loss Char: 0.100344 Loss Font: 1.332585
# Train Epoch: 12 [19200/60000 (32%)]	Loss Char: 0.276984 Loss Font: 1.508683
# Train Epoch: 12 [25600/60000 (43%)]	Loss Char: 0.129942 Loss Font: 1.400116
# Train Epoch: 12 [32000/60000 (53%)]	Loss Char: 0.097752 Loss Font: 1.344796
# Train Epoch: 12 [38400/60000 (64%)]	Loss Char: 0.079813 Loss Font: 1.358783
# Train Epoch: 12 [44800/60000 (75%)]	Loss Char: 0.212479 Loss Font: 1.326330
# Train Epoch: 12 [51200/60000 (85%)]	Loss Char: 0.080568 Loss Font: 1.306037
# Train Epoch: 12 [57600/60000 (96%)]	Loss Char: 0.223681 Loss Font: 1.378509
#
# Test set: Accuracy Char : 9378/10000 (93.78%)
#           Accuracy Font : 3729/10000 (37.29%)
# (perturbate)
# Train Epoch: 13 [0/60000 (0%)]	Loss Char: 0.269905 Loss Font: 1.403541
# Train Epoch: 13 [6400/60000 (11%)]	Loss Char: 0.142373 Loss Font: 1.338523
# Train Epoch: 13 [12800/60000 (21%)]	Loss Char: 0.113912 Loss Font: 1.345282
# Train Epoch: 13 [19200/60000 (32%)]	Loss Char: 0.130288 Loss Font: 1.305028
# Train Epoch: 13 [25600/60000 (43%)]	Loss Char: 0.105280 Loss Font: 1.315424
# Train Epoch: 13 [32000/60000 (53%)]	Loss Char: 0.122026 Loss Font: 1.367700
# Train Epoch: 13 [38400/60000 (64%)]	Loss Char: 0.151673 Loss Font: 1.309076
# Train Epoch: 13 [44800/60000 (75%)]	Loss Char: 0.043392 Loss Font: 1.381196
# Train Epoch: 13 [51200/60000 (85%)]	Loss Char: 0.084007 Loss Font: 1.287989
# Train Epoch: 13 [57600/60000 (96%)]	Loss Char: 0.192320 Loss Font: 1.359067
#
# Test set: Accuracy Char : 9370/10000 (93.70%)
#           Accuracy Font : 3867/10000 (38.67%)
# (perturbate)
# Train Epoch: 14 [0/60000 (0%)]	Loss Char: 0.204365 Loss Font: 1.203770
# Train Epoch: 14 [6400/60000 (11%)]	Loss Char: 0.078834 Loss Font: 1.345520
# Train Epoch: 14 [12800/60000 (21%)]	Loss Char: 0.108724 Loss Font: 1.342834
# Train Epoch: 14 [19200/60000 (32%)]	Loss Char: 0.173362 Loss Font: 1.292338
# Train Epoch: 14 [25600/60000 (43%)]	Loss Char: 0.090255 Loss Font: 1.205342
# Train Epoch: 14 [32000/60000 (53%)]	Loss Char: 0.083889 Loss Font: 1.415146
# Train Epoch: 14 [38400/60000 (64%)]	Loss Char: 0.068873 Loss Font: 1.403657
# Train Epoch: 14 [44800/60000 (75%)]	Loss Char: 0.112984 Loss Font: 1.444921
# Train Epoch: 14 [51200/60000 (85%)]	Loss Char: 0.081005 Loss Font: 1.370633
# Train Epoch: 14 [57600/60000 (96%)]	Loss Char: 0.065848 Loss Font: 1.398920
#
# Test set: Accuracy Char : 9451/10000 (94.51%)
#           Accuracy Font : 4092/10000 (40.92%)
# (perturbate)
# Train Epoch: 15 [0/60000 (0%)]	Loss Char: 0.119705 Loss Font: 1.347291
# Train Epoch: 15 [6400/60000 (11%)]	Loss Char: 0.094378 Loss Font: 1.431716
# Train Epoch: 15 [12800/60000 (21%)]	Loss Char: 0.062866 Loss Font: 1.421244
# Train Epoch: 15 [19200/60000 (32%)]	Loss Char: 0.051732 Loss Font: 1.370365
# Train Epoch: 15 [25600/60000 (43%)]	Loss Char: 0.107271 Loss Font: 1.427697
# Train Epoch: 15 [32000/60000 (53%)]	Loss Char: 0.174978 Loss Font: 1.301883
# Train Epoch: 15 [38400/60000 (64%)]	Loss Char: 0.085966 Loss Font: 1.393358
# Train Epoch: 15 [44800/60000 (75%)]	Loss Char: 0.118428 Loss Font: 1.245535
# Train Epoch: 15 [51200/60000 (85%)]	Loss Char: 0.129690 Loss Font: 1.277630
# Train Epoch: 15 [57600/60000 (96%)]	Loss Char: 0.052447 Loss Font: 1.403417
#
# Test set: Accuracy Char : 9324/10000 (93.24%)
#           Accuracy Font : 3987/10000 (39.87%)
# (perturbate)
# Train Epoch: 16 [0/60000 (0%)]	Loss Char: 0.091881 Loss Font: 1.429139
# Train Epoch: 16 [6400/60000 (11%)]	Loss Char: 0.230673 Loss Font: 1.454617
# Train Epoch: 16 [12800/60000 (21%)]	Loss Char: 0.058933 Loss Font: 1.388216
# Train Epoch: 16 [19200/60000 (32%)]	Loss Char: 0.088131 Loss Font: 1.270727
# Train Epoch: 16 [25600/60000 (43%)]	Loss Char: 0.120461 Loss Font: 1.467681
# Train Epoch: 16 [32000/60000 (53%)]	Loss Char: 0.076248 Loss Font: 1.393094
# Train Epoch: 16 [38400/60000 (64%)]	Loss Char: 0.094850 Loss Font: 1.374911
# Train Epoch: 16 [44800/60000 (75%)]	Loss Char: 0.049168 Loss Font: 1.346828
# Train Epoch: 16 [51200/60000 (85%)]	Loss Char: 0.139408 Loss Font: 1.351613
# Train Epoch: 16 [57600/60000 (96%)]	Loss Char: 0.127216 Loss Font: 1.538719
#
# Test set: Accuracy Char : 9456/10000 (94.56%)
#           Accuracy Font : 4050/10000 (40.50%)
# (perturbate)
# Train Epoch: 17 [0/60000 (0%)]	Loss Char: 0.034236 Loss Font: 1.195216
# Train Epoch: 17 [6400/60000 (11%)]	Loss Char: 0.020770 Loss Font: 1.296014
# Train Epoch: 17 [12800/60000 (21%)]	Loss Char: 0.137932 Loss Font: 1.293465
# Train Epoch: 17 [19200/60000 (32%)]	Loss Char: 0.088139 Loss Font: 1.370068
# Train Epoch: 17 [25600/60000 (43%)]	Loss Char: 0.101972 Loss Font: 1.304693
# Train Epoch: 17 [32000/60000 (53%)]	Loss Char: 0.061065 Loss Font: 1.375558
# Train Epoch: 17 [38400/60000 (64%)]	Loss Char: 0.230293 Loss Font: 1.410953
# Train Epoch: 17 [44800/60000 (75%)]	Loss Char: 0.041941 Loss Font: 1.339368
# Train Epoch: 17 [51200/60000 (85%)]	Loss Char: 0.095336 Loss Font: 1.291884
# Train Epoch: 17 [57600/60000 (96%)]	Loss Char: 0.130468 Loss Font: 1.337994
#
# Test set: Accuracy Char : 9396/10000 (93.96%)
#           Accuracy Font : 3763/10000 (37.63%)
# (perturbate)
# Train Epoch: 18 [0/60000 (0%)]	Loss Char: 0.087784 Loss Font: 1.439558
# Train Epoch: 18 [6400/60000 (11%)]	Loss Char: 0.148915 Loss Font: 1.346449
# Train Epoch: 18 [12800/60000 (21%)]	Loss Char: 0.063993 Loss Font: 1.316497
# Train Epoch: 18 [19200/60000 (32%)]	Loss Char: 0.120420 Loss Font: 1.368680
# Train Epoch: 18 [25600/60000 (43%)]	Loss Char: 0.088691 Loss Font: 1.172692
# Train Epoch: 18 [32000/60000 (53%)]	Loss Char: 0.109383 Loss Font: 1.275333
# Train Epoch: 18 [38400/60000 (64%)]	Loss Char: 0.045819 Loss Font: 1.273043
# Train Epoch: 18 [44800/60000 (75%)]	Loss Char: 0.053621 Loss Font: 1.289406
# Train Epoch: 18 [51200/60000 (85%)]	Loss Char: 0.048317 Loss Font: 1.349830
# Train Epoch: 18 [57600/60000 (96%)]	Loss Char: 0.191775 Loss Font: 1.317667
# Test set: Accuracy Char : 9466/10000 (94.66%)
#           Accuracy Font : 3971/10000 (39.71%)
# (perturbate)
# Train Epoch: 19 [0/60000 (0%)]	Loss Char: 0.036944 Loss Font: 1.436465
# Train Epoch: 19 [6400/60000 (11%)]	Loss Char: 0.170963 Loss Font: 1.285802
# Train Epoch: 19 [12800/60000 (21%)]	Loss Char: 0.154011 Loss Font: 1.286802
# Train Epoch: 19 [19200/60000 (32%)]	Loss Char: 0.115065 Loss Font: 1.417873
# Train Epoch: 19 [25600/60000 (43%)]	Loss Char: 0.069001 Loss Font: 1.276271
# Train Epoch: 19 [32000/60000 (53%)]	Loss Char: 0.150686 Loss Font: 1.400086
# Train Epoch: 19 [38400/60000 (64%)]	Loss Char: 0.271615 Loss Font: 1.266448
# Train Epoch: 19 [44800/60000 (75%)]	Loss Char: 0.049059 Loss Font: 1.390155
# Train Epoch: 19 [51200/60000 (85%)]	Loss Char: 0.075748 Loss Font: 1.423297
# Train Epoch: 19 [57600/60000 (96%)]	Loss Char: 0.063520 Loss Font: 1.299315
#
# Test set: Accuracy Char : 9426/10000 (94.26%)
#           Accuracy Font : 3958/10000 (39.58%)
# (perturbate)
# Train Epoch: 20 [0/60000 (0%)]	Loss Char: 0.039558 Loss Font: 1.312630
# Train Epoch: 20 [6400/60000 (11%)]	Loss Char: 0.061440 Loss Font: 1.468020
# Train Epoch: 20 [12800/60000 (21%)]	Loss Char: 0.142416 Loss Font: 1.442933
# Train Epoch: 20 [19200/60000 (32%)]	Loss Char: 0.037890 Loss Font: 1.252207
# Train Epoch: 20 [25600/60000 (43%)]	Loss Char: 0.074836 Loss Font: 1.338602
# Train Epoch: 20 [32000/60000 (53%)]	Loss Char: 0.068179 Loss Font: 1.361175
# Train Epoch: 20 [38400/60000 (64%)]	Loss Char: 0.025489 Loss Font: 1.430921
# Train Epoch: 20 [44800/60000 (75%)]	Loss Char: 0.040814 Loss Font: 1.446902
# Train Epoch: 20 [51200/60000 (85%)]	Loss Char: 0.142774 Loss Font: 1.340484
# Train Epoch: 20 [57600/60000 (96%)]	Loss Char: 0.019051 Loss Font: 1.196188
#
# Test set: Accuracy Char : 9435/10000 (94.35%)
#           Accuracy Font : 3978/10000 (39.78%)
# Train Epoch: 21 [0/60000 (0%)]	Loss Char: 0.031609 Loss Font: 1.455068
# Train Epoch: 21 [6400/60000 (11%)]	Loss Char: 0.027753 Loss Font: 1.373513
# Train Epoch: 21 [12800/60000 (21%)]	Loss Char: 0.182416 Loss Font: 1.443436
# Train Epoch: 21 [19200/60000 (32%)]	Loss Char: 0.109060 Loss Font: 1.393706
# Train Epoch: 21 [25600/60000 (43%)]	Loss Char: 0.181840 Loss Font: 1.364673
# Train Epoch: 21 [32000/60000 (53%)]	Loss Char: 0.087196 Loss Font: 1.278707
# Train Epoch: 21 [38400/60000 (64%)]	Loss Char: 0.141854 Loss Font: 1.383366
# Train Epoch: 21 [44800/60000 (75%)]	Loss Char: 0.087904 Loss Font: 1.234684
# Train Epoch: 21 [51200/60000 (85%)]	Loss Char: 0.059584 Loss Font: 1.399551
# Train Epoch: 21 [57600/60000 (96%)]	Loss Char: 0.123514 Loss Font: 1.396196
#
# Test set: Accuracy Char : 9482/10000 (94.82%)
#           Accuracy Font : 4020/10000 (40.20%)
# Train Epoch: 22 [0/60000 (0%)]	Loss Char: 0.117303 Loss Font: 1.334376
# Train Epoch: 22 [6400/60000 (11%)]	Loss Char: 0.197849 Loss Font: 1.640213
# Train Epoch: 22 [12800/60000 (21%)]	Loss Char: 0.074042 Loss Font: 1.353162
# Train Epoch: 22 [19200/60000 (32%)]	Loss Char: 0.061024 Loss Font: 1.505687
# Train Epoch: 22 [25600/60000 (43%)]	Loss Char: 0.034041 Loss Font: 1.394106
# Train Epoch: 22 [32000/60000 (53%)]	Loss Char: 0.029073 Loss Font: 1.367586
# Train Epoch: 22 [38400/60000 (64%)]	Loss Char: 0.074727 Loss Font: 1.381731
# Train Epoch: 22 [44800/60000 (75%)]	Loss Char: 0.021849 Loss Font: 1.466393
# Train Epoch: 22 [51200/60000 (85%)]	Loss Char: 0.049403 Loss Font: 1.440777
# Train Epoch: 22 [57600/60000 (96%)]	Loss Char: 0.154320 Loss Font: 1.439383
#
# Test set: Accuracy Char : 9477/10000 (94.77%)
#           Accuracy Font : 3802/10000 (38.02%)
# Train Epoch: 23 [0/60000 (0%)]	Loss Char: 0.082067 Loss Font: 1.567823
# Train Epoch: 23 [6400/60000 (11%)]	Loss Char: 0.018711 Loss Font: 1.303775
# Train Epoch: 23 [12800/60000 (21%)]	Loss Char: 0.033431 Loss Font: 1.364101
# Train Epoch: 23 [19200/60000 (32%)]	Loss Char: 0.118486 Loss Font: 1.318456
# Train Epoch: 23 [25600/60000 (43%)]	Loss Char: 0.137154 Loss Font: 1.402416
# Train Epoch: 23 [32000/60000 (53%)]	Loss Char: 0.022608 Loss Font: 1.343752
# Train Epoch: 23 [38400/60000 (64%)]	Loss Char: 0.065241 Loss Font: 1.530892
# Train Epoch: 23 [44800/60000 (75%)]	Loss Char: 0.070221 Loss Font: 1.364359
# Train Epoch: 23 [51200/60000 (85%)]	Loss Char: 0.058129 Loss Font: 1.462995
# Train Epoch: 23 [57600/60000 (96%)]	Loss Char: 0.250981 Loss Font: 1.381272
#
# Test set: Accuracy Char : 9475/10000 (94.75%)
#           Accuracy Font : 3967/10000 (39.67%)
# Train Epoch: 24 [0/60000 (0%)]	Loss Char: 0.122645 Loss Font: 1.358527
# Train Epoch: 24 [6400/60000 (11%)]	Loss Char: 0.111557 Loss Font: 1.473693
# Train Epoch: 24 [12800/60000 (21%)]	Loss Char: 0.101518 Loss Font: 1.400663
# Train Epoch: 24 [19200/60000 (32%)]	Loss Char: 0.099207 Loss Font: 1.575611
# Train Epoch: 24 [25600/60000 (43%)]	Loss Char: 0.086675 Loss Font: 1.275623
# Train Epoch: 24 [32000/60000 (53%)]	Loss Char: 0.070052 Loss Font: 1.491791
# Train Epoch: 24 [38400/60000 (64%)]	Loss Char: 0.214287 Loss Font: 1.347712
# Train Epoch: 24 [44800/60000 (75%)]	Loss Char: 0.088577 Loss Font: 1.386079
# Train Epoch: 24 [51200/60000 (85%)]	Loss Char: 0.224288 Loss Font: 1.309510
# Train Epoch: 24 [57600/60000 (96%)]	Loss Char: 0.242757 Loss Font: 1.341276
#
# Test set: Accuracy Char : 9454/10000 (94.54%)
#           Accuracy Font : 4085/10000 (40.85%)
# Train Epoch: 25 [0/60000 (0%)]	Loss Char: 0.152539 Loss Font: 1.310840
# Train Epoch: 25 [6400/60000 (11%)]	Loss Char: 0.164890 Loss Font: 1.287427
# Train Epoch: 25 [12800/60000 (21%)]	Loss Char: 0.106193 Loss Font: 1.594961
# Train Epoch: 25 [19200/60000 (32%)]	Loss Char: 0.205138 Loss Font: 1.260309
# Train Epoch: 25 [25600/60000 (43%)]	Loss Char: 0.116945 Loss Font: 1.304143
# Train Epoch: 25 [32000/60000 (53%)]	Loss Char: 0.103781 Loss Font: 1.363048
# Train Epoch: 25 [38400/60000 (64%)]	Loss Char: 0.196208 Loss Font: 1.421915
# Train Epoch: 25 [44800/60000 (75%)]	Loss Char: 0.103102 Loss Font: 1.267457
# Train Epoch: 25 [51200/60000 (85%)]	Loss Char: 0.046122 Loss Font: 1.243568
# Train Epoch: 25 [57600/60000 (96%)]	Loss Char: 0.109478 Loss Font: 1.254928
#
# Test set: Accuracy Char : 9486/10000 (94.86%)
#           Accuracy Font : 4059/10000 (40.59%)
# Train Epoch: 26 [0/60000 (0%)]	Loss Char: 0.068416 Loss Font: 1.353766
# Train Epoch: 26 [6400/60000 (11%)]	Loss Char: 0.015975 Loss Font: 1.199581
# Train Epoch: 26 [12800/60000 (21%)]	Loss Char: 0.033366 Loss Font: 1.277087
# Train Epoch: 26 [19200/60000 (32%)]	Loss Char: 0.029179 Loss Font: 1.388490
# Train Epoch: 26 [25600/60000 (43%)]	Loss Char: 0.040969 Loss Font: 1.474471
# Train Epoch: 26 [32000/60000 (53%)]	Loss Char: 0.158225 Loss Font: 1.411462
# Train Epoch: 26 [38400/60000 (64%)]	Loss Char: 0.037689 Loss Font: 1.459346
# Train Epoch: 26 [44800/60000 (75%)]	Loss Char: 0.065041 Loss Font: 1.358325
# Train Epoch: 26 [51200/60000 (85%)]	Loss Char: 0.137933 Loss Font: 1.276141
# Train Epoch: 26 [57600/60000 (96%)]	Loss Char: 0.047992 Loss Font: 1.365027
#
# Test set: Accuracy Char : 9495/10000 (94.95%)
#           Accuracy Font : 4087/10000 (40.87%)
# ...
# Train Epoch: 12 [19200/60000 (32%)]	Loss Char: 0.342698 Loss Font: 1.613685
# Train Epoch: 12 [25600/60000 (43%)]	Loss Char: 0.207420 Loss Font: 1.535617
# Train Epoch: 12 [32000/60000 (53%)]	Loss Char: 0.075756 Loss Font: 1.546792
# Train Epoch: 12 [38400/60000 (64%)]	Loss Char: 0.223984 Loss Font: 1.598157
# Train Epoch: 12 [44800/60000 (75%)]	Loss Char: 0.278002 Loss Font: 1.576921
# Train Epoch: 12 [51200/60000 (85%)]	Loss Char: 0.161398 Loss Font: 1.566254
# Train Epoch: 12 [57600/60000 (96%)]	Loss Char: 0.301508 Loss Font: 1.600522
#
# Test set: Accuracy Char : 9048/10000 (90.48%)
#           Accuracy Font : 2600/10000 (26.00%)
# (perturbate)
# Train Epoch: 13 [0/60000 (0%)]	Loss Char: 0.314957 Loss Font: 1.649271
# Train Epoch: 13 [6400/60000 (11%)]	Loss Char: 0.328179 Loss Font: 1.568319
# Train Epoch: 13 [12800/60000 (21%)]	Loss Char: 0.122906 Loss Font: 1.559160
# Train Epoch: 13 [19200/60000 (32%)]	Loss Char: 0.266205 Loss Font: 1.508393
# Train Epoch: 13 [25600/60000 (43%)]	Loss Char: 0.197627 Loss Font: 1.516097
# Train Epoch: 13 [32000/60000 (53%)]	Loss Char: 0.162434 Loss Font: 1.577991
# Train Epoch: 13 [38400/60000 (64%)]	Loss Char: 0.294063 Loss Font: 1.529969
# Train Epoch: 13 [44800/60000 (75%)]	Loss Char: 0.155301 Loss Font: 1.557149
# Train Epoch: 13 [51200/60000 (85%)]	Loss Char: 0.125011 Loss Font: 1.542926
# Train Epoch: 13 [57600/60000 (96%)]	Loss Char: 0.383262 Loss Font: 1.574707
#
# Test set: Accuracy Char : 9080/10000 (90.80%)
#           Accuracy Font : 2531/10000 (25.31%)
# (perturbate)
# Train Epoch: 14 [0/60000 (0%)]	Loss Char: 0.278341 Loss Font: 1.526604
# Train Epoch: 14 [6400/60000 (11%)]	Loss Char: 0.135689 Loss Font: 1.577885
# Train Epoch: 14 [12800/60000 (21%)]	Loss Char: 0.158389 Loss Font: 1.580974
# Train Epoch: 14 [19200/60000 (32%)]	Loss Char: 0.272425 Loss Font: 1.529828
# Train Epoch: 14 [25600/60000 (43%)]	Loss Char: 0.140133 Loss Font: 1.579454
# Train Epoch: 14 [32000/60000 (53%)]	Loss Char: 0.248789 Loss Font: 1.571508
# Train Epoch: 14 [38400/60000 (64%)]	Loss Char: 0.136081 Loss Font: 1.607471
# Train Epoch: 14 [44800/60000 (75%)]	Loss Char: 0.165598 Loss Font: 1.594940
# Train Epoch: 14 [51200/60000 (85%)]	Loss Char: 0.171256 Loss Font: 1.567702
# Train Epoch: 14 [57600/60000 (96%)]	Loss Char: 0.218479 Loss Font: 1.565865
#
# Test set: Accuracy Char : 9198/10000 (91.98%)
#           Accuracy Font : 2595/10000 (25.95%)
# (perturbate)
# Train Epoch: 15 [0/60000 (0%)]	Loss Char: 0.255008 Loss Font: 1.527314
# Train Epoch: 15 [6400/60000 (11%)]	Loss Char: 0.188329 Loss Font: 1.558111
# Train Epoch: 15 [12800/60000 (21%)]	Loss Char: 0.131909 Loss Font: 1.539198
# Train Epoch: 15 [19200/60000 (32%)]	Loss Char: 0.105035 Loss Font: 1.576828
# Train Epoch: 15 [25600/60000 (43%)]	Loss Char: 0.163770 Loss Font: 1.594101
# Train Epoch: 15 [32000/60000 (53%)]	Loss Char: 0.374604 Loss Font: 1.559164
# Train Epoch: 15 [38400/60000 (64%)]	Loss Char: 0.144400 Loss Font: 1.635647
# Train Epoch: 15 [44800/60000 (75%)]	Loss Char: 0.179797 Loss Font: 1.551216
# Train Epoch: 15 [51200/60000 (85%)]	Loss Char: 0.365075 Loss Font: 1.529112
# Train Epoch: 15 [57600/60000 (96%)]	Loss Char: 0.140033 Loss Font: 1.620022
#
# Test set: Accuracy Char : 9038/10000 (90.38%)
#           Accuracy Font : 2540/10000 (25.40%)
# (perturbate)
# Train Epoch: 16 [0/60000 (0%)]	Loss Char: 0.136096 Loss Font: 1.600196
# Train Epoch: 16 [6400/60000 (11%)]	Loss Char: 0.222573 Loss Font: 1.613846
# Train Epoch: 16 [12800/60000 (21%)]	Loss Char: 0.135115 Loss Font: 1.569069
# Train Epoch: 16 [19200/60000 (32%)]	Loss Char: 0.152348 Loss Font: 1.549034
# Train Epoch: 16 [25600/60000 (43%)]	Loss Char: 0.197774 Loss Font: 1.559569
# Train Epoch: 16 [32000/60000 (53%)]	Loss Char: 0.087576 Loss Font: 1.553550
# Train Epoch: 16 [38400/60000 (64%)]	Loss Char: 0.194760 Loss Font: 1.538093
# Train Epoch: 16 [44800/60000 (75%)]	Loss Char: 0.083963 Loss Font: 1.561564
# Train Epoch: 16 [51200/60000 (85%)]	Loss Char: 0.143228 Loss Font: 1.564061
# Train Epoch: 16 [57600/60000 (96%)]	Loss Char: 0.205051 Loss Font: 1.596627
#
# Test set: Accuracy Char : 9083/10000 (90.83%)
#           Accuracy Font : 2592/10000 (25.92%)
# (perturbate)
# Train Epoch: 17 [0/60000 (0%)]	Loss Char: 0.070363 Loss Font: 1.562415
# Train Epoch: 17 [6400/60000 (11%)]	Loss Char: 0.056994 Loss Font: 1.600723
# Train Epoch: 17 [12800/60000 (21%)]	Loss Char: 0.172980 Loss Font: 1.542877
# Train Epoch: 17 [19200/60000 (32%)]	Loss Char: 0.101061 Loss Font: 1.571041
# Train Epoch: 17 [25600/60000 (43%)]	Loss Char: 0.205364 Loss Font: 1.545466
# Train Epoch: 17 [32000/60000 (53%)]	Loss Char: 0.234610 Loss Font: 1.616360
# Train Epoch: 17 [38400/60000 (64%)]	Loss Char: 0.245339 Loss Font: 1.571787
# Train Epoch: 17 [44800/60000 (75%)]	Loss Char: 0.113608 Loss Font: 1.522235
# Train Epoch: 17 [51200/60000 (85%)]	Loss Char: 0.150566 Loss Font: 1.512662
# Train Epoch: 17 [57600/60000 (96%)]	Loss Char: 0.202239 Loss Font: 1.576526
#
# Test set: Accuracy Char : 9169/10000 (91.69%)
#           Accuracy Font : 2683/10000 (26.83%)
# (perturbate)
# Train Epoch: 18 [0/60000 (0%)]	Loss Char: 0.198200 Loss Font: 1.586675
# Train Epoch: 18 [6400/60000 (11%)]	Loss Char: 0.146977 Loss Font: 1.572472
# Train Epoch: 18 [12800/60000 (21%)]	Loss Char: 0.153495 Loss Font: 1.541503
# Train Epoch: 18 [19200/60000 (32%)]	Loss Char: 0.227087 Loss Font: 1.575020
# Train Epoch: 18 [25600/60000 (43%)]	Loss Char: 0.096515 Loss Font: 1.506073
# Train Epoch: 18 [32000/60000 (53%)]	Loss Char: 0.186298 Loss Font: 1.609054
# Train Epoch: 18 [38400/60000 (64%)]	Loss Char: 0.066601 Loss Font: 1.561717
# Train Epoch: 18 [44800/60000 (75%)]	Loss Char: 0.067850 Loss Font: 1.551222
# Train Epoch: 18 [51200/60000 (85%)]	Loss Char: 0.074798 Loss Font: 1.573703
# Train Epoch: 18 [57600/60000 (96%)]	Loss Char: 0.298339 Loss Font: 1.578881
#
# Test set: Accuracy Char : 9182/10000 (91.82%)
#           Accuracy Font : 2582/10000 (25.82%)
# (perturbate)
# Train Epoch: 19 [0/60000 (0%)]	Loss Char: 0.189445 Loss Font: 1.567876
# Train Epoch: 19 [6400/60000 (11%)]	Loss Char: 0.218570 Loss Font: 1.547679
# Train Epoch: 19 [12800/60000 (21%)]	Loss Char: 0.234500 Loss Font: 1.572716
# Train Epoch: 19 [19200/60000 (32%)]	Loss Char: 0.201363 Loss Font: 1.586891
# Train Epoch: 19 [25600/60000 (43%)]	Loss Char: 0.327274 Loss Font: 1.568732
# Train Epoch: 19 [32000/60000 (53%)]	Loss Char: 0.188140 Loss Font: 1.559618
# Train Epoch: 19 [38400/60000 (64%)]	Loss Char: 0.178259 Loss Font: 1.551470
# Train Epoch: 19 [44800/60000 (75%)]	Loss Char: 0.121650 Loss Font: 1.570662
# Train Epoch: 19 [51200/60000 (85%)]	Loss Char: 0.191344 Loss Font: 1.607613
# Train Epoch: 19 [57600/60000 (96%)]	Loss Char: 0.080912 Loss Font: 1.598372
#
# Test set: Accuracy Char : 9148/10000 (91.48%)
#           Accuracy Font : 2555/10000 (25.55%)
# (perturbate)
# Train Epoch: 20 [0/60000 (0%)]	Loss Char: 0.145118 Loss Font: 1.626167
# Train Epoch: 20 [6400/60000 (11%)]	Loss Char: 0.222413 Loss Font: 1.600337
# Train Epoch: 20 [12800/60000 (21%)]	Loss Char: 0.220804 Loss Font: 1.574258
# Train Epoch: 20 [19200/60000 (32%)]	Loss Char: 0.174357 Loss Font: 1.631633
# Train Epoch: 20 [25600/60000 (43%)]	Loss Char: 0.234317 Loss Font: 1.560657
# Train Epoch: 20 [32000/60000 (53%)]	Loss Char: 0.127782 Loss Font: 1.568303
# Train Epoch: 20 [38400/60000 (64%)]	Loss Char: 0.080526 Loss Font: 1.609178
# Train Epoch: 20 [44800/60000 (75%)]	Loss Char: 0.055571 Loss Font: 1.607101
# Train Epoch: 20 [51200/60000 (85%)]	Loss Char: 0.403803 Loss Font: 1.543746
# Train Epoch: 20 [57600/60000 (96%)]	Loss Char: 0.054153 Loss Font: 1.546714
#
# Test set: Accuracy Char : 9191/10000 (91.91%)
#           Accuracy Font : 2571/10000 (25.71%)
# Train Epoch: 21 [0/60000 (0%)]	Loss Char: 0.113393 Loss Font: 1.634183
# Train Epoch: 21 [6400/60000 (11%)]	Loss Char: 0.120919 Loss Font: 1.616467
# Train Epoch: 21 [12800/60000 (21%)]	Loss Char: 0.241322 Loss Font: 1.555883
# Train Epoch: 21 [19200/60000 (32%)]	Loss Char: 0.115328 Loss Font: 1.610417
# Train Epoch: 21 [25600/60000 (43%)]	Loss Char: 0.327338 Loss Font: 1.539739
# Train Epoch: 21 [32000/60000 (53%)]	Loss Char: 0.107389 Loss Font: 1.530296
# Train Epoch: 21 [38400/60000 (64%)]	Loss Char: 0.165090 Loss Font: 1.543408
# Train Epoch: 21 [44800/60000 (75%)]	Loss Char: 0.257562 Loss Font: 1.514668
# Train Epoch: 21 [51200/60000 (85%)]	Loss Char: 0.172048 Loss Font: 1.530427
# Train Epoch: 21 [57600/60000 (96%)]	Loss Char: 0.206293 Loss Font: 1.602716
#
# Test set: Accuracy Char : 9238/10000 (92.38%)
#           Accuracy Font : 2625/10000 (26.25%)
# Train Epoch: 22 [0/60000 (0%)]	Loss Char: 0.219706 Loss Font: 1.616642
# Train Epoch: 22 [6400/60000 (11%)]	Loss Char: 0.369253 Loss Font: 1.602485
# Train Epoch: 22 [12800/60000 (21%)]	Loss Char: 0.118443 Loss Font: 1.606923
# Train Epoch: 22 [19200/60000 (32%)]	Loss Char: 0.148692 Loss Font: 1.586052
# Train Epoch: 22 [25600/60000 (43%)]	Loss Char: 0.060630 Loss Font: 1.588153
# Train Epoch: 22 [32000/60000 (53%)]	Loss Char: 0.111886 Loss Font: 1.589262
# Train Epoch: 22 [38400/60000 (64%)]	Loss Char: 0.119622 Loss Font: 1.520955
# Train Epoch: 22 [44800/60000 (75%)]	Loss Char: 0.063125 Loss Font: 1.621145
# Train Epoch: 22 [51200/60000 (85%)]	Loss Char: 0.123293 Loss Font: 1.593739
# Train Epoch: 22 [57600/60000 (96%)]	Loss Char: 0.244404 Loss Font: 1.573838
#
# Test set: Accuracy Char : 9242/10000 (92.42%)
#           Accuracy Font : 2658/10000 (26.58%)
# Train Epoch: 23 [0/60000 (0%)]	Loss Char: 0.180386 Loss Font: 1.639148
# Train Epoch: 23 [6400/60000 (11%)]	Loss Char: 0.060206 Loss Font: 1.558560
# Train Epoch: 23 [12800/60000 (21%)]	Loss Char: 0.158389 Loss Font: 1.557957
# Train Epoch: 23 [19200/60000 (32%)]	Loss Char: 0.148269 Loss Font: 1.572072
# Train Epoch: 23 [25600/60000 (43%)]	Loss Char: 0.119767 Loss Font: 1.562616
# Train Epoch: 23 [32000/60000 (53%)]	Loss Char: 0.079025 Loss Font: 1.551124
# Train Epoch: 23 [38400/60000 (64%)]	Loss Char: 0.160781 Loss Font: 1.621058
# Train Epoch: 23 [44800/60000 (75%)]	Loss Char: 0.083728 Loss Font: 1.583774
# Train Epoch: 23 [51200/60000 (85%)]	Loss Char: 0.117397 Loss Font: 1.569486
# Train Epoch: 23 [57600/60000 (96%)]	Loss Char: 0.269316 Loss Font: 1.557101
#
# Test set: Accuracy Char : 9258/10000 (92.58%)
#           Accuracy Font : 2692/10000 (26.92%)
# Train Epoch: 24 [0/60000 (0%)]	Loss Char: 0.193678 Loss Font: 1.557880
# Train Epoch: 24 [6400/60000 (11%)]	Loss Char: 0.136678 Loss Font: 1.594842
# Train Epoch: 24 [12800/60000 (21%)]	Loss Char: 0.160834 Loss Font: 1.614871
# Train Epoch: 24 [19200/60000 (32%)]	Loss Char: 0.152202 Loss Font: 1.653976
# Train Epoch: 24 [25600/60000 (43%)]	Loss Char: 0.299759 Loss Font: 1.529662
# Train Epoch: 24 [32000/60000 (53%)]	Loss Char: 0.256293 Loss Font: 1.596213
# Train Epoch: 24 [38400/60000 (64%)]	Loss Char: 0.267680 Loss Font: 1.585391
# Train Epoch: 24 [44800/60000 (75%)]	Loss Char: 0.252904 Loss Font: 1.549589
# Train Epoch: 24 [51200/60000 (85%)]	Loss Char: 0.319803 Loss Font: 1.596798
# Train Epoch: 24 [57600/60000 (96%)]	Loss Char: 0.374216 Loss Font: 1.519368
#
# Test set: Accuracy Char : 9246/10000 (92.46%)
#           Accuracy Font : 2827/10000 (28.27%)
# Train Epoch: 25 [0/60000 (0%)]	Loss Char: 0.423537 Loss Font: 1.621467
# Train Epoch: 25 [6400/60000 (11%)]	Loss Char: 0.253086 Loss Font: 1.542005
# Train Epoch: 25 [12800/60000 (21%)]	Loss Char: 0.142105 Loss Font: 1.638759
# Train Epoch: 25 [19200/60000 (32%)]	Loss Char: 0.282151 Loss Font: 1.542593
# Train Epoch: 25 [25600/60000 (43%)]	Loss Char: 0.227459 Loss Font: 1.482486
# Train Epoch: 25 [32000/60000 (53%)]	Loss Char: 0.305137 Loss Font: 1.570389
# Train Epoch: 25 [38400/60000 (64%)]	Loss Char: 0.352580 Loss Font: 1.569325
# Train Epoch: 25 [44800/60000 (75%)]	Loss Char: 0.235555 Loss Font: 1.581320
# Train Epoch: 25 [51200/60000 (85%)]	Loss Char: 0.193173 Loss Font: 1.507280
# Train Epoch: 25 [57600/60000 (96%)]	Loss Char: 0.230069 Loss Font: 1.544275
#
# Test set: Accuracy Char : 9295/10000 (92.95%)
#           Accuracy Font : 2935/10000 (29.35%)
# Train Epoch: 26 [0/60000 (0%)]	Loss Char: 0.133642 Loss Font: 1.535625
# Train Epoch: 26 [6400/60000 (11%)]	Loss Char: 0.047911 Loss Font: 1.488173
# Train Epoch: 26 [12800/60000 (21%)]	Loss Char: 0.121305 Loss Font: 1.469351
# Train Epoch: 26 [19200/60000 (32%)]	Loss Char: 0.086827 Loss Font: 1.580440
# Train Epoch: 26 [25600/60000 (43%)]	Loss Char: 0.142550 Loss Font: 1.566849
# Train Epoch: 26 [32000/60000 (53%)]	Loss Char: 0.186099 Loss Font: 1.549442
# Train Epoch: 26 [38400/60000 (64%)]	Loss Char: 0.102792 Loss Font: 1.555041
# Train Epoch: 26 [44800/60000 (75%)]	Loss Char: 0.165671 Loss Font: 1.609709
# Train Epoch: 26 [51200/60000 (85%)]	Loss Char: 0.238025 Loss Font: 1.423302
# Train Epoch: 26 [57600/60000 (96%)]	Loss Char: 0.050860 Loss Font: 1.509407
#
# Test set: Accuracy Char : 9263/10000 (92.63%)
#           Accuracy Font : 2935/10000 (29.35%)
# Train Epoch: 27 [0/60000 (0%)]	Loss Char: 0.240696 Loss Font: 1.583990
# Train Epoch: 27 [6400/60000 (11%)]	Loss Char: 0.347356 Loss Font: 1.520938
# Train Epoch: 27 [12800/60000 (21%)]	Loss Char: 0.071035 Loss Font: 1.487636
# Train Epoch: 27 [19200/60000 (32%)]	Loss Char: 0.109846 Loss Font: 1.528720
# Train Epoch: 27 [25600/60000 (43%)]	Loss Char: 0.078665 Loss Font: 1.529557
# Train Epoch: 27 [32000/60000 (53%)]	Loss Char: 0.086095 Loss Font: 1.476653
# Train Epoch: 27 [38400/60000 (64%)]	Loss Char: 0.137168 Loss Font: 1.522964
# Train Epoch: 27 [44800/60000 (75%)]	Loss Char: 0.163800 Loss Font: 1.531866
# Train Epoch: 27 [51200/60000 (85%)]	Loss Char: 0.105821 Loss Font: 1.564627
# Train Epoch: 27 [57600/60000 (96%)]	Loss Char: 0.058910 Loss Font: 1.481619
#
# Test set: Accuracy Char : 9262/10000 (92.62%)
#           Accuracy Font : 3033/10000 (30.33%)
# Train Epoch: 28 [0/60000 (0%)]	Loss Char: 0.239396 Loss Font: 1.543901
# Train Epoch: 28 [6400/60000 (11%)]	Loss Char: 0.229043 Loss Font: 1.583694
# Train Epoch: 28 [12800/60000 (21%)]	Loss Char: 0.387296 Loss Font: 1.544452
# Train Epoch: 28 [19200/60000 (32%)]	Loss Char: 0.215537 Loss Font: 1.493643
# Train Epoch: 28 [25600/60000 (43%)]	Loss Char: 0.072706 Loss Font: 1.562202
# Train Epoch: 28 [32000/60000 (53%)]	Loss Char: 0.288327 Loss Font: 1.532022
# Train Epoch: 28 [38400/60000 (64%)]	Loss Char: 0.113145 Loss Font: 1.521405
# Train Epoch: 28 [44800/60000 (75%)]	Loss Char: 0.120236 Loss Font: 1.562490
# Train Epoch: 28 [51200/60000 (85%)]	Loss Char: 0.116539 Loss Font: 1.529738
# Train Epoch: 28 [57600/60000 (96%)]	Loss Char: 0.157050 Loss Font: 1.484635
#
# Test set: Accuracy Char : 9287/10000 (92.87%)
#           Accuracy Font : 2959/10000 (29.59%)
# Train Epoch: 29 [0/60000 (0%)]	Loss Char: 0.142142 Loss Font: 1.506475
# Train Epoch: 29 [6400/60000 (11%)]	Loss Char: 0.139681 Loss Font: 1.518335
# Train Epoch: 29 [12800/60000 (21%)]	Loss Char: 0.108764 Loss Font: 1.494138
# Train Epoch: 29 [19200/60000 (32%)]	Loss Char: 0.182378 Loss Font: 1.596255
# Train Epoch: 29 [25600/60000 (43%)]	Loss Char: 0.232430 Loss Font: 1.546584
# Train Epoch: 29 [32000/60000 (53%)]	Loss Char: 0.097350 Loss Font: 1.542325
# Train Epoch: 29 [38400/60000 (64%)]	Loss Char: 0.147510 Loss Font: 1.568382
# Train Epoch: 29 [44800/60000 (75%)]	Loss Char: 0.283372 Loss Font: 1.553246
# Train Epoch: 29 [51200/60000 (85%)]	Loss Char: 0.176256 Loss Font: 1.558288
# Train Epoch: 29 [57600/60000 (96%)]	Loss Char: 0.253119 Loss Font: 1.534584
#
# Test set: Accuracy Char : 9260/10000 (92.60%)
#           Accuracy Font : 3055/10000 (30.55%)
# Train Epoch: 30 [0/60000 (0%)]	Loss Char: 0.337108 Loss Font: 1.502867
# Train Epoch: 30 [6400/60000 (11%)]	Loss Char: 0.169664 Loss Font: 1.613332
# Train Epoch: 30 [12800/60000 (21%)]	Loss Char: 0.353530 Loss Font: 1.471656
# Train Epoch: 30 [19200/60000 (32%)]	Loss Char: 0.247299 Loss Font: 1.522746
# Train Epoch: 30 [25600/60000 (43%)]	Loss Char: 0.156913 Loss Font: 1.549967
# Train Epoch: 30 [32000/60000 (53%)]	Loss Char: 0.135381 Loss Font: 1.566173
# Train Epoch: 30 [38400/60000 (64%)]	Loss Char: 0.172837 Loss Font: 1.622213
# Train Epoch: 30 [44800/60000 (75%)]	Loss Char: 0.189755 Loss Font: 1.514065
# Train Epoch: 30 [51200/60000 (85%)]	Loss Char: 0.314869 Loss Font: 1.516758
# Train Epoch: 30 [57600/60000 (96%)]	Loss Char: 0.252948 Loss Font: 1.580547
#
# Test set: Accuracy Char : 9286/10000 (92.86%)
#           Accuracy Font : 3062/10000 (30.62%)

# %%
main_results = {k:v for k, v in results.items() if 'Main' in k}
show_results(main_results, "The impact of perturbation with recovering phase on the main task", ymin=67, ymax=95)

# %%
collateral_results = {k:v for k, v in results.items() if 'Collateral' in k}
show_results(collateral_results, "The impact of perturbation with recovering phase on the collateral task", ymin=17, ymax=45)

# %% [markdown]
# We only distinguish the difference between phase 1 and 2, when we start perturbing Q against the collateral task; the recovering part is not clearly visible even if we observe that it helps recovering a bit of accuracy in the most perturbed settings.
# What we observe is that we achieve a far better trade-off than in Part 9. We assume that the training advantage of the tasks is similar to the one in Part 9, as we have given 30 epochs to improve, including 10 epochs for recovering.
# Indeed, while one of the best tradeoff was (34.9, 92.0) in the last part, we now claim to have (30.0, 93.5) !

# %% [markdown]
# We report the results for a better visualisation of the trade-off that we have now:

# %%
import matplotlib.pyplot as plt

main_scores = []
collateral_scores = []
for k, v in main_results.items():
    main_scores.append(v[-1])
for k, v in collateral_results.items():
    collateral_scores.append(v[-1])
    
alpha_values = [0] + alphas

fig, ax1 = plt.subplots(figsize=(8, 4))

ax1.plot(alpha_values, main_scores, 'b', label='Main Task accuracy')
ax1.set_xlabel('alpha')
ax1.set_ylabel('Main Task Accuracy in %')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(alpha_values, collateral_scores, 'r', label='Collateral Task accuracy')
ax2.set_ylabel('Collateral Task Accuracy in %')
ax2.tick_params('y', colors='r')

plt.title('Trade-off between the main and collateral tasks accuracies as a function of alpha')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
#
# This technique of joint optimisation gives us very interesting trade-offs. The next questions we can try to solve is to put other models on the private output, on the one hand more classic models as there are only 8 output values, and on the other hand more powerful neural networks to try to increase the ability of the collateral task to recover some information.

# %% [markdown]
# ## Task inversion
# For the sake of curiosity, we inverse the main and collateral tasks to see what the performance are. To this aim, all we have to do is overwrite the train function.

# %%
def train(args, model, train_loader, optimizer, epoch, alpha, initial_phase, perturbate):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # Split the two targets
        target_char = target[:, 0]
        target_font = target[:, 1]
        
        
        # Optimize C and F parts of the model with 2 strategies
        if initial_phase:  # Normal optimisation of F
            # Phase 1: Optimise Q + F
            optimizer.zero_grad()
            output_font = model.forward_font(data)
            loss_font = F.nll_loss(output_font, target_font)
            loss_font.backward()
            optimizer.step()
        else: # Freezed(Q) optimisation
            # Phase 1: Optimise Freezed(Q) + F
            model.freeze('quad')
            optimizer.zero_grad()
            output_font = model.forward_font(data)
            loss_font = F.nll_loss(output_font, target_font)
            loss_font.backward()
            optimizer.step()
            model.unfreeze()
        # Phase 2: Optimise Freezed(Q) + C
        model.freeze('quad')
        output_char = model.forward_char(data)
        loss_char = F.nll_loss(output_char, target_char)
        loss_char.backward()
        optimizer.step()
        model.unfreeze()
        
        if perturbate:
            # Optimize Q
            model.freeze('font')
            model.freeze('char')
            optimizer.zero_grad()
            output_font = model.forward_font(data)
            loss_font = F.nll_loss(output_font, target_font)
            
            output_char = model.forward_char(data)
            loss_char = F.nll_loss(output_char, target_char)

            loss = loss_font - alpha * loss_char
            loss.backward()
            optimizer.step()
            model.unfreeze()
        
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss Char: {:.6f} Loss Font: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                       100. * batch_idx / len(train_loader), loss_char.item(), loss_font.item()))

# %% [markdown]
# We reload the exact same function so that it uses the new train function.

# %%
def main(alpha=0):
    """
    Perform a learning phase
    """
    torch.manual_seed(1)
    args = Parser()

    data = load_data()
    train_data, train_target_char, train_target_family, test_data, test_target_char, test_target_family = data
    # Merge the target datasets
    train_target = list(zip(train_target_char, train_target_family))
    test_target = list(zip(test_target_char, test_target_family))

    # We use here the slightly modified version of this function
    train_dataset = build_tensor_dataset(train_data, train_target)
    test_dataset = build_tensor_dataset(test_data, test_target)

    train_loader = utils.DataLoader(
        train_dataset,
        batch_size=args.batch_size, shuffle=True
    )

    test_loader = utils.DataLoader(
        test_dataset,
        batch_size=args.test_batch_size, shuffle=True
    )
   
    model = QuadConvNet()

    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)
    
    test_perfs_char = []
    test_perfs_font = []
    
    for epoch in range(1, args.epochs + args.sabotage_epochs + args.recovering_epochs + 1):
        initial_phase = epoch <= args.epochs
        if initial_phase:
            print("(initial phase)")
        perturbate = epoch > args.epochs and epoch <= args.epochs + args.sabotage_epochs
        if perturbate:
            print("(perturbate)")
        train(args, model, train_loader, optimizer, epoch, alpha, initial_phase, perturbate)
        test_perf_char, test_perf_font = test(args, model, test_loader)
        test_perfs_char.append(test_perf_char)
        test_perfs_font.append(test_perf_font)

    return test_perfs_char, test_perfs_font, model

# %%
inverse_results = {}

# %%
alphas = [0, 0.05, 0.1, 0.2, 0.5, 0.7]
for alpha in alphas:
    test_perfs_char_perturbate, test_perfs_font_perturbate, model_perturbate = main(alpha=alpha)
    inverse_results[f"Main task with perturbation alpha={alpha}"] = test_perfs_font_perturbate
    inverse_results[f"Collateral task with perturbation alpha={alpha}"] = test_perfs_char_perturbate
# Out:
# Training set 60000 items
# Testing set  10000 items
# (initial phase)
# Train Epoch: 1 [0/60000 (0%)]	Loss Char: 3.241415 Loss Font: 1.619730
# Train Epoch: 1 [6400/60000 (11%)]	Loss Char: 3.263018 Loss Font: 1.628097
# Train Epoch: 1 [12800/60000 (21%)]	Loss Char: 3.270997 Loss Font: 1.615132
# Train Epoch: 1 [19200/60000 (32%)]	Loss Char: 3.281497 Loss Font: 1.534119
# Train Epoch: 1 [25600/60000 (43%)]	Loss Char: 3.349080 Loss Font: 1.546521
# Train Epoch: 1 [32000/60000 (53%)]	Loss Char: 3.284698 Loss Font: 1.494218
# Train Epoch: 1 [38400/60000 (64%)]	Loss Char: 3.259710 Loss Font: 1.492212
# Train Epoch: 1 [44800/60000 (75%)]	Loss Char: 3.317601 Loss Font: 1.396274
# Train Epoch: 1 [51200/60000 (85%)]	Loss Char: 3.308629 Loss Font: 1.472666
# Train Epoch: 1 [57600/60000 (96%)]	Loss Char: 3.221884 Loss Font: 1.405497
#
# Test set: Accuracy Char : 462/10000 (4.62%)
#           Accuracy Font : 4124/10000 (41.24%)
# (initial phase)
# Train Epoch: 2 [0/60000 (0%)]	Loss Char: 3.207519 Loss Font: 1.499060
# Train Epoch: 2 [6400/60000 (11%)]	Loss Char: 3.227783 Loss Font: 1.351040
# Train Epoch: 2 [12800/60000 (21%)]	Loss Char: 3.244180 Loss Font: 1.126336
# Train Epoch: 2 [19200/60000 (32%)]	Loss Char: 3.160681 Loss Font: 1.352572
# Train Epoch: 2 [25600/60000 (43%)]	Loss Char: 3.183574 Loss Font: 1.316568
# Train Epoch: 2 [32000/60000 (53%)]	Loss Char: 3.200935 Loss Font: 1.304667
# Train Epoch: 2 [38400/60000 (64%)]	Loss Char: 3.126493 Loss Font: 1.196334
# Train Epoch: 2 [44800/60000 (75%)]	Loss Char: 3.068561 Loss Font: 1.207792
# Train Epoch: 2 [51200/60000 (85%)]	Loss Char: 3.069199 Loss Font: 1.098197
# Train Epoch: 2 [57600/60000 (96%)]	Loss Char: 3.069148 Loss Font: 1.177299
#
# Test set: Accuracy Char : 954/10000 (9.54%)
#           Accuracy Font : 5099/10000 (50.99%)
# (initial phase)
# Train Epoch: 3 [0/60000 (0%)]	Loss Char: 3.085202 Loss Font: 1.182961
# Train Epoch: 3 [6400/60000 (11%)]	Loss Char: 3.090423 Loss Font: 1.219852
# Train Epoch: 3 [12800/60000 (21%)]	Loss Char: 3.231507 Loss Font: 1.031398
# Train Epoch: 3 [19200/60000 (32%)]	Loss Char: 3.073160 Loss Font: 1.208520
# Train Epoch: 3 [25600/60000 (43%)]	Loss Char: 2.988332 Loss Font: 1.189705
# Train Epoch: 3 [32000/60000 (53%)]	Loss Char: 2.901659 Loss Font: 1.080075
# Train Epoch: 3 [38400/60000 (64%)]	Loss Char: 2.989711 Loss Font: 1.171021
# Train Epoch: 3 [44800/60000 (75%)]	Loss Char: 3.099116 Loss Font: 1.074513
# Train Epoch: 3 [51200/60000 (85%)]	Loss Char: 2.864553 Loss Font: 1.184706
# Train Epoch: 3 [57600/60000 (96%)]	Loss Char: 3.023208 Loss Font: 1.114001
#
# Test set: Accuracy Char : 1338/10000 (13.38%)
#           Accuracy Font : 5418/10000 (54.18%)
# (initial phase)
# Train Epoch: 4 [0/60000 (0%)]	Loss Char: 2.997872 Loss Font: 1.056815
# Train Epoch: 4 [6400/60000 (11%)]	Loss Char: 2.766458 Loss Font: 0.938360
# Train Epoch: 4 [12800/60000 (21%)]	Loss Char: 2.856854 Loss Font: 1.108281
# Train Epoch: 4 [19200/60000 (32%)]	Loss Char: 2.844776 Loss Font: 1.174923
# Train Epoch: 4 [25600/60000 (43%)]	Loss Char: 2.980901 Loss Font: 1.038894
# Train Epoch: 4 [32000/60000 (53%)]	Loss Char: 2.813131 Loss Font: 0.876292
# Train Epoch: 4 [38400/60000 (64%)]	Loss Char: 2.772401 Loss Font: 1.051256
# Train Epoch: 4 [44800/60000 (75%)]	Loss Char: 2.805861 Loss Font: 1.053291
# Train Epoch: 4 [51200/60000 (85%)]	Loss Char: 2.687517 Loss Font: 1.004375
# Train Epoch: 4 [57600/60000 (96%)]	Loss Char: 2.827705 Loss Font: 1.039387
#
# Test set: Accuracy Char : 1863/10000 (18.63%)
#           Accuracy Font : 5900/10000 (59.00%)
# (initial phase)
# Train Epoch: 5 [0/60000 (0%)]	Loss Char: 2.616552 Loss Font: 0.869547
# Train Epoch: 5 [6400/60000 (11%)]	Loss Char: 2.644687 Loss Font: 0.986470
# Train Epoch: 5 [12800/60000 (21%)]	Loss Char: 2.518281 Loss Font: 0.940778
# Train Epoch: 5 [19200/60000 (32%)]	Loss Char: 2.427081 Loss Font: 0.906559
# Train Epoch: 5 [25600/60000 (43%)]	Loss Char: 2.556287 Loss Font: 0.843067
# Train Epoch: 5 [32000/60000 (53%)]	Loss Char: 2.548599 Loss Font: 1.017592
# Train Epoch: 5 [38400/60000 (64%)]	Loss Char: 2.713661 Loss Font: 0.860155
# Train Epoch: 5 [44800/60000 (75%)]	Loss Char: 2.534139 Loss Font: 0.918040
# Train Epoch: 5 [51200/60000 (85%)]	Loss Char: 2.454515 Loss Font: 0.968704
# Train Epoch: 5 [57600/60000 (96%)]	Loss Char: 2.538097 Loss Font: 0.760653
#
# Test set: Accuracy Char : 2362/10000 (23.62%)
#           Accuracy Font : 6107/10000 (61.07%)
# (initial phase)
# Train Epoch: 6 [0/60000 (0%)]	Loss Char: 2.505681 Loss Font: 0.851479
# Train Epoch: 6 [6400/60000 (11%)]	Loss Char: 2.622647 Loss Font: 0.953182
# Train Epoch: 6 [12800/60000 (21%)]	Loss Char: 2.519301 Loss Font: 0.852091
# Train Epoch: 6 [19200/60000 (32%)]	Loss Char: 2.397657 Loss Font: 0.935180
# Train Epoch: 6 [25600/60000 (43%)]	Loss Char: 2.364400 Loss Font: 0.855711
# Train Epoch: 6 [32000/60000 (53%)]	Loss Char: 2.441684 Loss Font: 0.931718
# Train Epoch: 6 [38400/60000 (64%)]	Loss Char: 2.481534 Loss Font: 0.927142
# Train Epoch: 6 [44800/60000 (75%)]	Loss Char: 2.374841 Loss Font: 0.736201
# Train Epoch: 6 [51200/60000 (85%)]	Loss Char: 2.344272 Loss Font: 1.069886
# Train Epoch: 6 [57600/60000 (96%)]	Loss Char: 2.421772 Loss Font: 0.756299
#
# Test set: Accuracy Char : 2686/10000 (26.86%)
#           Accuracy Font : 6144/10000 (61.44%)
# (initial phase)
# Train Epoch: 7 [0/60000 (0%)]	Loss Char: 2.429507 Loss Font: 0.824293
# Train Epoch: 7 [6400/60000 (11%)]	Loss Char: 2.644153 Loss Font: 0.761268
# Train Epoch: 7 [12800/60000 (21%)]	Loss Char: 2.281783 Loss Font: 0.928055
# Train Epoch: 7 [19200/60000 (32%)]	Loss Char: 2.308526 Loss Font: 1.001602
# Train Epoch: 7 [25600/60000 (43%)]	Loss Char: 2.077121 Loss Font: 0.836495
# Train Epoch: 7 [32000/60000 (53%)]	Loss Char: 2.209131 Loss Font: 0.970984
# Train Epoch: 7 [38400/60000 (64%)]	Loss Char: 2.254699 Loss Font: 0.815222
# Train Epoch: 7 [44800/60000 (75%)]	Loss Char: 2.416778 Loss Font: 0.908124
# Train Epoch: 7 [51200/60000 (85%)]	Loss Char: 2.498140 Loss Font: 0.867565
# Train Epoch: 7 [57600/60000 (96%)]	Loss Char: 2.277665 Loss Font: 0.830104
#
# Test set: Accuracy Char : 2900/10000 (29.00%)
#           Accuracy Font : 6344/10000 (63.44%)
# (initial phase)
# Train Epoch: 8 [0/60000 (0%)]	Loss Char: 2.176007 Loss Font: 0.673463
# Train Epoch: 8 [6400/60000 (11%)]	Loss Char: 2.386080 Loss Font: 0.789331
# Train Epoch: 8 [12800/60000 (21%)]	Loss Char: 2.382780 Loss Font: 0.861489
# Train Epoch: 8 [19200/60000 (32%)]	Loss Char: 2.092609 Loss Font: 0.735713
# Train Epoch: 8 [25600/60000 (43%)]	Loss Char: 2.175648 Loss Font: 0.859557
# Train Epoch: 8 [32000/60000 (53%)]	Loss Char: 2.181084 Loss Font: 0.933011
# Train Epoch: 8 [38400/60000 (64%)]	Loss Char: 2.245403 Loss Font: 0.827092
# Train Epoch: 8 [44800/60000 (75%)]	Loss Char: 2.158715 Loss Font: 0.640619
# Train Epoch: 8 [51200/60000 (85%)]	Loss Char: 2.217150 Loss Font: 0.633119
# Train Epoch: 8 [57600/60000 (96%)]	Loss Char: 2.370155 Loss Font: 0.823836
#
# Test set: Accuracy Char : 3200/10000 (32.00%)
#           Accuracy Font : 6599/10000 (65.99%)
# (initial phase)
# Train Epoch: 9 [0/60000 (0%)]	Loss Char: 2.256904 Loss Font: 0.710445
# Train Epoch: 9 [6400/60000 (11%)]	Loss Char: 2.314316 Loss Font: 0.781568
# Train Epoch: 9 [12800/60000 (21%)]	Loss Char: 2.096962 Loss Font: 0.753784
# Train Epoch: 9 [19200/60000 (32%)]	Loss Char: 2.145629 Loss Font: 0.771372
# Train Epoch: 9 [25600/60000 (43%)]	Loss Char: 2.301601 Loss Font: 0.746959
# Train Epoch: 9 [32000/60000 (53%)]	Loss Char: 2.279788 Loss Font: 0.838071
# Train Epoch: 9 [38400/60000 (64%)]	Loss Char: 1.999935 Loss Font: 0.774363
# Train Epoch: 9 [44800/60000 (75%)]	Loss Char: 2.207775 Loss Font: 0.683812
# Train Epoch: 9 [51200/60000 (85%)]	Loss Char: 2.213757 Loss Font: 0.800260
# Train Epoch: 9 [57600/60000 (96%)]	Loss Char: 2.356125 Loss Font: 0.719768
#
# Test set: Accuracy Char : 3111/10000 (31.11%)
#           Accuracy Font : 6548/10000 (65.48%)
# (initial phase)
# Train Epoch: 10 [0/60000 (0%)]	Loss Char: 2.104309 Loss Font: 0.723060
# Train Epoch: 10 [6400/60000 (11%)]	Loss Char: 1.979629 Loss Font: 0.776139
# Train Epoch: 10 [12800/60000 (21%)]	Loss Char: 2.385142 Loss Font: 0.789376
# Train Epoch: 10 [19200/60000 (32%)]	Loss Char: 1.798293 Loss Font: 0.702201
# Train Epoch: 10 [25600/60000 (43%)]	Loss Char: 2.133091 Loss Font: 0.690897
# Train Epoch: 10 [32000/60000 (53%)]	Loss Char: 2.094879 Loss Font: 0.713692
# Train Epoch: 10 [38400/60000 (64%)]	Loss Char: 2.261243 Loss Font: 0.997405
# Train Epoch: 10 [44800/60000 (75%)]	Loss Char: 2.067286 Loss Font: 0.733459
# Train Epoch: 10 [51200/60000 (85%)]	Loss Char: 2.040209 Loss Font: 0.669155
# Train Epoch: 10 [57600/60000 (96%)]	Loss Char: 1.855520 Loss Font: 0.698910
#
# Test set: Accuracy Char : 3348/10000 (33.48%)
#           Accuracy Font : 6491/10000 (64.91%)
# (perturbate)
# Train Epoch: 11 [0/60000 (0%)]	Loss Char: 1.911289 Loss Font: 0.972825
# Train Epoch: 11 [6400/60000 (11%)]	Loss Char: 1.858711 Loss Font: 0.667871
# Train Epoch: 11 [12800/60000 (21%)]	Loss Char: 1.849734 Loss Font: 0.621311
# Train Epoch: 11 [19200/60000 (32%)]	Loss Char: 2.078959 Loss Font: 0.840889
# Train Epoch: 11 [25600/60000 (43%)]	Loss Char: 2.186903 Loss Font: 0.680580
# Train Epoch: 11 [32000/60000 (53%)]	Loss Char: 2.255265 Loss Font: 0.804533
# Train Epoch: 11 [38400/60000 (64%)]	Loss Char: 2.381123 Loss Font: 0.641462
# Train Epoch: 11 [44800/60000 (75%)]	Loss Char: 2.302402 Loss Font: 0.670824
# Train Epoch: 11 [51200/60000 (85%)]	Loss Char: 2.364986 Loss Font: 0.647432
# Train Epoch: 11 [57600/60000 (96%)]	Loss Char: 2.195852 Loss Font: 0.617262
#
# Test set: Accuracy Char : 2681/10000 (26.81%)
#           Accuracy Font : 6848/10000 (68.48%)
# (perturbate)
# Train Epoch: 12 [0/60000 (0%)]	Loss Char: 2.327545 Loss Font: 0.799542
# Train Epoch: 12 [6400/60000 (11%)]	Loss Char: 2.169801 Loss Font: 0.608053
# Train Epoch: 12 [12800/60000 (21%)]	Loss Char: 2.468490 Loss Font: 0.489991
# Train Epoch: 12 [19200/60000 (32%)]	Loss Char: 2.358400 Loss Font: 0.628754
# Train Epoch: 12 [25600/60000 (43%)]	Loss Char: 2.203063 Loss Font: 0.683322
# Train Epoch: 12 [32000/60000 (53%)]	Loss Char: 2.249090 Loss Font: 0.611297
# Train Epoch: 12 [38400/60000 (64%)]	Loss Char: 2.610742 Loss Font: 0.800437
# Train Epoch: 12 [44800/60000 (75%)]	Loss Char: 2.294311 Loss Font: 0.612188
# Train Epoch: 12 [51200/60000 (85%)]	Loss Char: 2.522165 Loss Font: 0.586325
# Train Epoch: 12 [57600/60000 (96%)]	Loss Char: 2.311955 Loss Font: 0.762142
#
# Test set: Accuracy Char : 2597/10000 (25.97%)
#           Accuracy Font : 6934/10000 (69.34%)
# (perturbate)
# Train Epoch: 13 [0/60000 (0%)]	Loss Char: 2.420884 Loss Font: 0.865161
# Train Epoch: 13 [6400/60000 (11%)]	Loss Char: 2.187857 Loss Font: 0.952787
# Train Epoch: 13 [12800/60000 (21%)]	Loss Char: 2.310231 Loss Font: 0.527524
# Train Epoch: 13 [19200/60000 (32%)]	Loss Char: 2.518913 Loss Font: 0.751620
# Train Epoch: 13 [25600/60000 (43%)]	Loss Char: 2.237348 Loss Font: 0.550422
# Train Epoch: 13 [32000/60000 (53%)]	Loss Char: 2.521365 Loss Font: 0.631236
# Train Epoch: 13 [38400/60000 (64%)]	Loss Char: 2.361718 Loss Font: 0.630735
# Train Epoch: 13 [44800/60000 (75%)]	Loss Char: 2.375987 Loss Font: 0.739729
# Train Epoch: 13 [51200/60000 (85%)]	Loss Char: 2.333684 Loss Font: 0.590895
# Train Epoch: 13 [57600/60000 (96%)]	Loss Char: 2.372567 Loss Font: 0.601636
#
# Test set: Accuracy Char : 2649/10000 (26.49%)
#           Accuracy Font : 6896/10000 (68.96%)
# (perturbate)
# Train Epoch: 14 [0/60000 (0%)]	Loss Char: 2.391267 Loss Font: 0.634392
# Train Epoch: 14 [6400/60000 (11%)]	Loss Char: 2.440555 Loss Font: 0.698381
# Train Epoch: 14 [12800/60000 (21%)]	Loss Char: 2.349268 Loss Font: 0.561286
# Train Epoch: 14 [19200/60000 (32%)]	Loss Char: 2.338480 Loss Font: 0.557369
# Train Epoch: 14 [25600/60000 (43%)]	Loss Char: 2.441807 Loss Font: 0.488750
# Train Epoch: 14 [32000/60000 (53%)]	Loss Char: 2.476426 Loss Font: 0.600462
# Train Epoch: 14 [38400/60000 (64%)]	Loss Char: 2.138079 Loss Font: 0.506580
# Train Epoch: 14 [44800/60000 (75%)]	Loss Char: 2.272870 Loss Font: 0.710078
# Train Epoch: 14 [51200/60000 (85%)]	Loss Char: 2.152198 Loss Font: 0.529191
# Train Epoch: 14 [57600/60000 (96%)]	Loss Char: 2.167339 Loss Font: 1.067781
#
# Test set: Accuracy Char : 2581/10000 (25.81%)
#           Accuracy Font : 6899/10000 (68.99%)
# (perturbate)
# Train Epoch: 15 [0/60000 (0%)]	Loss Char: 2.262684 Loss Font: 0.784320
# Train Epoch: 15 [6400/60000 (11%)]	Loss Char: 2.242764 Loss Font: 0.606478
# Train Epoch: 15 [12800/60000 (21%)]	Loss Char: 2.352039 Loss Font: 0.590868
# Train Epoch: 15 [19200/60000 (32%)]	Loss Char: 2.161631 Loss Font: 0.643552
# Train Epoch: 15 [25600/60000 (43%)]	Loss Char: 2.269992 Loss Font: 0.481430
# Train Epoch: 15 [32000/60000 (53%)]	Loss Char: 2.398078 Loss Font: 0.838049
# Train Epoch: 15 [38400/60000 (64%)]	Loss Char: 2.254031 Loss Font: 0.608152
# Train Epoch: 15 [44800/60000 (75%)]	Loss Char: 2.269848 Loss Font: 0.652778
# Train Epoch: 15 [51200/60000 (85%)]	Loss Char: 2.378856 Loss Font: 0.788716
# Train Epoch: 15 [57600/60000 (96%)]	Loss Char: 2.129863 Loss Font: 0.699687
#
# Test set: Accuracy Char : 2646/10000 (26.46%)
#           Accuracy Font : 6978/10000 (69.78%)
# (perturbate)
# Train Epoch: 16 [0/60000 (0%)]	Loss Char: 2.329542 Loss Font: 0.574748
# Train Epoch: 16 [6400/60000 (11%)]	Loss Char: 2.310703 Loss Font: 0.600541
# Train Epoch: 16 [12800/60000 (21%)]	Loss Char: 2.505395 Loss Font: 0.531757
# Train Epoch: 16 [19200/60000 (32%)]	Loss Char: 2.354037 Loss Font: 0.845987
# Train Epoch: 16 [25600/60000 (43%)]	Loss Char: 2.562438 Loss Font: 0.706809
# Train Epoch: 16 [32000/60000 (53%)]	Loss Char: 2.360333 Loss Font: 0.777545
# Train Epoch: 16 [38400/60000 (64%)]	Loss Char: 2.363598 Loss Font: 0.750394
# Train Epoch: 16 [44800/60000 (75%)]	Loss Char: 2.096885 Loss Font: 0.612831
# Train Epoch: 16 [51200/60000 (85%)]	Loss Char: 2.189023 Loss Font: 0.595988
# Train Epoch: 16 [57600/60000 (96%)]	Loss Char: 2.446066 Loss Font: 0.640989
#
# Test set: Accuracy Char : 2656/10000 (26.56%)
#           Accuracy Font : 6970/10000 (69.70%)
# (perturbate)
# Train Epoch: 17 [0/60000 (0%)]	Loss Char: 2.503534 Loss Font: 0.589852
# Train Epoch: 17 [6400/60000 (11%)]	Loss Char: 2.293588 Loss Font: 0.674880
# Train Epoch: 17 [12800/60000 (21%)]	Loss Char: 2.377717 Loss Font: 0.748961
# Train Epoch: 17 [19200/60000 (32%)]	Loss Char: 2.338847 Loss Font: 0.902917
# Train Epoch: 17 [25600/60000 (43%)]	Loss Char: 2.412808 Loss Font: 0.631250
# Train Epoch: 17 [32000/60000 (53%)]	Loss Char: 2.449840 Loss Font: 0.645768
# Train Epoch: 17 [38400/60000 (64%)]	Loss Char: 2.170341 Loss Font: 0.529410
# Train Epoch: 17 [44800/60000 (75%)]	Loss Char: 2.085835 Loss Font: 0.596542
# Train Epoch: 17 [51200/60000 (85%)]	Loss Char: 2.470880 Loss Font: 0.693655
# Train Epoch: 17 [57600/60000 (96%)]	Loss Char: 2.112518 Loss Font: 0.602951
#
# Test set: Accuracy Char : 2592/10000 (25.92%)
#           Accuracy Font : 6991/10000 (69.91%)
# (perturbate)
# Train Epoch: 18 [0/60000 (0%)]	Loss Char: 2.085569 Loss Font: 0.597754
# Train Epoch: 18 [6400/60000 (11%)]	Loss Char: 2.482334 Loss Font: 0.631128
# Train Epoch: 18 [12800/60000 (21%)]	Loss Char: 2.588640 Loss Font: 0.555443
# Train Epoch: 18 [19200/60000 (32%)]	Loss Char: 2.387052 Loss Font: 0.617891
# Train Epoch: 18 [25600/60000 (43%)]	Loss Char: 2.374111 Loss Font: 0.676105
# Train Epoch: 18 [32000/60000 (53%)]	Loss Char: 2.288964 Loss Font: 0.473950
# Train Epoch: 18 [38400/60000 (64%)]	Loss Char: 2.488261 Loss Font: 0.460454
# Train Epoch: 18 [44800/60000 (75%)]	Loss Char: 2.362130 Loss Font: 0.664602
# Train Epoch: 18 [51200/60000 (85%)]	Loss Char: 2.322041 Loss Font: 0.510483
# Train Epoch: 18 [57600/60000 (96%)]	Loss Char: 2.250108 Loss Font: 0.554254
#
# Test set: Accuracy Char : 2597/10000 (25.97%)
#           Accuracy Font : 7051/10000 (70.51%)
# (perturbate)
# Train Epoch: 19 [0/60000 (0%)]	Loss Char: 2.183157 Loss Font: 0.825656
# Train Epoch: 19 [6400/60000 (11%)]	Loss Char: 2.469967 Loss Font: 0.507443
# Train Epoch: 19 [12800/60000 (21%)]	Loss Char: 2.470200 Loss Font: 0.522400
# Train Epoch: 19 [19200/60000 (32%)]	Loss Char: 2.232604 Loss Font: 0.764330
# Train Epoch: 19 [25600/60000 (43%)]	Loss Char: 2.131697 Loss Font: 0.516642
# Train Epoch: 19 [32000/60000 (53%)]	Loss Char: 2.167452 Loss Font: 0.751999
# Train Epoch: 19 [38400/60000 (64%)]	Loss Char: 2.267088 Loss Font: 0.714516
# Train Epoch: 19 [44800/60000 (75%)]	Loss Char: 2.477823 Loss Font: 0.806992
# Train Epoch: 19 [51200/60000 (85%)]	Loss Char: 2.206064 Loss Font: 0.640557
# Train Epoch: 19 [57600/60000 (96%)]	Loss Char: 2.209480 Loss Font: 0.556622
#
# Test set: Accuracy Char : 2624/10000 (26.24%)
#           Accuracy Font : 7008/10000 (70.08%)
# (perturbate)
# Train Epoch: 20 [0/60000 (0%)]	Loss Char: 2.419453 Loss Font: 0.500511
# Train Epoch: 20 [6400/60000 (11%)]	Loss Char: 2.390781 Loss Font: 0.683833
# Train Epoch: 20 [12800/60000 (21%)]	Loss Char: 2.349296 Loss Font: 0.599779
# Train Epoch: 20 [19200/60000 (32%)]	Loss Char: 2.291671 Loss Font: 0.575469
# Train Epoch: 20 [25600/60000 (43%)]	Loss Char: 2.526794 Loss Font: 0.479464
# Train Epoch: 20 [32000/60000 (53%)]	Loss Char: 2.174864 Loss Font: 0.505703
# Train Epoch: 20 [38400/60000 (64%)]	Loss Char: 2.250866 Loss Font: 0.591691
# Train Epoch: 20 [44800/60000 (75%)]	Loss Char: 2.286704 Loss Font: 0.553469
# Train Epoch: 20 [51200/60000 (85%)]	Loss Char: 2.290635 Loss Font: 0.629314
# Train Epoch: 20 [57600/60000 (96%)]	Loss Char: 2.266487 Loss Font: 0.589982
#
# Test set: Accuracy Char : 2615/10000 (26.15%)
#           Accuracy Font : 7129/10000 (71.29%)
# Train Epoch: 21 [0/60000 (0%)]	Loss Char: 2.299906 Loss Font: 0.641012
# Train Epoch: 21 [6400/60000 (11%)]	Loss Char: 2.416835 Loss Font: 0.492827
# Train Epoch: 21 [12800/60000 (21%)]	Loss Char: 2.325278 Loss Font: 0.659033
# Train Epoch: 21 [19200/60000 (32%)]	Loss Char: 2.288440 Loss Font: 0.496417
# Train Epoch: 21 [25600/60000 (43%)]	Loss Char: 2.391472 Loss Font: 0.609156
# Train Epoch: 21 [32000/60000 (53%)]	Loss Char: 2.345547 Loss Font: 0.655058
# Train Epoch: 21 [38400/60000 (64%)]	Loss Char: 2.468090 Loss Font: 0.669597
# Train Epoch: 21 [44800/60000 (75%)]	Loss Char: 2.158013 Loss Font: 0.459681
# Train Epoch: 21 [51200/60000 (85%)]	Loss Char: 2.146584 Loss Font: 0.619576
# Train Epoch: 21 [57600/60000 (96%)]	Loss Char: 2.222202 Loss Font: 0.404338
#
# Test set: Accuracy Char : 2688/10000 (26.88%)
#           Accuracy Font : 7100/10000 (71.00%)
# Train Epoch: 22 [0/60000 (0%)]	Loss Char: 2.170444 Loss Font: 0.493652
# Train Epoch: 22 [6400/60000 (11%)]	Loss Char: 2.546468 Loss Font: 0.632066
# Train Epoch: 22 [12800/60000 (21%)]	Loss Char: 2.328992 Loss Font: 0.591134
# Train Epoch: 22 [19200/60000 (32%)]	Loss Char: 2.324123 Loss Font: 0.636802
# Train Epoch: 22 [25600/60000 (43%)]	Loss Char: 2.102218 Loss Font: 0.625149
# Train Epoch: 22 [32000/60000 (53%)]	Loss Char: 2.392285 Loss Font: 0.600740
# Train Epoch: 22 [38400/60000 (64%)]	Loss Char: 2.170621 Loss Font: 0.460637
# Train Epoch: 22 [44800/60000 (75%)]	Loss Char: 2.652177 Loss Font: 0.580340
# Train Epoch: 22 [51200/60000 (85%)]	Loss Char: 2.359885 Loss Font: 0.675907
# Train Epoch: 22 [57600/60000 (96%)]	Loss Char: 2.371052 Loss Font: 0.589926
#
# Test set: Accuracy Char : 2706/10000 (27.06%)
#           Accuracy Font : 7120/10000 (71.20%)
# Train Epoch: 23 [0/60000 (0%)]	Loss Char: 2.398352 Loss Font: 0.632605
# Train Epoch: 23 [6400/60000 (11%)]	Loss Char: 2.108191 Loss Font: 0.554273
# Train Epoch: 23 [12800/60000 (21%)]	Loss Char: 2.303243 Loss Font: 0.556374
# Train Epoch: 23 [19200/60000 (32%)]	Loss Char: 2.301530 Loss Font: 0.647206
# Train Epoch: 23 [25600/60000 (43%)]	Loss Char: 2.358254 Loss Font: 0.660613
# Train Epoch: 23 [32000/60000 (53%)]	Loss Char: 2.176841 Loss Font: 0.464373
# Train Epoch: 23 [38400/60000 (64%)]	Loss Char: 2.232867 Loss Font: 0.452714
# Train Epoch: 23 [44800/60000 (75%)]	Loss Char: 2.136244 Loss Font: 0.663770
# Train Epoch: 23 [51200/60000 (85%)]	Loss Char: 2.283586 Loss Font: 0.611673
# Train Epoch: 23 [57600/60000 (96%)]	Loss Char: 2.091484 Loss Font: 0.464630
#
# Test set: Accuracy Char : 2755/10000 (27.55%)
#           Accuracy Font : 7043/10000 (70.43%)
# Train Epoch: 24 [0/60000 (0%)]	Loss Char: 2.404753 Loss Font: 0.525185
# Train Epoch: 24 [6400/60000 (11%)]	Loss Char: 2.212844 Loss Font: 0.535149
# Train Epoch: 24 [12800/60000 (21%)]	Loss Char: 2.515248 Loss Font: 0.533710
# Train Epoch: 24 [19200/60000 (32%)]	Loss Char: 2.010221 Loss Font: 0.611271
# Train Epoch: 24 [25600/60000 (43%)]	Loss Char: 2.226632 Loss Font: 0.451869
# Train Epoch: 24 [32000/60000 (53%)]	Loss Char: 2.153780 Loss Font: 0.537673
# Train Epoch: 24 [38400/60000 (64%)]	Loss Char: 2.317788 Loss Font: 0.794333
# Train Epoch: 24 [44800/60000 (75%)]	Loss Char: 2.330438 Loss Font: 0.518713
# Train Epoch: 24 [51200/60000 (85%)]	Loss Char: 2.475783 Loss Font: 0.678793
# Train Epoch: 24 [57600/60000 (96%)]	Loss Char: 2.300829 Loss Font: 0.569250
#
# Test set: Accuracy Char : 2743/10000 (27.43%)
#           Accuracy Font : 7126/10000 (71.26%)
# Train Epoch: 25 [0/60000 (0%)]	Loss Char: 2.344763 Loss Font: 0.633776
# Train Epoch: 25 [6400/60000 (11%)]	Loss Char: 2.220480 Loss Font: 0.653627
# Train Epoch: 25 [12800/60000 (21%)]	Loss Char: 2.119892 Loss Font: 0.462597
# Train Epoch: 25 [19200/60000 (32%)]	Loss Char: 2.230413 Loss Font: 0.440235
# Train Epoch: 25 [25600/60000 (43%)]	Loss Char: 2.175431 Loss Font: 0.441347
# Train Epoch: 25 [32000/60000 (53%)]	Loss Char: 2.323238 Loss Font: 0.552396
# Train Epoch: 25 [38400/60000 (64%)]	Loss Char: 2.261382 Loss Font: 0.480750
# Train Epoch: 25 [44800/60000 (75%)]	Loss Char: 2.235409 Loss Font: 0.566277
# Train Epoch: 25 [51200/60000 (85%)]	Loss Char: 2.484011 Loss Font: 0.582973
# Train Epoch: 25 [57600/60000 (96%)]	Loss Char: 2.392629 Loss Font: 0.592740
#
# Test set: Accuracy Char : 2793/10000 (27.93%)
#           Accuracy Font : 7113/10000 (71.13%)
# Train Epoch: 26 [0/60000 (0%)]	Loss Char: 2.166723 Loss Font: 0.610215
# Train Epoch: 26 [6400/60000 (11%)]	Loss Char: 2.104871 Loss Font: 0.416397
# Train Epoch: 26 [12800/60000 (21%)]	Loss Char: 2.318805 Loss Font: 0.503120
# Train Epoch: 26 [19200/60000 (32%)]	Loss Char: 2.096732 Loss Font: 0.553780
# Train Epoch: 26 [25600/60000 (43%)]	Loss Char: 2.254629 Loss Font: 0.485902
# Train Epoch: 26 [32000/60000 (53%)]	Loss Char: 2.127838 Loss Font: 0.468459
# Train Epoch: 26 [38400/60000 (64%)]	Loss Char: 2.420775 Loss Font: 0.688524
# Train Epoch: 26 [44800/60000 (75%)]	Loss Char: 2.562526 Loss Font: 0.462066
# Train Epoch: 26 [51200/60000 (85%)]	Loss Char: 2.387604 Loss Font: 0.563625
# Train Epoch: 26 [57600/60000 (96%)]	Loss Char: 2.149333 Loss Font: 0.582389
#
# Test set: Accuracy Char : 2800/10000 (28.00%)
#           Accuracy Font : 7120/10000 (71.20%)
# Train Epoch: 27 [0/60000 (0%)]	Loss Char: 2.260429 Loss Font: 0.693748
# Train Epoch: 27 [6400/60000 (11%)]	Loss Char: 2.227336 Loss Font: 0.644007
# Train Epoch: 27 [12800/60000 (21%)]	Loss Char: 2.310513 Loss Font: 0.613015
# Train Epoch: 27 [19200/60000 (32%)]	Loss Char: 2.280030 Loss Font: 0.575364
# Train Epoch: 27 [25600/60000 (43%)]	Loss Char: 2.107556 Loss Font: 0.542489
# Train Epoch: 27 [32000/60000 (53%)]	Loss Char: 2.175805 Loss Font: 0.501922
# Train Epoch: 27 [38400/60000 (64%)]	Loss Char: 2.460932 Loss Font: 0.480245
# Train Epoch: 27 [44800/60000 (75%)]	Loss Char: 2.330506 Loss Font: 0.511066
# Train Epoch: 27 [51200/60000 (85%)]	Loss Char: 2.212896 Loss Font: 0.733381
# Train Epoch: 27 [57600/60000 (96%)]	Loss Char: 2.313081 Loss Font: 0.492680
#
# Test set: Accuracy Char : 2816/10000 (28.16%)
#           Accuracy Font : 7131/10000 (71.31%)
# Train Epoch: 28 [0/60000 (0%)]	Loss Char: 2.332238 Loss Font: 0.539858
# Train Epoch: 28 [6400/60000 (11%)]	Loss Char: 2.297248 Loss Font: 0.876807
# Train Epoch: 28 [12800/60000 (21%)]	Loss Char: 2.263397 Loss Font: 0.878991
# Train Epoch: 28 [19200/60000 (32%)]	Loss Char: 2.169767 Loss Font: 0.690355
# Train Epoch: 28 [25600/60000 (43%)]	Loss Char: 2.335168 Loss Font: 0.505215
# Train Epoch: 28 [32000/60000 (53%)]	Loss Char: 2.286077 Loss Font: 0.657712
# Train Epoch: 28 [38400/60000 (64%)]	Loss Char: 2.253232 Loss Font: 0.461666
# Train Epoch: 28 [44800/60000 (75%)]	Loss Char: 2.215202 Loss Font: 0.607909
# Train Epoch: 28 [51200/60000 (85%)]	Loss Char: 2.457926 Loss Font: 0.794772
# Train Epoch: 28 [57600/60000 (96%)]	Loss Char: 2.258692 Loss Font: 0.440991
#
# Test set: Accuracy Char : 2780/10000 (27.80%)
#           Accuracy Font : 7075/10000 (70.75%)
# Train Epoch: 29 [0/60000 (0%)]	Loss Char: 2.435177 Loss Font: 0.595983
# Train Epoch: 29 [6400/60000 (11%)]	Loss Char: 2.362322 Loss Font: 0.646348
# Train Epoch: 29 [12800/60000 (21%)]	Loss Char: 2.201022 Loss Font: 0.633842
# Train Epoch: 29 [19200/60000 (32%)]	Loss Char: 2.199768 Loss Font: 0.571997
# Train Epoch: 29 [25600/60000 (43%)]	Loss Char: 2.336332 Loss Font: 0.579069
# Train Epoch: 29 [32000/60000 (53%)]	Loss Char: 2.250010 Loss Font: 0.589464
# Train Epoch: 29 [38400/60000 (64%)]	Loss Char: 2.356006 Loss Font: 0.503072
# Train Epoch: 29 [44800/60000 (75%)]	Loss Char: 2.489684 Loss Font: 0.758352
# Train Epoch: 29 [51200/60000 (85%)]	Loss Char: 2.194682 Loss Font: 0.746775
# Train Epoch: 29 [57600/60000 (96%)]	Loss Char: 2.539641 Loss Font: 0.682100
# Test set: Accuracy Char : 2831/10000 (28.31%)
#           Accuracy Font : 7129/10000 (71.29%)
# Train Epoch: 30 [0/60000 (0%)]	Loss Char: 2.028900 Loss Font: 0.691521
# Train Epoch: 30 [6400/60000 (11%)]	Loss Char: 2.594589 Loss Font: 0.711300
# Train Epoch: 30 [12800/60000 (21%)]	Loss Char: 2.008779 Loss Font: 0.564774
# Train Epoch: 30 [19200/60000 (32%)]	Loss Char: 2.350926 Loss Font: 0.643551
# Train Epoch: 30 [25600/60000 (43%)]	Loss Char: 2.070491 Loss Font: 0.618388
# Train Epoch: 30 [32000/60000 (53%)]	Loss Char: 2.130822 Loss Font: 0.628926
# Train Epoch: 30 [38400/60000 (64%)]	Loss Char: 2.248435 Loss Font: 0.793584
# Train Epoch: 30 [44800/60000 (75%)]	Loss Char: 2.438173 Loss Font: 0.384246
# Train Epoch: 30 [51200/60000 (85%)]	Loss Char: 2.135997 Loss Font: 0.582343
# Train Epoch: 30 [57600/60000 (96%)]	Loss Char: 2.340244 Loss Font: 0.843731
#
# Test set: Accuracy Char : 2855/10000 (28.55%)
#           Accuracy Font : 7124/10000 (71.24%)
# Training set 60000 items
# Testing set  10000 items
# (initial phase)
# Train Epoch: 1 [0/60000 (0%)]	Loss Char: 3.241415 Loss Font: 1.619730
# Train Epoch: 1 [6400/60000 (11%)]	Loss Char: 3.263018 Loss Font: 1.628097
# Train Epoch: 1 [12800/60000 (21%)]	Loss Char: 3.270997 Loss Font: 1.615132
# Train Epoch: 1 [19200/60000 (32%)]	Loss Char: 3.281497 Loss Font: 1.534119
# Train Epoch: 1 [25600/60000 (43%)]	Loss Char: 3.349080 Loss Font: 1.546521
# Train Epoch: 1 [32000/60000 (53%)]	Loss Char: 3.284698 Loss Font: 1.494218
# Train Epoch: 1 [38400/60000 (64%)]	Loss Char: 3.259710 Loss Font: 1.492212
# Train Epoch: 1 [44800/60000 (75%)]	Loss Char: 3.317601 Loss Font: 1.396274
# Train Epoch: 1 [51200/60000 (85%)]	Loss Char: 3.308629 Loss Font: 1.472666
# Train Epoch: 1 [57600/60000 (96%)]	Loss Char: 3.221884 Loss Font: 1.405497
#
# Test set: Accuracy Char : 462/10000 (4.62%)
#           Accuracy Font : 4124/10000 (41.24%)
# (initial phase)
# Train Epoch: 2 [0/60000 (0%)]	Loss Char: 3.207519 Loss Font: 1.499060
# Train Epoch: 2 [6400/60000 (11%)]	Loss Char: 3.227783 Loss Font: 1.351040
# Train Epoch: 2 [12800/60000 (21%)]	Loss Char: 3.244180 Loss Font: 1.126336
# Train Epoch: 2 [19200/60000 (32%)]	Loss Char: 3.160681 Loss Font: 1.352572
# Train Epoch: 2 [25600/60000 (43%)]	Loss Char: 3.183574 Loss Font: 1.316568
# Train Epoch: 2 [32000/60000 (53%)]	Loss Char: 3.200935 Loss Font: 1.304667
# Train Epoch: 2 [38400/60000 (64%)]	Loss Char: 3.126493 Loss Font: 1.196334
# Train Epoch: 2 [44800/60000 (75%)]	Loss Char: 3.068561 Loss Font: 1.207792
# Train Epoch: 2 [51200/60000 (85%)]	Loss Char: 3.069199 Loss Font: 1.098197
# Train Epoch: 2 [57600/60000 (96%)]	Loss Char: 3.069148 Loss Font: 1.177299
#
# Test set: Accuracy Char : 954/10000 (9.54%)
#           Accuracy Font : 5099/10000 (50.99%)
# (initial phase)
# Train Epoch: 3 [0/60000 (0%)]	Loss Char: 3.085202 Loss Font: 1.182961
# Train Epoch: 3 [6400/60000 (11%)]	Loss Char: 3.090423 Loss Font: 1.219852
# Train Epoch: 3 [12800/60000 (21%)]	Loss Char: 3.231507 Loss Font: 1.031398
# Train Epoch: 3 [19200/60000 (32%)]	Loss Char: 3.073160 Loss Font: 1.208520
# Train Epoch: 3 [25600/60000 (43%)]	Loss Char: 2.988332 Loss Font: 1.189705
# Train Epoch: 3 [32000/60000 (53%)]	Loss Char: 2.901659 Loss Font: 1.080075
# Train Epoch: 3 [38400/60000 (64%)]	Loss Char: 2.989711 Loss Font: 1.171021
# Train Epoch: 3 [44800/60000 (75%)]	Loss Char: 3.099116 Loss Font: 1.074513
# Train Epoch: 3 [51200/60000 (85%)]	Loss Char: 2.864553 Loss Font: 1.184706
# Train Epoch: 3 [57600/60000 (96%)]	Loss Char: 3.023208 Loss Font: 1.114001
#
# Test set: Accuracy Char : 1338/10000 (13.38%)
#           Accuracy Font : 5418/10000 (54.18%)
# (initial phase)
# Train Epoch: 4 [0/60000 (0%)]	Loss Char: 2.997872 Loss Font: 1.056815
# Train Epoch: 4 [6400/60000 (11%)]	Loss Char: 2.766458 Loss Font: 0.938360
# Train Epoch: 4 [12800/60000 (21%)]	Loss Char: 2.856854 Loss Font: 1.108281
# Train Epoch: 4 [19200/60000 (32%)]	Loss Char: 2.844776 Loss Font: 1.174923
# Train Epoch: 4 [25600/60000 (43%)]	Loss Char: 2.980901 Loss Font: 1.038894
# Train Epoch: 4 [32000/60000 (53%)]	Loss Char: 2.813131 Loss Font: 0.876292
# Train Epoch: 4 [38400/60000 (64%)]	Loss Char: 2.772401 Loss Font: 1.051256
# Train Epoch: 4 [44800/60000 (75%)]	Loss Char: 2.805861 Loss Font: 1.053291
# Train Epoch: 4 [51200/60000 (85%)]	Loss Char: 2.687517 Loss Font: 1.004375
# Train Epoch: 4 [57600/60000 (96%)]	Loss Char: 2.827705 Loss Font: 1.039387
#
# Test set: Accuracy Char : 1863/10000 (18.63%)
#           Accuracy Font : 5900/10000 (59.00%)
# (initial phase)
# Train Epoch: 5 [0/60000 (0%)]	Loss Char: 2.616552 Loss Font: 0.869547
# Train Epoch: 5 [6400/60000 (11%)]	Loss Char: 2.644687 Loss Font: 0.986470
# Train Epoch: 5 [12800/60000 (21%)]	Loss Char: 2.518281 Loss Font: 0.940778
# Train Epoch: 5 [19200/60000 (32%)]	Loss Char: 2.427081 Loss Font: 0.906559
# Train Epoch: 5 [25600/60000 (43%)]	Loss Char: 2.556287 Loss Font: 0.843067
# Train Epoch: 5 [32000/60000 (53%)]	Loss Char: 2.548599 Loss Font: 1.017592
# Train Epoch: 5 [38400/60000 (64%)]	Loss Char: 2.713661 Loss Font: 0.860155
# Train Epoch: 5 [44800/60000 (75%)]	Loss Char: 2.534139 Loss Font: 0.918040
# Train Epoch: 5 [51200/60000 (85%)]	Loss Char: 2.454515 Loss Font: 0.968704
# Train Epoch: 5 [57600/60000 (96%)]	Loss Char: 2.538097 Loss Font: 0.760653
#
# Test set: Accuracy Char : 2362/10000 (23.62%)
#           Accuracy Font : 6107/10000 (61.07%)
# (initial phase)
# Train Epoch: 6 [0/60000 (0%)]	Loss Char: 2.505681 Loss Font: 0.851479
# Train Epoch: 6 [6400/60000 (11%)]	Loss Char: 2.622647 Loss Font: 0.953182
# Train Epoch: 6 [12800/60000 (21%)]	Loss Char: 2.519301 Loss Font: 0.852091
# Train Epoch: 6 [19200/60000 (32%)]	Loss Char: 2.397657 Loss Font: 0.935180
# Train Epoch: 6 [25600/60000 (43%)]	Loss Char: 2.364400 Loss Font: 0.855711
# Train Epoch: 6 [32000/60000 (53%)]	Loss Char: 2.441684 Loss Font: 0.931718
# Train Epoch: 6 [38400/60000 (64%)]	Loss Char: 2.481534 Loss Font: 0.927142
# Train Epoch: 6 [44800/60000 (75%)]	Loss Char: 2.374841 Loss Font: 0.736201
# Train Epoch: 6 [51200/60000 (85%)]	Loss Char: 2.344272 Loss Font: 1.069886
# Train Epoch: 6 [57600/60000 (96%)]	Loss Char: 2.421772 Loss Font: 0.756299
#
# Test set: Accuracy Char : 2686/10000 (26.86%)
#           Accuracy Font : 6144/10000 (61.44%)
# (initial phase)
# Train Epoch: 7 [0/60000 (0%)]	Loss Char: 2.429507 Loss Font: 0.824293
# Train Epoch: 7 [6400/60000 (11%)]	Loss Char: 2.644153 Loss Font: 0.761268
# Train Epoch: 7 [12800/60000 (21%)]	Loss Char: 2.281783 Loss Font: 0.928055
# Train Epoch: 7 [19200/60000 (32%)]	Loss Char: 2.308526 Loss Font: 1.001602
# Train Epoch: 7 [25600/60000 (43%)]	Loss Char: 2.077121 Loss Font: 0.836495
# Train Epoch: 7 [32000/60000 (53%)]	Loss Char: 2.209131 Loss Font: 0.970984
# Train Epoch: 7 [38400/60000 (64%)]	Loss Char: 2.254699 Loss Font: 0.815222
# Train Epoch: 7 [44800/60000 (75%)]	Loss Char: 2.416778 Loss Font: 0.908124
# Train Epoch: 7 [51200/60000 (85%)]	Loss Char: 2.498140 Loss Font: 0.867565
# Train Epoch: 7 [57600/60000 (96%)]	Loss Char: 2.277665 Loss Font: 0.830104
#
# Test set: Accuracy Char : 2900/10000 (29.00%)
#           Accuracy Font : 6344/10000 (63.44%)
# (initial phase)
# Train Epoch: 8 [0/60000 (0%)]	Loss Char: 2.176007 Loss Font: 0.673463
# Train Epoch: 8 [6400/60000 (11%)]	Loss Char: 2.386080 Loss Font: 0.789331
# Train Epoch: 8 [12800/60000 (21%)]	Loss Char: 2.382780 Loss Font: 0.861489
# Train Epoch: 8 [19200/60000 (32%)]	Loss Char: 2.092609 Loss Font: 0.735713
# Train Epoch: 8 [25600/60000 (43%)]	Loss Char: 2.175648 Loss Font: 0.859557
# Train Epoch: 8 [32000/60000 (53%)]	Loss Char: 2.181084 Loss Font: 0.933011
# Train Epoch: 8 [38400/60000 (64%)]	Loss Char: 2.245403 Loss Font: 0.827092
# Train Epoch: 8 [44800/60000 (75%)]	Loss Char: 2.158715 Loss Font: 0.640619
# Train Epoch: 8 [51200/60000 (85%)]	Loss Char: 2.217150 Loss Font: 0.633119
# Train Epoch: 8 [57600/60000 (96%)]	Loss Char: 2.370155 Loss Font: 0.823836
#
# Test set: Accuracy Char : 3200/10000 (32.00%)
#           Accuracy Font : 6599/10000 (65.99%)
# (initial phase)
# Train Epoch: 9 [0/60000 (0%)]	Loss Char: 2.256904 Loss Font: 0.710445
# Train Epoch: 9 [6400/60000 (11%)]	Loss Char: 2.314316 Loss Font: 0.781568
# Train Epoch: 9 [12800/60000 (21%)]	Loss Char: 2.096962 Loss Font: 0.753784
# Train Epoch: 9 [19200/60000 (32%)]	Loss Char: 2.145629 Loss Font: 0.771372
# Train Epoch: 9 [25600/60000 (43%)]	Loss Char: 2.301601 Loss Font: 0.746959
# Train Epoch: 9 [32000/60000 (53%)]	Loss Char: 2.279788 Loss Font: 0.838071
# Train Epoch: 9 [38400/60000 (64%)]	Loss Char: 1.999935 Loss Font: 0.774363
# Train Epoch: 9 [44800/60000 (75%)]	Loss Char: 2.207775 Loss Font: 0.683812
# Train Epoch: 9 [51200/60000 (85%)]	Loss Char: 2.213757 Loss Font: 0.800260
# Train Epoch: 9 [57600/60000 (96%)]	Loss Char: 2.356125 Loss Font: 0.719768
#
# Test set: Accuracy Char : 3111/10000 (31.11%)
#           Accuracy Font : 6548/10000 (65.48%)
# (initial phase)
# Train Epoch: 10 [0/60000 (0%)]	Loss Char: 2.104309 Loss Font: 0.723060
# Train Epoch: 10 [6400/60000 (11%)]	Loss Char: 1.979629 Loss Font: 0.776139
# Train Epoch: 10 [12800/60000 (21%)]	Loss Char: 2.385142 Loss Font: 0.789376
# Train Epoch: 10 [19200/60000 (32%)]	Loss Char: 1.798293 Loss Font: 0.702201
# Train Epoch: 10 [25600/60000 (43%)]	Loss Char: 2.133091 Loss Font: 0.690897
# Train Epoch: 10 [32000/60000 (53%)]	Loss Char: 2.094879 Loss Font: 0.713692
# Train Epoch: 10 [38400/60000 (64%)]	Loss Char: 2.261243 Loss Font: 0.997405
# Train Epoch: 10 [44800/60000 (75%)]	Loss Char: 2.067286 Loss Font: 0.733459
# Train Epoch: 10 [51200/60000 (85%)]	Loss Char: 2.040209 Loss Font: 0.669155
# Train Epoch: 10 [57600/60000 (96%)]	Loss Char: 1.855520 Loss Font: 0.698910
#
# Test set: Accuracy Char : 3348/10000 (33.48%)
#           Accuracy Font : 6491/10000 (64.91%)
# (perturbate)
# Train Epoch: 11 [0/60000 (0%)]	Loss Char: 1.911289 Loss Font: 0.972825
# Train Epoch: 11 [6400/60000 (11%)]	Loss Char: 1.918952 Loss Font: 0.673722
# Train Epoch: 11 [12800/60000 (21%)]	Loss Char: 2.003019 Loss Font: 0.639690
# Train Epoch: 11 [19200/60000 (32%)]	Loss Char: 2.387902 Loss Font: 0.848180
# Train Epoch: 11 [25600/60000 (43%)]	Loss Char: 2.457869 Loss Font: 0.702197
# Train Epoch: 11 [32000/60000 (53%)]	Loss Char: 2.540974 Loss Font: 0.824302
# Train Epoch: 11 [38400/60000 (64%)]	Loss Char: 2.675549 Loss Font: 0.650261
# Train Epoch: 11 [44800/60000 (75%)]	Loss Char: 2.511302 Loss Font: 0.695934
# Train Epoch: 11 [51200/60000 (85%)]	Loss Char: 2.646115 Loss Font: 0.685322
# Train Epoch: 11 [57600/60000 (96%)]	Loss Char: 2.482363 Loss Font: 0.620233
#
# Test set: Accuracy Char : 2184/10000 (21.84%)
#           Accuracy Font : 6813/10000 (68.13%)
# (perturbate)
# Train Epoch: 12 [0/60000 (0%)]	Loss Char: 2.593806 Loss Font: 0.829119
# Train Epoch: 12 [6400/60000 (11%)]	Loss Char: 2.401996 Loss Font: 0.615026
# Train Epoch: 12 [12800/60000 (21%)]	Loss Char: 2.722701 Loss Font: 0.531876
# Train Epoch: 12 [19200/60000 (32%)]	Loss Char: 2.604060 Loss Font: 0.638299
# Train Epoch: 12 [25600/60000 (43%)]	Loss Char: 2.460174 Loss Font: 0.738467
# Train Epoch: 12 [32000/60000 (53%)]	Loss Char: 2.452445 Loss Font: 0.638788
# Train Epoch: 12 [38400/60000 (64%)]	Loss Char: 2.713425 Loss Font: 0.818542
# Train Epoch: 12 [44800/60000 (75%)]	Loss Char: 2.469560 Loss Font: 0.629503
# Train Epoch: 12 [51200/60000 (85%)]	Loss Char: 2.674075 Loss Font: 0.596731
# Train Epoch: 12 [57600/60000 (96%)]	Loss Char: 2.440004 Loss Font: 0.758047
#
# Test set: Accuracy Char : 2137/10000 (21.37%)
#           Accuracy Font : 6858/10000 (68.58%)
# (perturbate)
# Train Epoch: 13 [0/60000 (0%)]	Loss Char: 2.545103 Loss Font: 0.877387
# Train Epoch: 13 [6400/60000 (11%)]	Loss Char: 2.414618 Loss Font: 0.965556
# Train Epoch: 13 [12800/60000 (21%)]	Loss Char: 2.522891 Loss Font: 0.542053
# Train Epoch: 13 [19200/60000 (32%)]	Loss Char: 2.639013 Loss Font: 0.751294
# Train Epoch: 13 [25600/60000 (43%)]	Loss Char: 2.437310 Loss Font: 0.569826
# Train Epoch: 13 [32000/60000 (53%)]	Loss Char: 2.736735 Loss Font: 0.661633
# Train Epoch: 13 [38400/60000 (64%)]	Loss Char: 2.526060 Loss Font: 0.633986
# Train Epoch: 13 [44800/60000 (75%)]	Loss Char: 2.623560 Loss Font: 0.774024
# Train Epoch: 13 [51200/60000 (85%)]	Loss Char: 2.576790 Loss Font: 0.584372
# Train Epoch: 13 [57600/60000 (96%)]	Loss Char: 2.495947 Loss Font: 0.613840
#
# Test set: Accuracy Char : 2214/10000 (22.14%)
#           Accuracy Font : 6839/10000 (68.39%)
# (perturbate)
# Train Epoch: 14 [0/60000 (0%)]	Loss Char: 2.569469 Loss Font: 0.639236
# Train Epoch: 14 [6400/60000 (11%)]	Loss Char: 2.646667 Loss Font: 0.721966
# Train Epoch: 14 [12800/60000 (21%)]	Loss Char: 2.654764 Loss Font: 0.602792
# Train Epoch: 14 [19200/60000 (32%)]	Loss Char: 2.550347 Loss Font: 0.595436
# Train Epoch: 14 [25600/60000 (43%)]	Loss Char: 2.708184 Loss Font: 0.528096
# Train Epoch: 14 [32000/60000 (53%)]	Loss Char: 2.611120 Loss Font: 0.602626
# Train Epoch: 14 [38400/60000 (64%)]	Loss Char: 2.416919 Loss Font: 0.515329
# Train Epoch: 14 [44800/60000 (75%)]	Loss Char: 2.565678 Loss Font: 0.731754
# Train Epoch: 14 [51200/60000 (85%)]	Loss Char: 2.403042 Loss Font: 0.557801
# Train Epoch: 14 [57600/60000 (96%)]	Loss Char: 2.418970 Loss Font: 1.025138
#
# Test set: Accuracy Char : 2082/10000 (20.82%)
#           Accuracy Font : 6809/10000 (68.09%)
# (perturbate)
# Train Epoch: 15 [0/60000 (0%)]	Loss Char: 2.504658 Loss Font: 0.776703
# Train Epoch: 15 [6400/60000 (11%)]	Loss Char: 2.519381 Loss Font: 0.626256
# Train Epoch: 15 [12800/60000 (21%)]	Loss Char: 2.596933 Loss Font: 0.574038
# Train Epoch: 15 [19200/60000 (32%)]	Loss Char: 2.429409 Loss Font: 0.689478
# Train Epoch: 15 [25600/60000 (43%)]	Loss Char: 2.535076 Loss Font: 0.504169
# Train Epoch: 15 [32000/60000 (53%)]	Loss Char: 2.641885 Loss Font: 0.929331
# Train Epoch: 15 [38400/60000 (64%)]	Loss Char: 2.466435 Loss Font: 0.626173
# Train Epoch: 15 [44800/60000 (75%)]	Loss Char: 2.518897 Loss Font: 0.649405
# Train Epoch: 15 [51200/60000 (85%)]	Loss Char: 2.598327 Loss Font: 0.826740
# Train Epoch: 15 [57600/60000 (96%)]	Loss Char: 2.454324 Loss Font: 0.644577
#
# Test set: Accuracy Char : 2090/10000 (20.90%)
#           Accuracy Font : 6907/10000 (69.07%)
# (perturbate)
# Train Epoch: 16 [0/60000 (0%)]	Loss Char: 2.578067 Loss Font: 0.574381
# Train Epoch: 16 [6400/60000 (11%)]	Loss Char: 2.525385 Loss Font: 0.600225
# Train Epoch: 16 [12800/60000 (21%)]	Loss Char: 2.763030 Loss Font: 0.536858
# Train Epoch: 16 [19200/60000 (32%)]	Loss Char: 2.589029 Loss Font: 0.856705
# Train Epoch: 16 [25600/60000 (43%)]	Loss Char: 2.759305 Loss Font: 0.718547
# Train Epoch: 16 [32000/60000 (53%)]	Loss Char: 2.657133 Loss Font: 0.807783
# Train Epoch: 16 [38400/60000 (64%)]	Loss Char: 2.640115 Loss Font: 0.769573
# Train Epoch: 16 [44800/60000 (75%)]	Loss Char: 2.365943 Loss Font: 0.603080
# Train Epoch: 16 [51200/60000 (85%)]	Loss Char: 2.431429 Loss Font: 0.638797
# Train Epoch: 16 [57600/60000 (96%)]	Loss Char: 2.651228 Loss Font: 0.633842
#
# Test set: Accuracy Char : 2111/10000 (21.11%)
#           Accuracy Font : 6863/10000 (68.63%)
# (perturbate)
# Train Epoch: 17 [0/60000 (0%)]	Loss Char: 2.738292 Loss Font: 0.595035
# Train Epoch: 17 [6400/60000 (11%)]	Loss Char: 2.483656 Loss Font: 0.696768
# Train Epoch: 17 [12800/60000 (21%)]	Loss Char: 2.568130 Loss Font: 0.731378
# Train Epoch: 17 [19200/60000 (32%)]	Loss Char: 2.543926 Loss Font: 0.918418
# Train Epoch: 17 [25600/60000 (43%)]	Loss Char: 2.714811 Loss Font: 0.671419
# Train Epoch: 17 [32000/60000 (53%)]	Loss Char: 2.731539 Loss Font: 0.675734
# Train Epoch: 17 [38400/60000 (64%)]	Loss Char: 2.494451 Loss Font: 0.565732
# Train Epoch: 17 [44800/60000 (75%)]	Loss Char: 2.281831 Loss Font: 0.664655
# Train Epoch: 17 [51200/60000 (85%)]	Loss Char: 2.745043 Loss Font: 0.714150
# Train Epoch: 17 [57600/60000 (96%)]	Loss Char: 2.447744 Loss Font: 0.605052
#
# Test set: Accuracy Char : 2043/10000 (20.43%)
#           Accuracy Font : 6893/10000 (68.93%)
# (perturbate)
# Train Epoch: 18 [0/60000 (0%)]	Loss Char: 2.362996 Loss Font: 0.606563
# Train Epoch: 18 [6400/60000 (11%)]	Loss Char: 2.715343 Loss Font: 0.634865
# Train Epoch: 18 [12800/60000 (21%)]	Loss Char: 2.906090 Loss Font: 0.589441
# Train Epoch: 18 [19200/60000 (32%)]	Loss Char: 2.553112 Loss Font: 0.620511
# Train Epoch: 18 [25600/60000 (43%)]	Loss Char: 2.573698 Loss Font: 0.693650
# Train Epoch: 18 [32000/60000 (53%)]	Loss Char: 2.543342 Loss Font: 0.467468
# Train Epoch: 18 [38400/60000 (64%)]	Loss Char: 2.784765 Loss Font: 0.448962
# Train Epoch: 18 [44800/60000 (75%)]	Loss Char: 2.558293 Loss Font: 0.695627
# Train Epoch: 18 [51200/60000 (85%)]	Loss Char: 2.557571 Loss Font: 0.521903
# Train Epoch: 18 [57600/60000 (96%)]	Loss Char: 2.491757 Loss Font: 0.523467
#
# Test set: Accuracy Char : 2038/10000 (20.38%)
#           Accuracy Font : 6944/10000 (69.44%)
# (perturbate)
# Train Epoch: 19 [0/60000 (0%)]	Loss Char: 2.435590 Loss Font: 0.879435
# Train Epoch: 19 [6400/60000 (11%)]	Loss Char: 2.834854 Loss Font: 0.483483
# Train Epoch: 19 [12800/60000 (21%)]	Loss Char: 2.727463 Loss Font: 0.544463
# Train Epoch: 19 [19200/60000 (32%)]	Loss Char: 2.573076 Loss Font: 0.850896
# Train Epoch: 19 [25600/60000 (43%)]	Loss Char: 2.536852 Loss Font: 0.539091
# Train Epoch: 19 [32000/60000 (53%)]	Loss Char: 2.518714 Loss Font: 0.738499
# Train Epoch: 19 [38400/60000 (64%)]	Loss Char: 2.514444 Loss Font: 0.781190
# Train Epoch: 19 [44800/60000 (75%)]	Loss Char: 2.660561 Loss Font: 0.837410
# Train Epoch: 19 [51200/60000 (85%)]	Loss Char: 2.459427 Loss Font: 0.658600
# Train Epoch: 19 [57600/60000 (96%)]	Loss Char: 2.518150 Loss Font: 0.570098
#
# Test set: Accuracy Char : 2038/10000 (20.38%)
#           Accuracy Font : 6952/10000 (69.52%)
# (perturbate)
# Train Epoch: 20 [0/60000 (0%)]	Loss Char: 2.693314 Loss Font: 0.533068
# Train Epoch: 20 [6400/60000 (11%)]	Loss Char: 2.745702 Loss Font: 0.725233
# Train Epoch: 20 [12800/60000 (21%)]	Loss Char: 2.582948 Loss Font: 0.654785
# Train Epoch: 20 [19200/60000 (32%)]	Loss Char: 2.496235 Loss Font: 0.603441
# Train Epoch: 20 [25600/60000 (43%)]	Loss Char: 2.765830 Loss Font: 0.520860
# Train Epoch: 20 [32000/60000 (53%)]	Loss Char: 2.482251 Loss Font: 0.531627
# Train Epoch: 20 [38400/60000 (64%)]	Loss Char: 2.479475 Loss Font: 0.619142
# Train Epoch: 20 [44800/60000 (75%)]	Loss Char: 2.602201 Loss Font: 0.591593
# Train Epoch: 20 [51200/60000 (85%)]	Loss Char: 2.564740 Loss Font: 0.620688
# Train Epoch: 20 [57600/60000 (96%)]	Loss Char: 2.505534 Loss Font: 0.590568
#
# Test set: Accuracy Char : 2074/10000 (20.74%)
#           Accuracy Font : 7043/10000 (70.43%)
# Train Epoch: 21 [0/60000 (0%)]	Loss Char: 2.612791 Loss Font: 0.650771
# Train Epoch: 21 [6400/60000 (11%)]	Loss Char: 2.722205 Loss Font: 0.483112
# Train Epoch: 21 [12800/60000 (21%)]	Loss Char: 2.608652 Loss Font: 0.659845
# Train Epoch: 21 [19200/60000 (32%)]	Loss Char: 2.522640 Loss Font: 0.500813
# Train Epoch: 21 [25600/60000 (43%)]	Loss Char: 2.688796 Loss Font: 0.672685
# Train Epoch: 21 [32000/60000 (53%)]	Loss Char: 2.586300 Loss Font: 0.621277
# Train Epoch: 21 [38400/60000 (64%)]	Loss Char: 2.664905 Loss Font: 0.653833
# Train Epoch: 21 [44800/60000 (75%)]	Loss Char: 2.503790 Loss Font: 0.479495
# Train Epoch: 21 [51200/60000 (85%)]	Loss Char: 2.454288 Loss Font: 0.592851
# Train Epoch: 21 [57600/60000 (96%)]	Loss Char: 2.434423 Loss Font: 0.463107
#
# Test set: Accuracy Char : 2110/10000 (21.10%)
#           Accuracy Font : 6995/10000 (69.95%)
# Train Epoch: 22 [0/60000 (0%)]	Loss Char: 2.440754 Loss Font: 0.509510
# Train Epoch: 22 [6400/60000 (11%)]	Loss Char: 2.766414 Loss Font: 0.700444
# Train Epoch: 22 [12800/60000 (21%)]	Loss Char: 2.513144 Loss Font: 0.614682
# Train Epoch: 22 [19200/60000 (32%)]	Loss Char: 2.606046 Loss Font: 0.606139
# Train Epoch: 22 [25600/60000 (43%)]	Loss Char: 2.429063 Loss Font: 0.640279
# Train Epoch: 22 [32000/60000 (53%)]	Loss Char: 2.660907 Loss Font: 0.606338
# Train Epoch: 22 [38400/60000 (64%)]	Loss Char: 2.414920 Loss Font: 0.481349
# Train Epoch: 22 [44800/60000 (75%)]	Loss Char: 2.848778 Loss Font: 0.601504
# Train Epoch: 22 [51200/60000 (85%)]	Loss Char: 2.647124 Loss Font: 0.657608
# Train Epoch: 22 [57600/60000 (96%)]	Loss Char: 2.580181 Loss Font: 0.649203
#
# Test set: Accuracy Char : 2126/10000 (21.26%)
#           Accuracy Font : 7014/10000 (70.14%)
# Train Epoch: 23 [0/60000 (0%)]	Loss Char: 2.569909 Loss Font: 0.642454
# Train Epoch: 23 [6400/60000 (11%)]	Loss Char: 2.407730 Loss Font: 0.595234
# Train Epoch: 23 [12800/60000 (21%)]	Loss Char: 2.493759 Loss Font: 0.577123
# Train Epoch: 23 [19200/60000 (32%)]	Loss Char: 2.500697 Loss Font: 0.690531
# Train Epoch: 23 [25600/60000 (43%)]	Loss Char: 2.644835 Loss Font: 0.666216
# Train Epoch: 23 [32000/60000 (53%)]	Loss Char: 2.511658 Loss Font: 0.471581
# Train Epoch: 23 [38400/60000 (64%)]	Loss Char: 2.564902 Loss Font: 0.481695
# Train Epoch: 23 [44800/60000 (75%)]	Loss Char: 2.424130 Loss Font: 0.672106
# Train Epoch: 23 [51200/60000 (85%)]	Loss Char: 2.527437 Loss Font: 0.627494
# Train Epoch: 23 [57600/60000 (96%)]	Loss Char: 2.364095 Loss Font: 0.468525
#
# Test set: Accuracy Char : 2149/10000 (21.49%)
#           Accuracy Font : 6955/10000 (69.55%)
# Train Epoch: 24 [0/60000 (0%)]	Loss Char: 2.662703 Loss Font: 0.533365
# Train Epoch: 24 [6400/60000 (11%)]	Loss Char: 2.485518 Loss Font: 0.529549
# Train Epoch: 24 [12800/60000 (21%)]	Loss Char: 2.748636 Loss Font: 0.534825
# Train Epoch: 24 [19200/60000 (32%)]	Loss Char: 2.324844 Loss Font: 0.641928
# Train Epoch: 24 [25600/60000 (43%)]	Loss Char: 2.548511 Loss Font: 0.433594
# Train Epoch: 24 [32000/60000 (53%)]	Loss Char: 2.500054 Loss Font: 0.546623
# Train Epoch: 24 [38400/60000 (64%)]	Loss Char: 2.583615 Loss Font: 0.808258
# Train Epoch: 24 [44800/60000 (75%)]	Loss Char: 2.529810 Loss Font: 0.557307
# Train Epoch: 24 [51200/60000 (85%)]	Loss Char: 2.725142 Loss Font: 0.722994
# Train Epoch: 24 [57600/60000 (96%)]	Loss Char: 2.563755 Loss Font: 0.612359
#
# Test set: Accuracy Char : 2144/10000 (21.44%)
#           Accuracy Font : 7036/10000 (70.36%)
# Train Epoch: 25 [0/60000 (0%)]	Loss Char: 2.579883 Loss Font: 0.640072
# Train Epoch: 25 [6400/60000 (11%)]	Loss Char: 2.620862 Loss Font: 0.670949
# Train Epoch: 25 [12800/60000 (21%)]	Loss Char: 2.446798 Loss Font: 0.476750
# Train Epoch: 25 [19200/60000 (32%)]	Loss Char: 2.482459 Loss Font: 0.455351
# Train Epoch: 25 [25600/60000 (43%)]	Loss Char: 2.523894 Loss Font: 0.489592
# Train Epoch: 25 [32000/60000 (53%)]	Loss Char: 2.554716 Loss Font: 0.590982
# Train Epoch: 25 [38400/60000 (64%)]	Loss Char: 2.474787 Loss Font: 0.506143
# Train Epoch: 25 [44800/60000 (75%)]	Loss Char: 2.508649 Loss Font: 0.544697
# Train Epoch: 25 [51200/60000 (85%)]	Loss Char: 2.705246 Loss Font: 0.597357
# Train Epoch: 25 [57600/60000 (96%)]	Loss Char: 2.619870 Loss Font: 0.578580
#
# Test set: Accuracy Char : 2181/10000 (21.81%)
#           Accuracy Font : 7039/10000 (70.39%)
# Train Epoch: 26 [0/60000 (0%)]	Loss Char: 2.604396 Loss Font: 0.684152
# Train Epoch: 26 [6400/60000 (11%)]	Loss Char: 2.474729 Loss Font: 0.468684
# Train Epoch: 26 [12800/60000 (21%)]	Loss Char: 2.571805 Loss Font: 0.528102
# Train Epoch: 26 [19200/60000 (32%)]	Loss Char: 2.270301 Loss Font: 0.541580
# Train Epoch: 26 [25600/60000 (43%)]	Loss Char: 2.545729 Loss Font: 0.543446
# Train Epoch: 26 [32000/60000 (53%)]	Loss Char: 2.452836 Loss Font: 0.493420
# Train Epoch: 26 [38400/60000 (64%)]	Loss Char: 2.655632 Loss Font: 0.639999
# Train Epoch: 26 [44800/60000 (75%)]	Loss Char: 2.755670 Loss Font: 0.454268
# Train Epoch: 26 [51200/60000 (85%)]	Loss Char: 2.728295 Loss Font: 0.552248
# Train Epoch: 26 [57600/60000 (96%)]	Loss Char: 2.536938 Loss Font: 0.583339
#
# Test set: Accuracy Char : 2207/10000 (22.07%)
#           Accuracy Font : 7019/10000 (70.19%)
# Train Epoch: 27 [0/60000 (0%)]	Loss Char: 2.519766 Loss Font: 0.662737
# Train Epoch: 27 [6400/60000 (11%)]	Loss Char: 2.466607 Loss Font: 0.626812
# Train Epoch: 27 [12800/60000 (21%)]	Loss Char: 2.573133 Loss Font: 0.637698
# Train Epoch: 27 [19200/60000 (32%)]	Loss Char: 2.572999 Loss Font: 0.623653
# Train Epoch: 27 [25600/60000 (43%)]	Loss Char: 2.354658 Loss Font: 0.579478
# Train Epoch: 27 [32000/60000 (53%)]	Loss Char: 2.429542 Loss Font: 0.529656
# Train Epoch: 27 [38400/60000 (64%)]	Loss Char: 2.662252 Loss Font: 0.525564
# Train Epoch: 27 [44800/60000 (75%)]	Loss Char: 2.575558 Loss Font: 0.521533
# Train Epoch: 27 [51200/60000 (85%)]	Loss Char: 2.450480 Loss Font: 0.755180
# Train Epoch: 27 [57600/60000 (96%)]	Loss Char: 2.543088 Loss Font: 0.494259
#
# Test set: Accuracy Char : 2208/10000 (22.08%)
#           Accuracy Font : 7035/10000 (70.35%)
# Train Epoch: 28 [0/60000 (0%)]	Loss Char: 2.546760 Loss Font: 0.564482
# Train Epoch: 28 [6400/60000 (11%)]	Loss Char: 2.531752 Loss Font: 0.865163
# Train Epoch: 28 [12800/60000 (21%)]	Loss Char: 2.478800 Loss Font: 0.827094
# Train Epoch: 28 [19200/60000 (32%)]	Loss Char: 2.413743 Loss Font: 0.701945
# Train Epoch: 28 [25600/60000 (43%)]	Loss Char: 2.484713 Loss Font: 0.508945
# Train Epoch: 28 [32000/60000 (53%)]	Loss Char: 2.428162 Loss Font: 0.690285
# Train Epoch: 28 [38400/60000 (64%)]	Loss Char: 2.543729 Loss Font: 0.499097
# Train Epoch: 28 [44800/60000 (75%)]	Loss Char: 2.488402 Loss Font: 0.644726
# Train Epoch: 28 [51200/60000 (85%)]	Loss Char: 2.602577 Loss Font: 0.772296
# Train Epoch: 28 [57600/60000 (96%)]	Loss Char: 2.455685 Loss Font: 0.490816
#
# Test set: Accuracy Char : 2263/10000 (22.63%)
#           Accuracy Font : 6981/10000 (69.81%)
# Train Epoch: 29 [0/60000 (0%)]	Loss Char: 2.630005 Loss Font: 0.596331
# Train Epoch: 29 [6400/60000 (11%)]	Loss Char: 2.624457 Loss Font: 0.706164
# Train Epoch: 29 [12800/60000 (21%)]	Loss Char: 2.378828 Loss Font: 0.660552
# Train Epoch: 29 [19200/60000 (32%)]	Loss Char: 2.489000 Loss Font: 0.597216
# Train Epoch: 29 [25600/60000 (43%)]	Loss Char: 2.601361 Loss Font: 0.569700
# Train Epoch: 29 [32000/60000 (53%)]	Loss Char: 2.440486 Loss Font: 0.613631
# Train Epoch: 29 [38400/60000 (64%)]	Loss Char: 2.534999 Loss Font: 0.499537
# Train Epoch: 29 [44800/60000 (75%)]	Loss Char: 2.717971 Loss Font: 0.833563
# Train Epoch: 29 [51200/60000 (85%)]	Loss Char: 2.434859 Loss Font: 0.709989
# Train Epoch: 29 [57600/60000 (96%)]	Loss Char: 2.650383 Loss Font: 0.713619
#
# Test set: Accuracy Char : 2249/10000 (22.49%)
#           Accuracy Font : 7018/10000 (70.18%)
# Train Epoch: 30 [0/60000 (0%)]	Loss Char: 2.348470 Loss Font: 0.721288
# Train Epoch: 30 [6400/60000 (11%)]	Loss Char: 2.765362 Loss Font: 0.722912
# Train Epoch: 30 [12800/60000 (21%)]	Loss Char: 2.335887 Loss Font: 0.600518
# Train Epoch: 30 [19200/60000 (32%)]	Loss Char: 2.575335 Loss Font: 0.635736
# Train Epoch: 30 [25600/60000 (43%)]	Loss Char: 2.342625 Loss Font: 0.632730
# Train Epoch: 30 [32000/60000 (53%)]	Loss Char: 2.336343 Loss Font: 0.677662
# Train Epoch: 30 [38400/60000 (64%)]	Loss Char: 2.571282 Loss Font: 0.814257
# Train Epoch: 30 [44800/60000 (75%)]	Loss Char: 2.642914 Loss Font: 0.414301
# Train Epoch: 30 [51200/60000 (85%)]	Loss Char: 2.409725 Loss Font: 0.586262
# Train Epoch: 30 [57600/60000 (96%)]	Loss Char: 2.649006 Loss Font: 0.857081
#
# Test set: Accuracy Char : 2284/10000 (22.84%)
#           Accuracy Font : 7045/10000 (70.45%)

# %%
main_results = {k:v for k, v in inverse_results.items() if 'Main' in k}
show_results(main_results, "The impact of perturbation with recovering phase on the main task", ymin=50, ymax=75)

# %%
collateral_results = {k:v for k, v in inverse_results.items() if 'Collateral' in k}
title = "The impact of perturbation with recovering phase on the collateral task"
show_results(collateral_results, title, ymin=5, ymax=50)

# %% [markdown]
# So the values of alpha need to be changed, but we observe a similarly good trade-off!
